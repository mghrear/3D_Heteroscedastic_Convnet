# %%
import numpy as np
import pandas as pd
import torch
import copy
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
from torchvision import datasets
import spconv.pytorch as spconv
import matplotlib.pyplot as plt
import mytools
import mymodels

# %% [markdown]
# # Prepare Data

# %%
# Read pandas dataframe with all information about sparse training tensors
file_loc = '/mnt/lustre/koa/scratch/majd/sparse_training_tensors/'
st_info = pd.read_pickle(file_loc+'sparse_tensor_info.pk')
st_info
# Out:
#                                                        dir  \
# 0        [0.5923457337920527, -0.5369941830475861, -0.6...
# 1        [-0.6164927192719855, 0.5695943083433039, -0.5...
# 2        [0.6322337566233259, -0.16773581669128113, -0....
# 3        [0.2908139608694231, -0.8484810341097399, -0.4...
# 4        [0.7738521869833273, -0.07925597736546798, -0....
# ...                                                    ...
# 2766793  [-0.2069418024409927, 0.2672370217202399, -0.9...
# 2766794  [0.5942730241053608, 0.6175260630673811, -0.51...
# 2766795  [0.3312106913072638, 0.5407131844563555, 0.773...
# 2766796  [-0.0071324298603245555, 0.623790473641556, 0....
# 2766797  [-0.06412683698521963, -0.9977986677530827, 0....
#
#                                                     offset      diff energy  \
# 0        [-0.851898273495669, 2.1253245532459824, 0.445...  0.046168     40
# 1        [-1.017085182270888, -1.6805460012244295, 1.10...  0.028843     40
# 2        [-0.10613203070195368, 0.22289410895907838, 1....  0.025293     40
# 3        [-1.0096727220437194, 1.2613684348817842, 1.42...  0.034410     40
# 4        [0.7752193984015442, 0.8404383794565299, 0.902...  0.033654     40
# ...                                                    ...       ...    ...
# 2766793  [-0.5891835692649702, -0.5092523892090935, 1.8...  0.043683     50
# 2766794  [-0.723736545709404, -0.10798660967928463, 0.6...  0.030250     50
# 2766795  [-0.3615579024644222, 1.934812461239543, -2.26...  0.030298     50
# 2766796  [0.7469683683355023, -2.603944946514045, -0.74...  0.039175     50
# 2766797  [1.8179965860730307, 1.618875928754491, -1.181...  0.024449     50
#
#         true_index
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
# ...            ...
# 2766793    2766793
# 2766794    2766794
# 2766795    2766795
# 2766796    2766796
# 2766797    2766797
#
# [2766798 rows x 5 columns]

# %%
# Make custom dataset
MyDataset = mytools.CustomDataset(dir_loc = file_loc, st_info = st_info)

# Split datat into training, validation, and testing sets
train_dataset, val_dataset = torch.utils.data.random_split(MyDataset,[0.8, 0.2], generator=torch.Generator().manual_seed(42))

print("Training samples: ", len(train_dataset))
print("Validation samples: ", len(val_dataset))

# Create training and validation DataLoaders
batch_size = 256
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
# Out:
# Training samples:  2213439
# Validation samples:  553359

# %%
# Print tensor shapes
for X_plot, y_plot, offset_plot in train_dataloader:
    print(f"Shape of X [N, C, H, W, D]: {X_plot.shape}")
    print(f"Shape of y: {y_plot.shape} {y_plot.dtype}")
    print("Offsets: ", offset_plot.shape)
    break
# Out:
# Shape of X [N, C, H, W, D]: torch.Size([256, 120, 120, 120, 1])
# Shape of y: torch.Size([256, 3]) torch.float32
# Offsets:  torch.Size([256, 3])

# %%
#Record shape of voxel grid
grid_shape = X_plot.shape[1:4]
print("Voxel grid shape: " , grid_shape)
# Out:
# Voxel grid shape:  torch.Size([120, 120, 120])

# %% [markdown]
# # Visualize a sample

# %%
# Plot an example as a sanity check

# x/y/z length being kept in cm
eff_l = mytools.voxel_grid['eff_l']
# Voxel size in cm
vox_l = mytools.voxel_grid['vox_l']

#Convert to dense, reshape and convert to numpy
X_plot = X_plot.to_dense().reshape(-1, 1, 120, 120, 120).numpy()

index = 2
mytools.plot_tensor_dir(tensor = X_plot[index], start = offset_plot[index].numpy(), direction = y_plot[index].numpy(), eff_l=eff_l, vox_l=vox_l)

# %% [markdown]
# # Initialize Convnet

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Using {device} device")

model = mymodels.spConvnet_subM_alpha(shape = grid_shape ).to(device)
print(model)
# Out:
# Using cuda device
# spConvnet_subM_alpha(
#   (net): SparseSequential(
#     (0): SubMConv3d(1, 32, kernel_size=[7, 7, 7], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (1): ReLU()
#     (2): SubMConv3d(32, 40, kernel_size=[5, 5, 5], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (3): ReLU()
#     (4): SparseConv3d(40, 50, kernel_size=[6, 6, 6], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (5): ReLU()
#     (6): SparseMaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], algo=ConvAlgo.MaskImplicitGemm)
#     (7): SparseConv3d(50, 30, kernel_size=[3, 3, 3], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.MaskImplicitGemm)
#     (8): ReLU()
#     (9): SparseConv3d(30, 10, kernel_size=[3, 3, 3], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.MaskImplicitGemm)
#     (10): ReLU()
#     (11): SparseMaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], algo=ConvAlgo.MaskImplicitGemm)
#     (12): ToDense()
#   )
#   (fc1): Linear(in_features=2160, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=200, bias=True)
#   (fc3): Linear(in_features=200, out_features=50, bias=True)
#   (fc4): Linear(in_features=50, out_features=3, bias=True)
# )

# %% [markdown]
# # Train the model

# %%
# Specify optimizer
optimizer = torch.optim.Adam(params = model.parameters(), lr=0.0001, betas=(0.94, 0.999), eps=1e-07)

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored

alpha = 1e-4
patience = 5

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 1000
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_alpha(train_dataloader, model, mytools.CSloss_alpha, optimizer, device,alpha))
    Validation_losses = np.append(Validation_losses, mytools.validate_alpha(val_dataloader, model, mytools.CSloss_alpha, device,alpha))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_model = copy.deepcopy(model)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Current batch training loss: -0.103325  [    0/2213439]
# Current batch training loss: -0.303156  [25600/2213439]
# Current batch training loss: -0.438751  [51200/2213439]
# Current batch training loss: -0.433904  [76800/2213439]
# Current batch training loss: -0.505284  [102400/2213439]
# Current batch training loss: -0.488072  [128000/2213439]
# Current batch training loss: -0.588975  [153600/2213439]
# Current batch training loss: -0.588219  [179200/2213439]
# Current batch training loss: -0.578258  [204800/2213439]
# Current batch training loss: -0.624038  [230400/2213439]
# Current batch training loss: -0.583040  [256000/2213439]
# Current batch training loss: -0.614264  [281600/2213439]
# Current batch training loss: -0.638030  [307200/2213439]
# Current batch training loss: -0.618277  [332800/2213439]
# Current batch training loss: -0.635875  [358400/2213439]
# Current batch training loss: -0.634809  [384000/2213439]
# Current batch training loss: -0.693508  [409600/2213439]
# Current batch training loss: -0.676448  [435200/2213439]
# Current batch training loss: -0.683816  [460800/2213439]
# Current batch training loss: -0.671430  [486400/2213439]
# Current batch training loss: -0.708054  [512000/2213439]
# Current batch training loss: -0.764509  [537600/2213439]
# Current batch training loss: -0.751089  [563200/2213439]
# Current batch training loss: -0.740014  [588800/2213439]
# Current batch training loss: -0.765118  [614400/2213439]
# Current batch training loss: -0.758585  [640000/2213439]
# Current batch training loss: -0.745983  [665600/2213439]
# Current batch training loss: -0.773939  [691200/2213439]
# Current batch training loss: -0.789514  [716800/2213439]
# Current batch training loss: -0.769535  [742400/2213439]
# Current batch training loss: -0.799562  [768000/2213439]
# Current batch training loss: -0.802927  [793600/2213439]
# Current batch training loss: -0.803038  [819200/2213439]
# Current batch training loss: -0.798392  [844800/2213439]
# Current batch training loss: -0.832879  [870400/2213439]
# Current batch training loss: -0.779411  [896000/2213439]
# Current batch training loss: -0.815055  [921600/2213439]
# Current batch training loss: -0.794930  [947200/2213439]
# Current batch training loss: -0.826726  [972800/2213439]
# Current batch training loss: -0.837928  [998400/2213439]
# Current batch training loss: -0.834439  [1024000/2213439]
# Current batch training loss: -0.880948  [1049600/2213439]
# Current batch training loss: -0.839391  [1075200/2213439]
# Current batch training loss: -0.836493  [1100800/2213439]
# Current batch training loss: -0.835674  [1126400/2213439]
# Current batch training loss: -0.811006  [1152000/2213439]
# Current batch training loss: -0.852336  [1177600/2213439]
# Current batch training loss: -0.813993  [1203200/2213439]
# Current batch training loss: -0.839349  [1228800/2213439]
# Current batch training loss: -0.839198  [1254400/2213439]
# Current batch training loss: -0.807028  [1280000/2213439]
# Current batch training loss: -0.843612  [1305600/2213439]
# Current batch training loss: -0.867989  [1331200/2213439]
# Current batch training loss: -0.855450  [1356800/2213439]
# Current batch training loss: -0.844889  [1382400/2213439]
# Current batch training loss: -0.856091  [1408000/2213439]
# Current batch training loss: -0.859631  [1433600/2213439]
# Current batch training loss: -0.839333  [1459200/2213439]
# Current batch training loss: -0.853868  [1484800/2213439]
# Current batch training loss: -0.834491  [1510400/2213439]
# Current batch training loss: -0.884963  [1536000/2213439]
# Current batch training loss: -0.855642  [1561600/2213439]
# Current batch training loss: -0.876607  [1587200/2213439]
# Current batch training loss: -0.830415  [1612800/2213439]
# Current batch training loss: -0.845711  [1638400/2213439]
# Current batch training loss: -0.864900  [1664000/2213439]
# Current batch training loss: -0.874116  [1689600/2213439]
# Current batch training loss: -0.865438  [1715200/2213439]
# Current batch training loss: -0.863243  [1740800/2213439]
# Current batch training loss: -0.837461  [1766400/2213439]
# Current batch training loss: -0.872827  [1792000/2213439]
# Current batch training loss: -0.828433  [1817600/2213439]
# Current batch training loss: -0.878304  [1843200/2213439]
# Current batch training loss: -0.835628  [1868800/2213439]
# Current batch training loss: -0.865466  [1894400/2213439]
# Current batch training loss: -0.894108  [1920000/2213439]
# Current batch training loss: -0.878383  [1945600/2213439]
# Current batch training loss: -0.880088  [1971200/2213439]
# Current batch training loss: -0.875892  [1996800/2213439]
# Current batch training loss: -0.864497  [2022400/2213439]
# Current batch training loss: -0.870962  [2048000/2213439]
# Current batch training loss: -0.865862  [2073600/2213439]
# Current batch training loss: -0.890928  [2099200/2213439]
# Current batch training loss: -0.885610  [2124800/2213439]
# Current batch training loss: -0.899952  [2150400/2213439]
# Current batch training loss: -0.887291  [2176000/2213439]
# Current batch training loss: -0.905305  [2201600/2213439]
# Training loss: -0.773450
# Validation loss: -0.882062
#
# Epoch 2
# -------------------------------
# Current batch training loss: -0.884616  [    0/2213439]
# Current batch training loss: -0.885186  [25600/2213439]
# Current batch training loss: -0.869595  [51200/2213439]
# Current batch training loss: -0.894628  [76800/2213439]
# Current batch training loss: -0.881931  [102400/2213439]
# Current batch training loss: -0.894692  [128000/2213439]
# Current batch training loss: -0.883713  [153600/2213439]
# Current batch training loss: -0.853389  [179200/2213439]
# Current batch training loss: -0.886470  [204800/2213439]
# Current batch training loss: -0.877504  [230400/2213439]
# Current batch training loss: -0.867309  [256000/2213439]
# Current batch training loss: -0.906656  [281600/2213439]
# Current batch training loss: -0.880084  [307200/2213439]
# Current batch training loss: -0.881364  [332800/2213439]
# Current batch training loss: -0.917097  [358400/2213439]
# Current batch training loss: -0.885246  [384000/2213439]
# Current batch training loss: -0.906269  [409600/2213439]
# Current batch training loss: -0.905642  [435200/2213439]
# Current batch training loss: -0.903520  [460800/2213439]
# Current batch training loss: -0.910350  [486400/2213439]
# Current batch training loss: -0.900569  [512000/2213439]
# Current batch training loss: -0.842770  [537600/2213439]
# Current batch training loss: -0.864357  [563200/2213439]
# Current batch training loss: -0.899491  [588800/2213439]
# Current batch training loss: -0.911130  [614400/2213439]
# Current batch training loss: -0.895007  [640000/2213439]
# Current batch training loss: -0.888345  [665600/2213439]
# Current batch training loss: -0.904079  [691200/2213439]
# Current batch training loss: -0.902931  [716800/2213439]
# Current batch training loss: -0.908245  [742400/2213439]
# Current batch training loss: -0.906914  [768000/2213439]
# Current batch training loss: -0.912267  [793600/2213439]
# Current batch training loss: -0.917466  [819200/2213439]
# Current batch training loss: -0.924930  [844800/2213439]
# Current batch training loss: -0.893400  [870400/2213439]
# Current batch training loss: -0.889423  [896000/2213439]
# Current batch training loss: -0.890403  [921600/2213439]
# Current batch training loss: -0.906946  [947200/2213439]
# Current batch training loss: -0.909427  [972800/2213439]
# Current batch training loss: -0.901961  [998400/2213439]
# Current batch training loss: -0.927688  [1024000/2213439]
# Current batch training loss: -0.924811  [1049600/2213439]
# Current batch training loss: -0.907597  [1075200/2213439]
# Current batch training loss: -0.915968  [1100800/2213439]
# Current batch training loss: -0.902897  [1126400/2213439]
# Current batch training loss: -0.892650  [1152000/2213439]
# Current batch training loss: -0.901812  [1177600/2213439]
# Current batch training loss: -0.916116  [1203200/2213439]
# Current batch training loss: -0.909388  [1228800/2213439]
# Current batch training loss: -0.905889  [1254400/2213439]
# Current batch training loss: -0.922928  [1280000/2213439]
# Current batch training loss: -0.915408  [1305600/2213439]
# Current batch training loss: -0.900362  [1331200/2213439]
# Current batch training loss: -0.915741  [1356800/2213439]
# Current batch training loss: -0.896910  [1382400/2213439]
# Current batch training loss: -0.913036  [1408000/2213439]
# Current batch training loss: -0.892940  [1433600/2213439]
# Current batch training loss: -0.913580  [1459200/2213439]
# Current batch training loss: -0.904746  [1484800/2213439]
# Current batch training loss: -0.906610  [1510400/2213439]
# Current batch training loss: -0.912824  [1536000/2213439]
# Current batch training loss: -0.902329  [1561600/2213439]
# Current batch training loss: -0.922904  [1587200/2213439]
# Current batch training loss: -0.894438  [1612800/2213439]
# Current batch training loss: -0.896789  [1638400/2213439]
# Current batch training loss: -0.932923  [1664000/2213439]
# Current batch training loss: -0.904770  [1689600/2213439]
# Current batch training loss: -0.910347  [1715200/2213439]
# Current batch training loss: -0.908922  [1740800/2213439]
# Current batch training loss: -0.910840  [1766400/2213439]
# Current batch training loss: -0.921602  [1792000/2213439]
# Current batch training loss: -0.925316  [1817600/2213439]
# Current batch training loss: -0.940914  [1843200/2213439]
# Current batch training loss: -0.906752  [1868800/2213439]
# Current batch training loss: -0.900103  [1894400/2213439]
# Current batch training loss: -0.908335  [1920000/2213439]
# Current batch training loss: -0.928421  [1945600/2213439]
# Current batch training loss: -0.930151  [1971200/2213439]
# Current batch training loss: -0.920873  [1996800/2213439]
# Current batch training loss: -0.907222  [2022400/2213439]
# Current batch training loss: -0.900362  [2048000/2213439]
# Current batch training loss: -0.910986  [2073600/2213439]
# Current batch training loss: -0.927116  [2099200/2213439]
# Current batch training loss: -0.933056  [2124800/2213439]
# Current batch training loss: -0.926255  [2150400/2213439]
# Current batch training loss: -0.905149  [2176000/2213439]
# Current batch training loss: -0.914573  [2201600/2213439]
# Training loss: -0.903071
# Validation loss: -0.911504
#
# Epoch 3
# -------------------------------
# Current batch training loss: -0.899254  [    0/2213439]
# Current batch training loss: -0.913796  [25600/2213439]
# Current batch training loss: -0.904298  [51200/2213439]
# Current batch training loss: -0.934310  [76800/2213439]
# Current batch training loss: -0.915816  [102400/2213439]
# Current batch training loss: -0.920097  [128000/2213439]
# Current batch training loss: -0.911181  [153600/2213439]
# Current batch training loss: -0.926074  [179200/2213439]
# Current batch training loss: -0.921601  [204800/2213439]
# Current batch training loss: -0.911465  [230400/2213439]
# Current batch training loss: -0.923076  [256000/2213439]
# Current batch training loss: -0.876084  [281600/2213439]
# Current batch training loss: -0.901522  [307200/2213439]
# Current batch training loss: -0.907808  [332800/2213439]
# Current batch training loss: -0.938889  [358400/2213439]
# Current batch training loss: -0.899194  [384000/2213439]
# Current batch training loss: -0.924690  [409600/2213439]
# Current batch training loss: -0.900148  [435200/2213439]
# Current batch training loss: -0.886337  [460800/2213439]
# Current batch training loss: -0.915936  [486400/2213439]
# Current batch training loss: -0.909221  [512000/2213439]
# Current batch training loss: -0.909681  [537600/2213439]
# Current batch training loss: -0.911739  [563200/2213439]
# Current batch training loss: -0.922921  [588800/2213439]
# Current batch training loss: -0.924801  [614400/2213439]
# Current batch training loss: -0.899713  [640000/2213439]
# Current batch training loss: -0.922234  [665600/2213439]
# Current batch training loss: -0.928235  [691200/2213439]
# Current batch training loss: -0.916329  [716800/2213439]
# Current batch training loss: -0.896365  [742400/2213439]
# Current batch training loss: -0.904332  [768000/2213439]
# Current batch training loss: -0.886217  [793600/2213439]
# Current batch training loss: -0.901499  [819200/2213439]
# Current batch training loss: -0.925205  [844800/2213439]
# Current batch training loss: -0.942205  [870400/2213439]
# Current batch training loss: -0.910810  [896000/2213439]
# Current batch training loss: -0.919278  [921600/2213439]
# Current batch training loss: -0.925419  [947200/2213439]
# Current batch training loss: -0.915656  [972800/2213439]
# Current batch training loss: -0.923560  [998400/2213439]
# Current batch training loss: -0.917361  [1024000/2213439]
# Current batch training loss: -0.902959  [1049600/2213439]
# Current batch training loss: -0.928390  [1075200/2213439]
# Current batch training loss: -0.931574  [1100800/2213439]
# Current batch training loss: -0.931682  [1126400/2213439]
# Current batch training loss: -0.907155  [1152000/2213439]
# Current batch training loss: -0.915535  [1177600/2213439]
# Current batch training loss: -0.917090  [1203200/2213439]
# Current batch training loss: -0.916022  [1228800/2213439]
# Current batch training loss: -0.933133  [1254400/2213439]
# Current batch training loss: -0.918560  [1280000/2213439]
# Current batch training loss: -0.920138  [1305600/2213439]
# Current batch training loss: -0.908770  [1331200/2213439]
# Current batch training loss: -0.910930  [1356800/2213439]
# Current batch training loss: -0.906822  [1382400/2213439]
# Current batch training loss: -0.906927  [1408000/2213439]
# Current batch training loss: -0.941806  [1433600/2213439]
# Current batch training loss: -0.930427  [1459200/2213439]
# Current batch training loss: -0.940688  [1484800/2213439]
# Current batch training loss: -0.928918  [1510400/2213439]
# Current batch training loss: -0.908753  [1536000/2213439]
# Current batch training loss: -0.904358  [1561600/2213439]
# Current batch training loss: -0.935387  [1587200/2213439]
# Current batch training loss: -0.914092  [1612800/2213439]
# Current batch training loss: -0.925821  [1638400/2213439]
# Current batch training loss: -0.910005  [1664000/2213439]
# Current batch training loss: -0.932115  [1689600/2213439]
# Current batch training loss: -0.927277  [1715200/2213439]
# Current batch training loss: -0.920502  [1740800/2213439]
# Current batch training loss: -0.898728  [1766400/2213439]
# Current batch training loss: -0.921845  [1792000/2213439]
# Current batch training loss: -0.910685  [1817600/2213439]
# Current batch training loss: -0.912371  [1843200/2213439]
# Current batch training loss: -0.928817  [1868800/2213439]
# Current batch training loss: -0.918897  [1894400/2213439]
# Current batch training loss: -0.924120  [1920000/2213439]
# Current batch training loss: -0.912066  [1945600/2213439]
# Current batch training loss: -0.899334  [1971200/2213439]
# Current batch training loss: -0.931215  [1996800/2213439]
# Current batch training loss: -0.916628  [2022400/2213439]
# Current batch training loss: -0.909171  [2048000/2213439]
# Current batch training loss: -0.918142  [2073600/2213439]
# Current batch training loss: -0.907908  [2099200/2213439]
# Current batch training loss: -0.923208  [2124800/2213439]
# Current batch training loss: -0.914335  [2150400/2213439]
# Current batch training loss: -0.909311  [2176000/2213439]
# Current batch training loss: -0.917549  [2201600/2213439]
# Training loss: -0.916128
# Validation loss: -0.917192
#
# Epoch 4
# -------------------------------
# Current batch training loss: -0.907762  [    0/2213439]
# Current batch training loss: -0.891315  [25600/2213439]
# Current batch training loss: -0.922826  [51200/2213439]
# Current batch training loss: -0.927850  [76800/2213439]
# Current batch training loss: -0.941543  [102400/2213439]
# Current batch training loss: -0.910191  [128000/2213439]
# Current batch training loss: -0.898391  [153600/2213439]
# Current batch training loss: -0.919025  [179200/2213439]
# Current batch training loss: -0.925123  [204800/2213439]
# Current batch training loss: -0.915651  [230400/2213439]
# Current batch training loss: -0.929720  [256000/2213439]
# Current batch training loss: -0.922256  [281600/2213439]
# Current batch training loss: -0.909446  [307200/2213439]
# Current batch training loss: -0.933338  [332800/2213439]
# Current batch training loss: -0.912629  [358400/2213439]
# Current batch training loss: -0.928075  [384000/2213439]
# Current batch training loss: -0.916083  [409600/2213439]
# Current batch training loss: -0.907607  [435200/2213439]
# Current batch training loss: -0.928689  [460800/2213439]
# Current batch training loss: -0.914932  [486400/2213439]
# Current batch training loss: -0.907141  [512000/2213439]
# Current batch training loss: -0.928105  [537600/2213439]
# Current batch training loss: -0.941673  [563200/2213439]
# Current batch training loss: -0.929270  [588800/2213439]
# Current batch training loss: -0.920861  [614400/2213439]
# Current batch training loss: -0.908720  [640000/2213439]
# Current batch training loss: -0.929496  [665600/2213439]
# Current batch training loss: -0.913075  [691200/2213439]
# Current batch training loss: -0.924008  [716800/2213439]
# Current batch training loss: -0.920842  [742400/2213439]
# Current batch training loss: -0.919056  [768000/2213439]
# Current batch training loss: -0.937117  [793600/2213439]
# Current batch training loss: -0.916820  [819200/2213439]
# Current batch training loss: -0.919756  [844800/2213439]
# Current batch training loss: -0.933504  [870400/2213439]
# Current batch training loss: -0.891381  [896000/2213439]
# Current batch training loss: -0.918952  [921600/2213439]
# Current batch training loss: -0.937068  [947200/2213439]
# Current batch training loss: -0.909339  [972800/2213439]
# Current batch training loss: -0.922251  [998400/2213439]
# Current batch training loss: -0.921045  [1024000/2213439]
# Current batch training loss: -0.939981  [1049600/2213439]
# Current batch training loss: -0.910704  [1075200/2213439]
# Current batch training loss: -0.931117  [1100800/2213439]
# Current batch training loss: -0.913270  [1126400/2213439]
# Current batch training loss: -0.913465  [1152000/2213439]
# Current batch training loss: -0.901489  [1177600/2213439]
# Current batch training loss: -0.917571  [1203200/2213439]
# Current batch training loss: -0.900191  [1228800/2213439]
# Current batch training loss: -0.933923  [1254400/2213439]
# Current batch training loss: -0.923555  [1280000/2213439]
# Current batch training loss: -0.911666  [1305600/2213439]
# Current batch training loss: -0.939828  [1331200/2213439]
# Current batch training loss: -0.927723  [1356800/2213439]
# Current batch training loss: -0.909864  [1382400/2213439]
# Current batch training loss: -0.920314  [1408000/2213439]
# Current batch training loss: -0.913806  [1433600/2213439]
# Current batch training loss: -0.913744  [1459200/2213439]
# Current batch training loss: -0.916690  [1484800/2213439]
# Current batch training loss: -0.917101  [1510400/2213439]
# Current batch training loss: -0.930840  [1536000/2213439]
# Current batch training loss: -0.924620  [1561600/2213439]
# Current batch training loss: -0.947294  [1587200/2213439]
# Current batch training loss: -0.928841  [1612800/2213439]
# Current batch training loss: -0.926254  [1638400/2213439]
# Current batch training loss: -0.916197  [1664000/2213439]
# Current batch training loss: -0.919955  [1689600/2213439]
# Current batch training loss: -0.913106  [1715200/2213439]
# Current batch training loss: -0.932582  [1740800/2213439]
# Current batch training loss: -0.938647  [1766400/2213439]
# Current batch training loss: -0.935271  [1792000/2213439]
# Current batch training loss: -0.915708  [1817600/2213439]
# Current batch training loss: -0.921234  [1843200/2213439]
# Current batch training loss: -0.929328  [1868800/2213439]
# Current batch training loss: -0.910732  [1894400/2213439]
# Current batch training loss: -0.908520  [1920000/2213439]
# Current batch training loss: -0.936080  [1945600/2213439]
# Current batch training loss: -0.929107  [1971200/2213439]
# Current batch training loss: -0.926703  [1996800/2213439]
# Current batch training loss: -0.897001  [2022400/2213439]
# Current batch training loss: -0.904222  [2048000/2213439]
# Current batch training loss: -0.913779  [2073600/2213439]
# Current batch training loss: -0.916277  [2099200/2213439]
# Current batch training loss: -0.925677  [2124800/2213439]
# Current batch training loss: -0.917857  [2150400/2213439]
# Current batch training loss: -0.924557  [2176000/2213439]
# Current batch training loss: -0.908968  [2201600/2213439]
# Training loss: -0.920082
# Validation loss: -0.918731
#
# Epoch 5
# -------------------------------
# Current batch training loss: -0.937165  [    0/2213439]
# Current batch training loss: -0.926908  [25600/2213439]
# Current batch training loss: -0.909689  [51200/2213439]
# Current batch training loss: -0.915872  [76800/2213439]
# Current batch training loss: -0.932700  [102400/2213439]
# Current batch training loss: -0.916896  [128000/2213439]
# Current batch training loss: -0.936193  [153600/2213439]
# Current batch training loss: -0.891230  [179200/2213439]
# Current batch training loss: -0.921460  [204800/2213439]
# Current batch training loss: -0.928137  [230400/2213439]
# Current batch training loss: -0.918428  [256000/2213439]
# Current batch training loss: -0.898986  [281600/2213439]
# Current batch training loss: -0.918072  [307200/2213439]
# Current batch training loss: -0.929105  [332800/2213439]
# Current batch training loss: -0.921232  [358400/2213439]
# Current batch training loss: -0.932660  [384000/2213439]
# Current batch training loss: -0.929522  [409600/2213439]
# Current batch training loss: -0.912938  [435200/2213439]
# Current batch training loss: -0.925768  [460800/2213439]
# Current batch training loss: -0.916888  [486400/2213439]
# Current batch training loss: -0.918756  [512000/2213439]
# Current batch training loss: -0.925937  [537600/2213439]
# Current batch training loss: -0.925832  [563200/2213439]
# Current batch training loss: -0.937834  [588800/2213439]
# Current batch training loss: -0.924153  [614400/2213439]
# Current batch training loss: -0.924248  [640000/2213439]
# Current batch training loss: -0.915134  [665600/2213439]
# Current batch training loss: -0.923059  [691200/2213439]
# Current batch training loss: -0.919103  [716800/2213439]
# Current batch training loss: -0.934352  [742400/2213439]
# Current batch training loss: -0.921111  [768000/2213439]
# Current batch training loss: -0.913493  [793600/2213439]
# Current batch training loss: -0.928849  [819200/2213439]
# Current batch training loss: -0.918145  [844800/2213439]
# Current batch training loss: -0.945004  [870400/2213439]
# Current batch training loss: -0.928163  [896000/2213439]
# Current batch training loss: -0.907159  [921600/2213439]
# Current batch training loss: -0.929009  [947200/2213439]
# Current batch training loss: -0.920364  [972800/2213439]
# Current batch training loss: -0.920446  [998400/2213439]
# Current batch training loss: -0.935145  [1024000/2213439]
# Current batch training loss: -0.921232  [1049600/2213439]
# Current batch training loss: -0.915478  [1075200/2213439]
# Current batch training loss: -0.935930  [1100800/2213439]
# Current batch training loss: -0.899553  [1126400/2213439]
# Current batch training loss: -0.909331  [1152000/2213439]
# Current batch training loss: -0.923414  [1177600/2213439]
# Current batch training loss: -0.921539  [1203200/2213439]
# Current batch training loss: -0.910173  [1228800/2213439]
# Current batch training loss: -0.917044  [1254400/2213439]
# Current batch training loss: -0.918873  [1280000/2213439]
# Current batch training loss: -0.911476  [1305600/2213439]
# Current batch training loss: -0.917039  [1331200/2213439]
# Current batch training loss: -0.922090  [1356800/2213439]
# Current batch training loss: -0.932133  [1382400/2213439]
# Current batch training loss: -0.917592  [1408000/2213439]
# Current batch training loss: -0.925524  [1433600/2213439]
# Current batch training loss: -0.937067  [1459200/2213439]
# Current batch training loss: -0.912982  [1484800/2213439]
# Current batch training loss: -0.914760  [1510400/2213439]
# Current batch training loss: -0.920321  [1536000/2213439]
# Current batch training loss: -0.932531  [1561600/2213439]
# Current batch training loss: -0.928473  [1587200/2213439]
# Current batch training loss: -0.929541  [1612800/2213439]
# Current batch training loss: -0.935893  [1638400/2213439]
# Current batch training loss: -0.924855  [1664000/2213439]
# Current batch training loss: -0.923193  [1689600/2213439]
# Current batch training loss: -0.934667  [1715200/2213439]
# Current batch training loss: -0.921117  [1740800/2213439]
# Current batch training loss: -0.932782  [1766400/2213439]
# Current batch training loss: -0.930411  [1792000/2213439]
# Current batch training loss: -0.930882  [1817600/2213439]
# Current batch training loss: -0.920547  [1843200/2213439]
# Current batch training loss: -0.907467  [1868800/2213439]
# Current batch training loss: -0.929516  [1894400/2213439]
# Current batch training loss: -0.922567  [1920000/2213439]
# Current batch training loss: -0.930857  [1945600/2213439]
# Current batch training loss: -0.928907  [1971200/2213439]
# Current batch training loss: -0.921750  [1996800/2213439]
# Current batch training loss: -0.926130  [2022400/2213439]
# Current batch training loss: -0.930542  [2048000/2213439]
# Current batch training loss: -0.930946  [2073600/2213439]
# Current batch training loss: -0.940275  [2099200/2213439]
# Current batch training loss: -0.915673  [2124800/2213439]
# Current batch training loss: -0.923344  [2150400/2213439]
# Current batch training loss: -0.927004  [2176000/2213439]
# Current batch training loss: -0.921615  [2201600/2213439]
# Training loss: -0.922450
# Validation loss: -0.918907
#
# Epoch 6
# -------------------------------
# Current batch training loss: -0.935848  [    0/2213439]
# Current batch training loss: -0.933500  [25600/2213439]
# Current batch training loss: -0.926475  [51200/2213439]
# Current batch training loss: -0.909437  [76800/2213439]
# Current batch training loss: -0.911692  [102400/2213439]
# Current batch training loss: -0.935745  [128000/2213439]
# Current batch training loss: -0.931442  [153600/2213439]
# Current batch training loss: -0.910623  [179200/2213439]
# Current batch training loss: -0.906712  [204800/2213439]
# Current batch training loss: -0.921219  [230400/2213439]
# Current batch training loss: -0.943356  [256000/2213439]
# Current batch training loss: -0.918274  [281600/2213439]
# Current batch training loss: -0.920730  [307200/2213439]
# Current batch training loss: -0.921864  [332800/2213439]
# Current batch training loss: -0.917224  [358400/2213439]
# Current batch training loss: -0.930638  [384000/2213439]
# Current batch training loss: -0.935519  [409600/2213439]
# Current batch training loss: -0.912141  [435200/2213439]
# Current batch training loss: -0.928164  [460800/2213439]
# Current batch training loss: -0.915264  [486400/2213439]
# Current batch training loss: -0.921585  [512000/2213439]
# Current batch training loss: -0.929188  [537600/2213439]
# Current batch training loss: -0.932116  [563200/2213439]
# Current batch training loss: -0.917391  [588800/2213439]
# Current batch training loss: -0.934062  [614400/2213439]
# Current batch training loss: -0.922043  [640000/2213439]
# Current batch training loss: -0.919572  [665600/2213439]
# Current batch training loss: -0.907643  [691200/2213439]
# Current batch training loss: -0.921310  [716800/2213439]
# Current batch training loss: -0.923896  [742400/2213439]
# Current batch training loss: -0.930990  [768000/2213439]
# Current batch training loss: -0.927185  [793600/2213439]
# Current batch training loss: -0.932739  [819200/2213439]
# Current batch training loss: -0.915119  [844800/2213439]
# Current batch training loss: -0.913861  [870400/2213439]
# Current batch training loss: -0.914276  [896000/2213439]
# Current batch training loss: -0.906134  [921600/2213439]
# Current batch training loss: -0.918534  [947200/2213439]
# Current batch training loss: -0.927486  [972800/2213439]
# Current batch training loss: -0.939450  [998400/2213439]
# Current batch training loss: -0.937881  [1024000/2213439]
# Current batch training loss: -0.940313  [1049600/2213439]
# Current batch training loss: -0.933691  [1075200/2213439]
# Current batch training loss: -0.935770  [1100800/2213439]
# Current batch training loss: -0.915108  [1126400/2213439]
# Current batch training loss: -0.932683  [1152000/2213439]
# Current batch training loss: -0.912226  [1177600/2213439]
# Current batch training loss: -0.924859  [1203200/2213439]
# Current batch training loss: -0.907661  [1228800/2213439]
# Current batch training loss: -0.924507  [1254400/2213439]
# Current batch training loss: -0.918782  [1280000/2213439]
# Current batch training loss: -0.914756  [1305600/2213439]
# Current batch training loss: -0.919235  [1331200/2213439]
# Current batch training loss: -0.915845  [1356800/2213439]
# Current batch training loss: -0.921066  [1382400/2213439]
# Current batch training loss: -0.927305  [1408000/2213439]
# Current batch training loss: -0.916268  [1433600/2213439]
# Current batch training loss: -0.914292  [1459200/2213439]
# Current batch training loss: -0.925822  [1484800/2213439]
# Current batch training loss: -0.922310  [1510400/2213439]
# Current batch training loss: -0.915951  [1536000/2213439]
# Current batch training loss: -0.929290  [1561600/2213439]
# Current batch training loss: -0.928988  [1587200/2213439]
# Current batch training loss: -0.928504  [1612800/2213439]
# Current batch training loss: -0.928895  [1638400/2213439]
# Current batch training loss: -0.942301  [1664000/2213439]
# Current batch training loss: -0.931346  [1689600/2213439]
# Current batch training loss: -0.939117  [1715200/2213439]
# Current batch training loss: -0.942774  [1740800/2213439]
# Current batch training loss: -0.926929  [1766400/2213439]
# Current batch training loss: -0.918391  [1792000/2213439]
# Current batch training loss: -0.915578  [1817600/2213439]
# Current batch training loss: -0.932099  [1843200/2213439]
# Current batch training loss: -0.925075  [1868800/2213439]
# Current batch training loss: -0.916257  [1894400/2213439]
# Current batch training loss: -0.933367  [1920000/2213439]
# Current batch training loss: -0.914404  [1945600/2213439]
# Current batch training loss: -0.921803  [1971200/2213439]
# Current batch training loss: -0.934117  [1996800/2213439]
# Current batch training loss: -0.939660  [2022400/2213439]
# Current batch training loss: -0.921613  [2048000/2213439]
# Current batch training loss: -0.929134  [2073600/2213439]
# Current batch training loss: -0.906798  [2099200/2213439]
# Current batch training loss: -0.917843  [2124800/2213439]
# Current batch training loss: -0.886758  [2150400/2213439]
# Current batch training loss: -0.929768  [2176000/2213439]
# Current batch training loss: -0.920011  [2201600/2213439]
# Training loss: -0.924180
# Validation loss: -0.920317
#
# Epoch 7
# -------------------------------
# Current batch training loss: -0.927113  [    0/2213439]
# Current batch training loss: -0.941534  [25600/2213439]
# Current batch training loss: -0.925907  [51200/2213439]
# Current batch training loss: -0.919368  [76800/2213439]
# Current batch training loss: -0.929419  [102400/2213439]
# Current batch training loss: -0.937491  [128000/2213439]
# Current batch training loss: -0.931963  [153600/2213439]
# Current batch training loss: -0.931892  [179200/2213439]
# Current batch training loss: -0.925195  [204800/2213439]
# Current batch training loss: -0.918758  [230400/2213439]
# Current batch training loss: -0.922987  [256000/2213439]
# Current batch training loss: -0.929053  [281600/2213439]
# Current batch training loss: -0.917709  [307200/2213439]
# Current batch training loss: -0.917645  [332800/2213439]
# Current batch training loss: -0.934402  [358400/2213439]
# Current batch training loss: -0.932234  [384000/2213439]
# Current batch training loss: -0.935685  [409600/2213439]
# Current batch training loss: -0.926582  [435200/2213439]
# Current batch training loss: -0.941335  [460800/2213439]
# Current batch training loss: -0.930546  [486400/2213439]
# Current batch training loss: -0.904078  [512000/2213439]
# Current batch training loss: -0.944343  [537600/2213439]
# Current batch training loss: -0.924425  [563200/2213439]
# Current batch training loss: -0.943741  [588800/2213439]
# Current batch training loss: -0.933664  [614400/2213439]
# Current batch training loss: -0.929587  [640000/2213439]
# Current batch training loss: -0.936507  [665600/2213439]
# Current batch training loss: -0.924538  [691200/2213439]
# Current batch training loss: -0.936924  [716800/2213439]
# Current batch training loss: -0.905605  [742400/2213439]
# Current batch training loss: -0.924711  [768000/2213439]
# Current batch training loss: -0.944672  [793600/2213439]
# Current batch training loss: -0.918519  [819200/2213439]
# Current batch training loss: -0.920595  [844800/2213439]
# Current batch training loss: -0.923637  [870400/2213439]
# Current batch training loss: -0.920624  [896000/2213439]
# Current batch training loss: -0.921437  [921600/2213439]
# Current batch training loss: -0.930335  [947200/2213439]
# Current batch training loss: -0.929837  [972800/2213439]
# Current batch training loss: -0.943650  [998400/2213439]
# Current batch training loss: -0.924916  [1024000/2213439]
# Current batch training loss: -0.945731  [1049600/2213439]
# Current batch training loss: -0.935454  [1075200/2213439]
# Current batch training loss: -0.925956  [1100800/2213439]
# Current batch training loss: -0.930836  [1126400/2213439]
# Current batch training loss: -0.929032  [1152000/2213439]
# Current batch training loss: -0.915654  [1177600/2213439]
# Current batch training loss: -0.936187  [1203200/2213439]
# Current batch training loss: -0.940305  [1228800/2213439]
# Current batch training loss: -0.929024  [1254400/2213439]
# Current batch training loss: -0.938807  [1280000/2213439]
# Current batch training loss: -0.923254  [1305600/2213439]
# Current batch training loss: -0.915630  [1331200/2213439]
# Current batch training loss: -0.923092  [1356800/2213439]
# Current batch training loss: -0.946526  [1382400/2213439]
# Current batch training loss: -0.930757  [1408000/2213439]
# Current batch training loss: -0.938318  [1433600/2213439]
# Current batch training loss: -0.926316  [1459200/2213439]
# Current batch training loss: -0.935387  [1484800/2213439]
# Current batch training loss: -0.921151  [1510400/2213439]
# Current batch training loss: -0.936213  [1536000/2213439]
# Current batch training loss: -0.928163  [1561600/2213439]
# Current batch training loss: -0.932508  [1587200/2213439]
# Current batch training loss: -0.925524  [1612800/2213439]
# Current batch training loss: -0.920954  [1638400/2213439]
# Current batch training loss: -0.926492  [1664000/2213439]
# Current batch training loss: -0.902961  [1689600/2213439]
# Current batch training loss: -0.922028  [1715200/2213439]
# Current batch training loss: -0.934237  [1740800/2213439]
# Current batch training loss: -0.928549  [1766400/2213439]
# Current batch training loss: -0.921841  [1792000/2213439]
# Current batch training loss: -0.938504  [1817600/2213439]
# Current batch training loss: -0.931560  [1843200/2213439]
# Current batch training loss: -0.939004  [1868800/2213439]
# Current batch training loss: -0.925464  [1894400/2213439]
# Current batch training loss: -0.926083  [1920000/2213439]
# Current batch training loss: -0.943253  [1945600/2213439]
# Current batch training loss: -0.913812  [1971200/2213439]
# Current batch training loss: -0.927750  [1996800/2213439]
# Current batch training loss: -0.920617  [2022400/2213439]
# Current batch training loss: -0.931295  [2048000/2213439]
# Current batch training loss: -0.938673  [2073600/2213439]
# Current batch training loss: -0.918157  [2099200/2213439]
# Current batch training loss: -0.931332  [2124800/2213439]
# Current batch training loss: -0.920347  [2150400/2213439]
# Current batch training loss: -0.926841  [2176000/2213439]
# Current batch training loss: -0.925889  [2201600/2213439]
# Training loss: -0.925651
# Validation loss: -0.920722
#
# Epoch 8
# -------------------------------
# Current batch training loss: -0.928712  [    0/2213439]
# Current batch training loss: -0.935662  [25600/2213439]
# Current batch training loss: -0.929015  [51200/2213439]
# Current batch training loss: -0.937092  [76800/2213439]
# Current batch training loss: -0.923857  [102400/2213439]
# Current batch training loss: -0.909137  [128000/2213439]
# Current batch training loss: -0.944784  [153600/2213439]
# Current batch training loss: -0.920042  [179200/2213439]
# Current batch training loss: -0.933933  [204800/2213439]
# Current batch training loss: -0.937865  [230400/2213439]
# Current batch training loss: -0.924809  [256000/2213439]
# Current batch training loss: -0.925835  [281600/2213439]
# Current batch training loss: -0.928750  [307200/2213439]
# Current batch training loss: -0.942647  [332800/2213439]
# Current batch training loss: -0.925313  [358400/2213439]
# Current batch training loss: -0.937899  [384000/2213439]
# Current batch training loss: -0.928951  [409600/2213439]
# Current batch training loss: -0.929119  [435200/2213439]
# Current batch training loss: -0.922382  [460800/2213439]
# Current batch training loss: -0.928240  [486400/2213439]
# Current batch training loss: -0.905493  [512000/2213439]
# Current batch training loss: -0.925909  [537600/2213439]
# Current batch training loss: -0.932562  [563200/2213439]
# Current batch training loss: -0.940529  [588800/2213439]
# Current batch training loss: -0.927269  [614400/2213439]
# Current batch training loss: -0.928709  [640000/2213439]
# Current batch training loss: -0.928975  [665600/2213439]
# Current batch training loss: -0.930416  [691200/2213439]
# Current batch training loss: -0.936298  [716800/2213439]
# Current batch training loss: -0.933390  [742400/2213439]
# Current batch training loss: -0.929133  [768000/2213439]
# Current batch training loss: -0.938071  [793600/2213439]
# Current batch training loss: -0.930237  [819200/2213439]
# Current batch training loss: -0.928909  [844800/2213439]
# Current batch training loss: -0.930536  [870400/2213439]
# Current batch training loss: -0.904248  [896000/2213439]
# Current batch training loss: -0.931074  [921600/2213439]
# Current batch training loss: -0.919359  [947200/2213439]
# Current batch training loss: -0.929137  [972800/2213439]
# Current batch training loss: -0.913023  [998400/2213439]
# Current batch training loss: -0.925294  [1024000/2213439]
# Current batch training loss: -0.915295  [1049600/2213439]
# Current batch training loss: -0.902531  [1075200/2213439]
# Current batch training loss: -0.919169  [1100800/2213439]
# Current batch training loss: -0.922854  [1126400/2213439]
# Current batch training loss: -0.924191  [1152000/2213439]
# Current batch training loss: -0.935331  [1177600/2213439]
# Current batch training loss: -0.912926  [1203200/2213439]
# Current batch training loss: -0.906578  [1228800/2213439]
# Current batch training loss: -0.929351  [1254400/2213439]
# Current batch training loss: -0.927440  [1280000/2213439]
# Current batch training loss: -0.936863  [1305600/2213439]
# Current batch training loss: -0.925726  [1331200/2213439]
# Current batch training loss: -0.927842  [1356800/2213439]
# Current batch training loss: -0.914603  [1382400/2213439]
# Current batch training loss: -0.929914  [1408000/2213439]
# Current batch training loss: -0.936531  [1433600/2213439]
# Current batch training loss: -0.938173  [1459200/2213439]
# Current batch training loss: -0.925228  [1484800/2213439]
# Current batch training loss: -0.938809  [1510400/2213439]
# Current batch training loss: -0.922810  [1536000/2213439]
# Current batch training loss: -0.939188  [1561600/2213439]
# Current batch training loss: -0.923445  [1587200/2213439]
# Current batch training loss: -0.898221  [1612800/2213439]
# Current batch training loss: -0.936052  [1638400/2213439]
# Current batch training loss: -0.944845  [1664000/2213439]
# Current batch training loss: -0.929509  [1689600/2213439]
# Current batch training loss: -0.934218  [1715200/2213439]
# Current batch training loss: -0.939674  [1740800/2213439]
# Current batch training loss: -0.925199  [1766400/2213439]
# Current batch training loss: -0.916187  [1792000/2213439]
# Current batch training loss: -0.934012  [1817600/2213439]
# Current batch training loss: -0.929367  [1843200/2213439]
# Current batch training loss: -0.931687  [1868800/2213439]
# Current batch training loss: -0.920420  [1894400/2213439]
# Current batch training loss: -0.936776  [1920000/2213439]
# Current batch training loss: -0.915356  [1945600/2213439]
# Current batch training loss: -0.906827  [1971200/2213439]
# Current batch training loss: -0.935982  [1996800/2213439]
# Current batch training loss: -0.941869  [2022400/2213439]
# Current batch training loss: -0.928766  [2048000/2213439]
# Current batch training loss: -0.930376  [2073600/2213439]
# Current batch training loss: -0.911367  [2099200/2213439]
# Current batch training loss: -0.929809  [2124800/2213439]
# Current batch training loss: -0.914184  [2150400/2213439]
# Current batch training loss: -0.933098  [2176000/2213439]
# Current batch training loss: -0.921258  [2201600/2213439]
# Training loss: -0.926996
# Validation loss: -0.921307
#
# Epoch 9
# -------------------------------
# Current batch training loss: -0.942190  [    0/2213439]
# Current batch training loss: -0.926555  [25600/2213439]
# Current batch training loss: -0.925972  [51200/2213439]
# Current batch training loss: -0.929570  [76800/2213439]
# Current batch training loss: -0.923003  [102400/2213439]
# Current batch training loss: -0.918165  [128000/2213439]
# Current batch training loss: -0.917471  [153600/2213439]
# Current batch training loss: -0.933178  [179200/2213439]
# Current batch training loss: -0.938127  [204800/2213439]
# Current batch training loss: -0.927623  [230400/2213439]
# Current batch training loss: -0.928369  [256000/2213439]
# Current batch training loss: -0.919114  [281600/2213439]
# Current batch training loss: -0.923033  [307200/2213439]
# Current batch training loss: -0.937192  [332800/2213439]
# Current batch training loss: -0.918277  [358400/2213439]
# Current batch training loss: -0.918404  [384000/2213439]
# Current batch training loss: -0.922562  [409600/2213439]
# Current batch training loss: -0.898074  [435200/2213439]
# Current batch training loss: -0.924297  [460800/2213439]
# Current batch training loss: -0.923655  [486400/2213439]
# Current batch training loss: -0.923240  [512000/2213439]
# Current batch training loss: -0.933428  [537600/2213439]
# Current batch training loss: -0.938552  [563200/2213439]
# Current batch training loss: -0.931289  [588800/2213439]
# Current batch training loss: -0.936788  [614400/2213439]
# Current batch training loss: -0.925166  [640000/2213439]
# Current batch training loss: -0.936218  [665600/2213439]
# Current batch training loss: -0.932938  [691200/2213439]
# Current batch training loss: -0.945313  [716800/2213439]
# Current batch training loss: -0.919243  [742400/2213439]
# Current batch training loss: -0.933227  [768000/2213439]
# Current batch training loss: -0.934117  [793600/2213439]
# Current batch training loss: -0.941515  [819200/2213439]
# Current batch training loss: -0.934767  [844800/2213439]
# Current batch training loss: -0.933200  [870400/2213439]
# Current batch training loss: -0.917005  [896000/2213439]
# Current batch training loss: -0.942399  [921600/2213439]
# Current batch training loss: -0.931445  [947200/2213439]
# Current batch training loss: -0.931412  [972800/2213439]
# Current batch training loss: -0.913669  [998400/2213439]
# Current batch training loss: -0.923741  [1024000/2213439]
# Current batch training loss: -0.915775  [1049600/2213439]
# Current batch training loss: -0.933765  [1075200/2213439]
# Current batch training loss: -0.902579  [1100800/2213439]
# Current batch training loss: -0.935951  [1126400/2213439]
# Current batch training loss: -0.916465  [1152000/2213439]
# Current batch training loss: -0.929988  [1177600/2213439]
# Current batch training loss: -0.934916  [1203200/2213439]
# Current batch training loss: -0.937427  [1228800/2213439]
# Current batch training loss: -0.925013  [1254400/2213439]
# Current batch training loss: -0.919717  [1280000/2213439]
# Current batch training loss: -0.932301  [1305600/2213439]
# Current batch training loss: -0.939765  [1331200/2213439]
# Current batch training loss: -0.940911  [1356800/2213439]
# Current batch training loss: -0.915113  [1382400/2213439]
# Current batch training loss: -0.914780  [1408000/2213439]
# Current batch training loss: -0.917423  [1433600/2213439]
# Current batch training loss: -0.936322  [1459200/2213439]
# Current batch training loss: -0.950682  [1484800/2213439]
# Current batch training loss: -0.927015  [1510400/2213439]
# Current batch training loss: -0.909693  [1536000/2213439]
# Current batch training loss: -0.918105  [1561600/2213439]
# Current batch training loss: -0.896956  [1587200/2213439]
# Current batch training loss: -0.924220  [1612800/2213439]
# Current batch training loss: -0.927660  [1638400/2213439]
# Current batch training loss: -0.912100  [1664000/2213439]
# Current batch training loss: -0.920506  [1689600/2213439]
# Current batch training loss: -0.927351  [1715200/2213439]
# Current batch training loss: -0.912419  [1740800/2213439]
# Current batch training loss: -0.926553  [1766400/2213439]
# Current batch training loss: -0.913725  [1792000/2213439]
# Current batch training loss: -0.930977  [1817600/2213439]
# Current batch training loss: -0.919967  [1843200/2213439]
# Current batch training loss: -0.941033  [1868800/2213439]
# Current batch training loss: -0.922347  [1894400/2213439]
# Current batch training loss: -0.929543  [1920000/2213439]
# Current batch training loss: -0.909524  [1945600/2213439]
# Current batch training loss: -0.931445  [1971200/2213439]
# Current batch training loss: -0.936343  [1996800/2213439]
# Current batch training loss: -0.935902  [2022400/2213439]
# Current batch training loss: -0.910305  [2048000/2213439]
# Current batch training loss: -0.932871  [2073600/2213439]
# Current batch training loss: -0.911042  [2099200/2213439]
# Current batch training loss: -0.922413  [2124800/2213439]
# Current batch training loss: -0.936487  [2150400/2213439]
# Current batch training loss: -0.919015  [2176000/2213439]
# Current batch training loss: -0.923268  [2201600/2213439]
# Training loss: -0.928240
# Validation loss: -0.921480
#
# Epoch 10
# -------------------------------
# Current batch training loss: -0.921854  [    0/2213439]
# Current batch training loss: -0.932248  [25600/2213439]
# Current batch training loss: -0.940962  [51200/2213439]
# Current batch training loss: -0.940417  [76800/2213439]
# Current batch training loss: -0.939128  [102400/2213439]
# Current batch training loss: -0.935806  [128000/2213439]
# Current batch training loss: -0.940107  [153600/2213439]
# Current batch training loss: -0.932954  [179200/2213439]
# Current batch training loss: -0.930883  [204800/2213439]
# Current batch training loss: -0.930219  [230400/2213439]
# Current batch training loss: -0.930771  [256000/2213439]
# Current batch training loss: -0.927221  [281600/2213439]
# Current batch training loss: -0.936788  [307200/2213439]
# Current batch training loss: -0.925712  [332800/2213439]
# Current batch training loss: -0.924032  [358400/2213439]
# Current batch training loss: -0.926069  [384000/2213439]
# Current batch training loss: -0.933254  [409600/2213439]
# Current batch training loss: -0.923412  [435200/2213439]
# Current batch training loss: -0.937717  [460800/2213439]
# Current batch training loss: -0.935546  [486400/2213439]
# Current batch training loss: -0.939961  [512000/2213439]
# Current batch training loss: -0.945020  [537600/2213439]
# Current batch training loss: -0.928092  [563200/2213439]
# Current batch training loss: -0.920645  [588800/2213439]
# Current batch training loss: -0.909362  [614400/2213439]
# Current batch training loss: -0.938285  [640000/2213439]
# Current batch training loss: -0.932769  [665600/2213439]
# Current batch training loss: -0.932815  [691200/2213439]
# Current batch training loss: -0.931169  [716800/2213439]
# Current batch training loss: -0.911871  [742400/2213439]
# Current batch training loss: -0.935467  [768000/2213439]
# Current batch training loss: -0.925926  [793600/2213439]
# Current batch training loss: -0.923694  [819200/2213439]
# Current batch training loss: -0.919805  [844800/2213439]
# Current batch training loss: -0.946557  [870400/2213439]
# Current batch training loss: -0.920759  [896000/2213439]
# ...
# Current batch training loss: -0.935811  [1971200/2213439]
# Current batch training loss: -0.940190  [1996800/2213439]
# Current batch training loss: -0.928321  [2022400/2213439]
# Current batch training loss: -0.948362  [2048000/2213439]
# Current batch training loss: -0.939172  [2073600/2213439]
# Current batch training loss: -0.930777  [2099200/2213439]
# Current batch training loss: -0.931242  [2124800/2213439]
# Current batch training loss: -0.934965  [2150400/2213439]
# Current batch training loss: -0.926359  [2176000/2213439]
# Current batch training loss: -0.939861  [2201600/2213439]
# Training loss: -0.932126
# Validation loss: -0.921093
#
# Epoch 14
# -------------------------------
# Current batch training loss: -0.920184  [    0/2213439]
# Current batch training loss: -0.921161  [25600/2213439]
# Current batch training loss: -0.920058  [51200/2213439]
# Current batch training loss: -0.937638  [76800/2213439]
# Current batch training loss: -0.943120  [102400/2213439]
# Current batch training loss: -0.942110  [128000/2213439]
# Current batch training loss: -0.931478  [153600/2213439]
# Current batch training loss: -0.930511  [179200/2213439]
# Current batch training loss: -0.928928  [204800/2213439]
# Current batch training loss: -0.937132  [230400/2213439]
# Current batch training loss: -0.938012  [256000/2213439]
# Current batch training loss: -0.907781  [281600/2213439]
# Current batch training loss: -0.935333  [307200/2213439]
# Current batch training loss: -0.944543  [332800/2213439]
# Current batch training loss: -0.934550  [358400/2213439]
# Current batch training loss: -0.935895  [384000/2213439]
# Current batch training loss: -0.943877  [409600/2213439]
# Current batch training loss: -0.932280  [435200/2213439]
# Current batch training loss: -0.933975  [460800/2213439]
# Current batch training loss: -0.935916  [486400/2213439]
# Current batch training loss: -0.932522  [512000/2213439]
# Current batch training loss: -0.917348  [537600/2213439]
# Current batch training loss: -0.941011  [563200/2213439]
# Current batch training loss: -0.931747  [588800/2213439]
# Current batch training loss: -0.931503  [614400/2213439]
# Current batch training loss: -0.938988  [640000/2213439]
# Current batch training loss: -0.943840  [665600/2213439]
# Current batch training loss: -0.938420  [691200/2213439]
# Current batch training loss: -0.942063  [716800/2213439]
# Current batch training loss: -0.938049  [742400/2213439]
# Current batch training loss: -0.939195  [768000/2213439]
# Current batch training loss: -0.937331  [793600/2213439]
# Current batch training loss: -0.932707  [819200/2213439]
# Current batch training loss: -0.939821  [844800/2213439]
# Current batch training loss: -0.936709  [870400/2213439]
# Current batch training loss: -0.937628  [896000/2213439]
# Current batch training loss: -0.941626  [921600/2213439]
# Current batch training loss: -0.936622  [947200/2213439]
# Current batch training loss: -0.916808  [972800/2213439]
# Current batch training loss: -0.937559  [998400/2213439]
# Current batch training loss: -0.930708  [1024000/2213439]
# Current batch training loss: -0.915539  [1049600/2213439]
# Current batch training loss: -0.941118  [1075200/2213439]
# Current batch training loss: -0.915423  [1100800/2213439]
# Current batch training loss: -0.930066  [1126400/2213439]
# Current batch training loss: -0.945358  [1152000/2213439]
# Current batch training loss: -0.935472  [1177600/2213439]
# Current batch training loss: -0.939632  [1203200/2213439]
# Current batch training loss: -0.938208  [1228800/2213439]
# Current batch training loss: -0.936102  [1254400/2213439]
# Current batch training loss: -0.921022  [1280000/2213439]
# Current batch training loss: -0.931468  [1305600/2213439]
# Current batch training loss: -0.938295  [1331200/2213439]
# Current batch training loss: -0.935281  [1356800/2213439]
# Current batch training loss: -0.920446  [1382400/2213439]
# Current batch training loss: -0.941443  [1408000/2213439]
# Current batch training loss: -0.942434  [1433600/2213439]
# Current batch training loss: -0.944703  [1459200/2213439]
# Current batch training loss: -0.943450  [1484800/2213439]
# Current batch training loss: -0.936412  [1510400/2213439]
# Current batch training loss: -0.928898  [1536000/2213439]
# Current batch training loss: -0.919327  [1561600/2213439]
# Current batch training loss: -0.929959  [1587200/2213439]
# Current batch training loss: -0.924711  [1612800/2213439]
# Current batch training loss: -0.931554  [1638400/2213439]
# Current batch training loss: -0.926179  [1664000/2213439]
# Current batch training loss: -0.930945  [1689600/2213439]
# Current batch training loss: -0.939314  [1715200/2213439]
# Current batch training loss: -0.953639  [1740800/2213439]
# Current batch training loss: -0.934471  [1766400/2213439]
# Current batch training loss: -0.925008  [1792000/2213439]
# Current batch training loss: -0.938059  [1817600/2213439]
# Current batch training loss: -0.920776  [1843200/2213439]
# Current batch training loss: -0.949149  [1868800/2213439]
# Current batch training loss: -0.919005  [1894400/2213439]
# Current batch training loss: -0.928027  [1920000/2213439]
# Current batch training loss: -0.926340  [1945600/2213439]
# Current batch training loss: -0.930624  [1971200/2213439]
# Current batch training loss: -0.927454  [1996800/2213439]
# Current batch training loss: -0.930113  [2022400/2213439]
# Current batch training loss: -0.935248  [2048000/2213439]
# Current batch training loss: -0.941377  [2073600/2213439]
# Current batch training loss: -0.924893  [2099200/2213439]
# Current batch training loss: -0.934853  [2124800/2213439]
# Current batch training loss: -0.936588  [2150400/2213439]
# Current batch training loss: -0.928391  [2176000/2213439]
# Current batch training loss: -0.939547  [2201600/2213439]
# Training loss: -0.933051
# Validation loss: -0.921024
#
# Epoch 15
# -------------------------------
# Current batch training loss: -0.921391  [    0/2213439]
# Current batch training loss: -0.938832  [25600/2213439]
# Current batch training loss: -0.937784  [51200/2213439]
# Current batch training loss: -0.937910  [76800/2213439]
# Current batch training loss: -0.929178  [102400/2213439]
# Current batch training loss: -0.936026  [128000/2213439]
# Current batch training loss: -0.929122  [153600/2213439]
# Current batch training loss: -0.947502  [179200/2213439]
# Current batch training loss: -0.943900  [204800/2213439]
# Current batch training loss: -0.937435  [230400/2213439]
# Current batch training loss: -0.911846  [256000/2213439]
# Current batch training loss: -0.941372  [281600/2213439]
# Current batch training loss: -0.935528  [307200/2213439]
# Current batch training loss: -0.938836  [332800/2213439]
# Current batch training loss: -0.922610  [358400/2213439]
# Current batch training loss: -0.943706  [384000/2213439]
# Current batch training loss: -0.933865  [409600/2213439]
# Current batch training loss: -0.933321  [435200/2213439]
# Current batch training loss: -0.943163  [460800/2213439]
# Current batch training loss: -0.936007  [486400/2213439]
# Current batch training loss: -0.924870  [512000/2213439]
# Current batch training loss: -0.951580  [537600/2213439]
# Current batch training loss: -0.940345  [563200/2213439]
# Current batch training loss: -0.953814  [588800/2213439]
# Current batch training loss: -0.918681  [614400/2213439]
# Current batch training loss: -0.930352  [640000/2213439]
# Current batch training loss: -0.939567  [665600/2213439]
# Current batch training loss: -0.936480  [691200/2213439]
# Current batch training loss: -0.920811  [716800/2213439]
# Current batch training loss: -0.933745  [742400/2213439]
# Current batch training loss: -0.946569  [768000/2213439]
# Current batch training loss: -0.936422  [793600/2213439]
# Current batch training loss: -0.931796  [819200/2213439]
# Current batch training loss: -0.933935  [844800/2213439]
# Current batch training loss: -0.942576  [870400/2213439]
# Current batch training loss: -0.944199  [896000/2213439]
# Current batch training loss: -0.942185  [921600/2213439]
# Current batch training loss: -0.918042  [947200/2213439]
# Current batch training loss: -0.933703  [972800/2213439]
# Current batch training loss: -0.939497  [998400/2213439]
# Current batch training loss: -0.946252  [1024000/2213439]
# Current batch training loss: -0.932469  [1049600/2213439]
# Current batch training loss: -0.940347  [1075200/2213439]
# Current batch training loss: -0.949190  [1100800/2213439]
# Current batch training loss: -0.934345  [1126400/2213439]
# Current batch training loss: -0.935503  [1152000/2213439]
# Current batch training loss: -0.930666  [1177600/2213439]
# Current batch training loss: -0.919756  [1203200/2213439]
# Current batch training loss: -0.949911  [1228800/2213439]
# Current batch training loss: -0.925860  [1254400/2213439]
# Current batch training loss: -0.925778  [1280000/2213439]
# Current batch training loss: -0.936300  [1305600/2213439]
# Current batch training loss: -0.928157  [1331200/2213439]
# Current batch training loss: -0.929034  [1356800/2213439]
# Current batch training loss: -0.947505  [1382400/2213439]
# Current batch training loss: -0.914303  [1408000/2213439]
# Current batch training loss: -0.942811  [1433600/2213439]
# Current batch training loss: -0.937254  [1459200/2213439]
# Current batch training loss: -0.931044  [1484800/2213439]
# Current batch training loss: -0.916938  [1510400/2213439]
# Current batch training loss: -0.917803  [1536000/2213439]
# Current batch training loss: -0.935374  [1561600/2213439]
# Current batch training loss: -0.935828  [1587200/2213439]
# Current batch training loss: -0.939491  [1612800/2213439]
# Current batch training loss: -0.935416  [1638400/2213439]
# Current batch training loss: -0.914494  [1664000/2213439]
# Current batch training loss: -0.937136  [1689600/2213439]
# Current batch training loss: -0.942590  [1715200/2213439]
# Current batch training loss: -0.922539  [1740800/2213439]
# Current batch training loss: -0.923440  [1766400/2213439]
# Current batch training loss: -0.932447  [1792000/2213439]
# Current batch training loss: -0.925929  [1817600/2213439]
# Current batch training loss: -0.932256  [1843200/2213439]
# Current batch training loss: -0.942862  [1868800/2213439]
# Current batch training loss: -0.918568  [1894400/2213439]
# Current batch training loss: -0.939149  [1920000/2213439]
# Current batch training loss: -0.941498  [1945600/2213439]
# Current batch training loss: -0.941611  [1971200/2213439]
# Current batch training loss: -0.924175  [1996800/2213439]
# Current batch training loss: -0.917111  [2022400/2213439]
# Current batch training loss: -0.936978  [2048000/2213439]
# Current batch training loss: -0.933261  [2073600/2213439]
# Current batch training loss: -0.922579  [2099200/2213439]
# Current batch training loss: -0.929177  [2124800/2213439]
# Current batch training loss: -0.937639  [2150400/2213439]
# Current batch training loss: -0.926656  [2176000/2213439]
# Current batch training loss: -0.938772  [2201600/2213439]
# Training loss: -0.933747
# Validation loss: -0.920565
#
# Epoch 16
# -------------------------------
# Current batch training loss: -0.944543  [    0/2213439]
# Current batch training loss: -0.931812  [25600/2213439]
# Current batch training loss: -0.931838  [51200/2213439]
# Current batch training loss: -0.940257  [76800/2213439]
# Current batch training loss: -0.929466  [102400/2213439]
# Current batch training loss: -0.935679  [128000/2213439]
# Current batch training loss: -0.926202  [153600/2213439]
# Current batch training loss: -0.920432  [179200/2213439]
# Current batch training loss: -0.930747  [204800/2213439]
# Current batch training loss: -0.922377  [230400/2213439]
# Current batch training loss: -0.937519  [256000/2213439]
# Current batch training loss: -0.925800  [281600/2213439]
# Current batch training loss: -0.944983  [307200/2213439]
# Current batch training loss: -0.944259  [332800/2213439]
# Current batch training loss: -0.953497  [358400/2213439]
# Current batch training loss: -0.939132  [384000/2213439]
# Current batch training loss: -0.927546  [409600/2213439]
# Current batch training loss: -0.937190  [435200/2213439]
# Current batch training loss: -0.940913  [460800/2213439]
# Current batch training loss: -0.934575  [486400/2213439]
# Current batch training loss: -0.936399  [512000/2213439]
# Current batch training loss: -0.931187  [537600/2213439]
# Current batch training loss: -0.945332  [563200/2213439]
# Current batch training loss: -0.947027  [588800/2213439]
# Current batch training loss: -0.932908  [614400/2213439]
# Current batch training loss: -0.930934  [640000/2213439]
# Current batch training loss: -0.937147  [665600/2213439]
# Current batch training loss: -0.919710  [691200/2213439]
# Current batch training loss: -0.916933  [716800/2213439]
# Current batch training loss: -0.918258  [742400/2213439]
# Current batch training loss: -0.916735  [768000/2213439]
# Current batch training loss: -0.924459  [793600/2213439]
# Current batch training loss: -0.947554  [819200/2213439]
# Current batch training loss: -0.927924  [844800/2213439]
# Current batch training loss: -0.941023  [870400/2213439]
# Current batch training loss: -0.919664  [896000/2213439]
# Current batch training loss: -0.944831  [921600/2213439]
# Current batch training loss: -0.945735  [947200/2213439]
# Current batch training loss: -0.936777  [972800/2213439]
# Current batch training loss: -0.932031  [998400/2213439]
# Current batch training loss: -0.949955  [1024000/2213439]
# Current batch training loss: -0.932368  [1049600/2213439]
# Current batch training loss: -0.949901  [1075200/2213439]
# Current batch training loss: -0.949396  [1100800/2213439]
# Current batch training loss: -0.936508  [1126400/2213439]
# Current batch training loss: -0.928822  [1152000/2213439]
# Current batch training loss: -0.927177  [1177600/2213439]
# Current batch training loss: -0.953606  [1203200/2213439]
# Current batch training loss: -0.940172  [1228800/2213439]
# Current batch training loss: -0.935544  [1254400/2213439]
# Current batch training loss: -0.926520  [1280000/2213439]
# Current batch training loss: -0.947721  [1305600/2213439]
# Current batch training loss: -0.930203  [1331200/2213439]
# Current batch training loss: -0.922966  [1356800/2213439]
# Current batch training loss: -0.932367  [1382400/2213439]
# Current batch training loss: -0.922510  [1408000/2213439]
# Current batch training loss: -0.945975  [1433600/2213439]
# Current batch training loss: -0.913762  [1459200/2213439]
# Current batch training loss: -0.914724  [1484800/2213439]
# Current batch training loss: -0.925445  [1510400/2213439]
# Current batch training loss: -0.933858  [1536000/2213439]
# Current batch training loss: -0.929683  [1561600/2213439]
# Current batch training loss: -0.944392  [1587200/2213439]
# Current batch training loss: -0.931712  [1612800/2213439]
# Current batch training loss: -0.925470  [1638400/2213439]
# Current batch training loss: -0.912129  [1664000/2213439]
# Current batch training loss: -0.940809  [1689600/2213439]
# Current batch training loss: -0.924370  [1715200/2213439]
# Current batch training loss: -0.930863  [1740800/2213439]
# Current batch training loss: -0.934589  [1766400/2213439]
# Current batch training loss: -0.941222  [1792000/2213439]
# Current batch training loss: -0.935290  [1817600/2213439]
# Current batch training loss: -0.935113  [1843200/2213439]
# Current batch training loss: -0.938146  [1868800/2213439]
# Current batch training loss: -0.933422  [1894400/2213439]
# Current batch training loss: -0.936717  [1920000/2213439]
# Current batch training loss: -0.948867  [1945600/2213439]
# Current batch training loss: -0.933713  [1971200/2213439]
# Current batch training loss: -0.932776  [1996800/2213439]
# Current batch training loss: -0.929067  [2022400/2213439]
# Current batch training loss: -0.945407  [2048000/2213439]
# Current batch training loss: -0.933262  [2073600/2213439]
# Current batch training loss: -0.929216  [2099200/2213439]
# Current batch training loss: -0.924748  [2124800/2213439]
# Current batch training loss: -0.936858  [2150400/2213439]
# Current batch training loss: -0.948328  [2176000/2213439]
# Current batch training loss: -0.935179  [2201600/2213439]
# Training loss: -0.934456
# Validation loss: -0.920380
#
# Stopping early!
# Done!

# %% [markdown]
# # Visualize Training

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('Cosine Similarity Loss')
plt.legend()

# %% [markdown]
# # Save the Model

# %%
torch.save(final_model, "../3D_Heteroscedastic_Convnet_models/3D_CNN_alpha_"+str(alpha)+".pt")
print("Saved PyTorch Model State to ../3D_Heteroscedastic_Convnet_models/3D_CNN_alpha.pt")
# Out:
# Saved PyTorch Model State to ../3D_Heteroscedastic_Convnet_models/3D_CNN_alpha.pt
