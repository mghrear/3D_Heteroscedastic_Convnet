# %%
import numpy as np
import pandas as pd
import torch
import copy
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
from torchvision import datasets
import spconv.pytorch as spconv
import matplotlib.pyplot as plt
import mytools
import mymodels

# %% [markdown]
# # Prepare Data

# %%
# Read pandas dataframe with all information about sparse training tensors
file_loc = '/home/majd/sparse_training_arrows/'
st_info = pd.read_pickle(file_loc+'sparse_tensor_info.pk')
st_info
# Out:
#                                                     dir     offset
# 0     [-0.21901664850274835, 0.5265499716031883, -0....  [0, 0, 0]
# 1     [0.6163518863561397, -0.005503427027638802, 0....  [0, 0, 0]
# 2     [-0.6471694153114912, -0.7611794141912354, -0....  [0, 0, 0]
# 3     [0.9523343909191598, -0.30492272014752914, 0.0...  [0, 0, 0]
# 4     [-0.8025988436739429, -0.4235082256992638, 0.4...  [0, 0, 0]
# ...                                                 ...        ...
# 4995  [-0.9977560064789827, -0.04785238461469428, 0....  [0, 0, 0]
# 4996  [0.5710925701503711, 0.22745074956915004, -0.7...  [0, 0, 0]
# 4997  [0.7211940456227056, -0.34132889060714344, -0....  [0, 0, 0]
# 4998  [-0.7217230782414498, 0.5561096076550991, -0.4...  [0, 0, 0]
# 4999  [0.07927758959038997, -0.9893188064855813, -0....  [0, 0, 0]
#
# [5000 rows x 2 columns]

# %%
# Make custom dataset
MyDataset = mytools.CustomDataset(dir_loc = file_loc, st_info = st_info)

# Split datat into training, validation, and testing sets
train_dataset, val_dataset = torch.utils.data.random_split(MyDataset,[0.8, 0.2], generator=torch.Generator().manual_seed(42))

print("Training samples: ", len(train_dataset))
print("Validation samples: ", len(val_dataset))

# Create training and validation DataLoaders
batch_size = 256
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
# Out:
# Training samples:  4000
# Validation samples:  1000

# %%
# Print tensor shapes
for X_plot, y_plot, offset_plot in train_dataloader:
    print(f"Shape of X [N, C, H, W, D]: {X_plot.shape}")
    print(f"Shape of y: {y_plot.shape} {y_plot.dtype}")
    print("Offsets: ", offset_plot.shape)
    break
# Out:
# Shape of X [N, C, H, W, D]: torch.Size([256, 120, 120, 120, 1])
# Shape of y: torch.Size([256, 3]) torch.float32
# Offsets:  torch.Size([256, 3])

# %%
#Record shape of voxel grid
grid_shape = X_plot.shape[1:4]
print("Voxel grid shape: " , grid_shape)
# Out:
# Voxel grid shape:  torch.Size([120, 120, 120])

# %% [markdown]
# # Visualize a sample

# %%
# Plot an example as a sanity check

# x/y/z length being kept in cm
eff_l = mytools.voxel_grid['eff_l']
# Voxel size in cm
vox_l = mytools.voxel_grid['vox_l']

#Convert to dense, reshape and convert to numpy
X_plot = X_plot.to_dense().reshape(-1, 1, 120, 120, 120).numpy()

index = 2
mytools.plot_tensor_dir(tensor = X_plot[index], start = offset_plot[index].numpy(), direction = y_plot[index].numpy(), eff_l=eff_l, vox_l=vox_l)

# %% [markdown]
# # Initialize Convnet

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Using {device} device")

model = mymodels.spConvnet_HSCDC_subM(shape = grid_shape ).to(device)
print(model)
# Out:
# Using cuda device
# spConvnet_HSCDC_subM(
#   (net): SparseSequential(
#     (0): SubMConv3d(1, 32, kernel_size=[7, 7, 7], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (1): ReLU()
#     (2): SubMConv3d(32, 40, kernel_size=[5, 5, 5], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (3): ReLU()
#     (4): SparseConv3d(40, 50, kernel_size=[6, 6, 6], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (5): ReLU()
#     (6): SparseMaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], algo=ConvAlgo.MaskImplicitGemm)
#     (7): SparseConv3d(50, 30, kernel_size=[3, 3, 3], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.MaskImplicitGemm)
#     (8): ReLU()
#     (9): SparseConv3d(30, 10, kernel_size=[3, 3, 3], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.MaskImplicitGemm)
#     (10): ReLU()
#     (11): SparseMaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], algo=ConvAlgo.MaskImplicitGemm)
#     (12): ToDense()
#   )
#   (fc1): Linear(in_features=2160, out_features=500, bias=True)
#   (fc2_1): Linear(in_features=500, out_features=200, bias=True)
#   (fc3_1): Linear(in_features=200, out_features=50, bias=True)
#   (fc4_1): Linear(in_features=50, out_features=3, bias=True)
#   (fc2_2): Linear(in_features=500, out_features=200, bias=True)
#   (fc3_2): Linear(in_features=200, out_features=50, bias=True)
#   (fc4_2): Linear(in_features=50, out_features=1, bias=True)
# )

# %% [markdown]
# # Train the model

# %%
# Specify optimizer
optimizer = torch.optim.Adam(params = model.parameters(), lr=0.0001, betas=(0.94, 0.999), eps=1e-08)

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 2

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 1000
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train(train_dataloader, model, mytools.NLLloss_TS, optimizer, device))
    Validation_losses = np.append(Validation_losses, mytools.validate(val_dataloader, model, mytools.NLLloss_TS, device))
    
    # Keep a running copy of the model with the lowest loss
    # Do not copy the model if loss in nan
    if (Validation_losses[-1] == np.min(Validation_losses)) and (~np.isnan(Validation_losses[-1])):
        final_model = copy.deepcopy(model)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Current batch training loss: 2.632457  [    0/ 4000]
# Training loss: 2.574553
# Validation loss: 2.336380
#
# Epoch 2
# -------------------------------
# Current batch training loss: 2.283186  [    0/ 4000]
# Training loss: 2.041898
# Validation loss: 1.906516
#
# Epoch 3
# -------------------------------
# Current batch training loss: 1.903775  [    0/ 4000]
# Training loss: 1.823919
# Validation loss: 1.595218
#
# Epoch 4
# -------------------------------
# Current batch training loss: 1.595442  [    0/ 4000]
# Training loss: 0.246381
# Validation loss: -1.567650
#
# Epoch 5
# -------------------------------
# Current batch training loss: -1.571883  [    0/ 4000]
# Training loss: -2.234845
# Validation loss: -2.538631
#
# Epoch 6
# -------------------------------
# Current batch training loss: -2.569842  [    0/ 4000]
# Training loss: -2.853862
# Validation loss: -3.138456
#
# Epoch 7
# -------------------------------
# Current batch training loss: -3.130942  [    0/ 4000]
# Training loss: -3.207306
# Validation loss: -3.248547
#
# Epoch 8
# -------------------------------
# Current batch training loss: -3.303294  [    0/ 4000]
# Training loss: -3.317175
# Validation loss: -3.438552
#
# Epoch 9
# -------------------------------
# Current batch training loss: -3.408840  [    0/ 4000]
# Training loss: -3.580199
# Validation loss: -3.561050
#
# Epoch 10
# -------------------------------
# Current batch training loss: -3.540960  [    0/ 4000]
# Training loss: -3.651892
# Validation loss: -3.802080
#
# Epoch 11
# -------------------------------
# Current batch training loss: -3.765848  [    0/ 4000]
# Training loss: -3.808423
# Validation loss: -3.948705
#
# Epoch 12
# -------------------------------
# Current batch training loss: -4.007876  [    0/ 4000]
# Warning: nan gradient found. The current loss is:  -3.925597667694092
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.092235565185547
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.067259788513184
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.063014030456543
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.044365882873535
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.0021138191223145
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -3.874016523361206
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.120217323303223
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.0414581298828125
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Training loss: -4.013382
# Validation loss: -4.068681
#
# Epoch 13
# -------------------------------
# Current batch training loss: -4.065572  [    0/ 4000]
# Warning: nan gradient found. The current loss is:  -4.077482223510742
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.100922107696533
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.009661674499512
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.120471954345703
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.04672908782959
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.02326774597168
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.067359924316406
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.061164855957031
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.045928001403809
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.048352241516113
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.107816219329834
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.056611061096191
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.0664381980896
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.0623064041137695
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -3.9815163612365723
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Training loss: -4.058850
# Validation loss: -4.066307
#
# Epoch 14
# -------------------------------
# Warning: nan gradient found. The current loss is:  -4.081417083740234
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Current batch training loss: -4.081417  [    0/ 4000]
# Warning: nan gradient found. The current loss is:  -4.0170392990112305
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -3.978133201599121
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.079550743103027
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.029630661010742
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.038666248321533
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.083337783813477
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.0420308113098145
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.031026363372803
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.047087669372559
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.176709175109863
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.023340702056885
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.05478048324585
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.125049591064453
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.088642120361328
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Warning: nan gradient found. The current loss is:  -4.133500576019287
# To avoid this, continue training with a lower order Taylor Series in the NLL loss
# Training loss: -4.064371
# Validation loss: -4.064244
#
# Stopping early!
# Done!

# %% [markdown]
# # Visualize Training

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses[~np.isnan(Training_losses)])+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('Negative Log Likelihood Loss')
plt.legend()

# %% [markdown]
# # Save the Model

# %%
torch.save(final_model, "../3D_Heteroscedastic_Convnet_models/3D_HSCDC_arrows.pt")
print("Saved PyTorch Model to ../3D_Heteroscedastic_Convnet_models/3D_HSCDC_arrows.pt")
# Out:
# Saved PyTorch Model to ../3D_Heteroscedastic_Convnet_models/3D_HSCDC_arrows.pt
