# %%
import numpy as np
import pandas as pd
import torch
import copy
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
from torchvision import datasets
import spconv.pytorch as spconv
import matplotlib.pyplot as plt
import mytools
import mymodels

# %% [markdown]
# # Prepare Data

# %%
# Read pandas dataframe with all information about sparse training tensors
file_loc = '/home/majd/sparse_training_arrows/'
st_info = pd.read_pickle(file_loc+'sparse_tensor_info.pk')
st_info
# Out:
#                                                   dir     offset
# 0   [-0.5520938254267553, -0.825713352783964, -0.1...  [0, 0, 0]
# 1   [0.3657888590215906, 0.4602307668281921, 0.808...  [0, 0, 0]
# 2   [0.9315045909480836, 0.35431361511161974, 0.08...  [0, 0, 0]
# 3   [0.17431689982853446, -0.9752304574243912, 0.1...  [0, 0, 0]
# 4   [-0.13304236665754948, 0.7513837952040148, 0.6...  [0, 0, 0]
# ..                                                ...        ...
# 95  [-0.23104568980665205, 0.5956136249445827, 0.7...  [0, 0, 0]
# 96  [0.91419301977937, 0.2786905690823306, -0.2942...  [0, 0, 0]
# 97  [-0.12297952315221822, -0.9187204705663674, -0...  [0, 0, 0]
# 98  [-0.6005107791429211, -0.2983086399835448, -0....  [0, 0, 0]
# 99  [0.5374642708895431, 0.19821716045529983, -0.8...  [0, 0, 0]
#
# [100 rows x 2 columns]

# %%
# Make custom dataset
MyDataset = mytools.CustomDataset(dir_loc = file_loc, st_info = st_info)

# Split datat into training, validation, and testing sets
train_dataset, val_dataset = torch.utils.data.random_split(MyDataset,[0.8, 0.2], generator=torch.Generator().manual_seed(42))

print("Training samples: ", len(train_dataset))
print("Validation samples: ", len(val_dataset))

# Create training and validation DataLoaders
batch_size = 256
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
# Out:
# Training samples:  80
# Validation samples:  20

# %%
# Print tensor shapes
for X_plot, y_plot, offset_plot in train_dataloader:
    print(f"Shape of X [N, C, H, W, D]: {X_plot.shape}")
    print(f"Shape of y: {y_plot.shape} {y_plot.dtype}")
    print("Offsets: ", offset_plot.shape)
    break
# Out:
# Shape of X [N, C, H, W, D]: torch.Size([80, 120, 120, 120, 1])
# Shape of y: torch.Size([80, 3]) torch.float32
# Offsets:  torch.Size([80, 3])

# %%
#Record shape of voxel grid
grid_shape = X_plot.shape[1:4]
print("Voxel grid shape: " , grid_shape)
# Out:
# Voxel grid shape:  torch.Size([120, 120, 120])

# %% [markdown]
# # Visualize a sample

# %%
# Plot an example as a sanity check

# x/y/z length being kept in cm
eff_l = mytools.voxel_grid['eff_l']
# Voxel size in cm
vox_l = mytools.voxel_grid['vox_l']

#Convert to dense, reshape and convert to numpy
X_plot = X_plot.to_dense().reshape(-1, 1, 120, 120, 120).numpy()

index = 2
mytools.plot_tensor_dir(tensor = X_plot[index], start = offset_plot[index].numpy(), direction = y_plot[index].numpy(), eff_l=eff_l, vox_l=vox_l)

# %% [markdown]
# # Initialize Convnet

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Using {device} device")

model = mymodels.spConvnet_HSCDC_subM(shape = grid_shape ).to(device)
print(model)
# Out:
# Using cuda device
# spConvnet_HSCDC_subM(
#   (net): SparseSequential(
#     (0): SubMConv3d(1, 32, kernel_size=[7, 7, 7], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (1): ReLU()
#     (2): SubMConv3d(32, 40, kernel_size=[5, 5, 5], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (3): ReLU()
#     (4): SparseConv3d(40, 50, kernel_size=[6, 6, 6], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (5): ReLU()
#     (6): SparseMaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], algo=ConvAlgo.MaskImplicitGemm)
#     (7): SparseConv3d(50, 30, kernel_size=[3, 3, 3], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.MaskImplicitGemm)
#     (8): ReLU()
#     (9): SparseConv3d(30, 10, kernel_size=[3, 3, 3], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.MaskImplicitGemm)
#     (10): ReLU()
#     (11): SparseMaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], algo=ConvAlgo.MaskImplicitGemm)
#     (12): ToDense()
#   )
#   (fc1): Linear(in_features=2160, out_features=500, bias=True)
#   (fc2_1): Linear(in_features=500, out_features=200, bias=True)
#   (fc3_1): Linear(in_features=200, out_features=50, bias=True)
#   (fc4_1): Linear(in_features=50, out_features=3, bias=True)
#   (fc2_2): Linear(in_features=500, out_features=200, bias=True)
#   (fc3_2): Linear(in_features=200, out_features=50, bias=True)
#   (fc4_2): Linear(in_features=50, out_features=1, bias=True)
# )

# %% [markdown]
# # Train the model

# %%
# Specify optimizer
optimizer = torch.optim.Adam(params = model.parameters(), lr=0.0001, betas=(0.94, 0.999), eps=1e-07)

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 2

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 1000
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train(train_dataloader, model, mytools.NLLloss, optimizer, device))
    Validation_losses = np.append(Validation_losses, mytools.validate(val_dataloader, model, mytools.NLLloss, device))
    
    # Keep a running copy of the model with the lowest loss
    # Do not copy the model if loss in nan
    if (Validation_losses[-1] == np.min(Validation_losses)) and (~np.isnan(Validation_losses[-1])):
        final_model = copy.deepcopy(model)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Current batch training loss: 2.573217  [    0/   80]
# Training loss: 2.573217
# Validation loss: 2.712095
#
# Epoch 2
# -------------------------------
# Current batch training loss: 2.572427  [    0/   80]
# Training loss: 2.572427
# Validation loss: 2.711688
#
# Epoch 3
# -------------------------------
# Current batch training loss: 2.571620  [    0/   80]
# Training loss: 2.571620
# Validation loss: 2.711189
#
# Epoch 4
# -------------------------------
# Current batch training loss: 2.570736  [    0/   80]
# Training loss: 2.570736
# Validation loss: 2.710493
#
# Epoch 5
# -------------------------------
# Current batch training loss: 2.569685  [    0/   80]
# Training loss: 2.569685
# Validation loss: 2.709525
#
# Epoch 6
# -------------------------------
# Current batch training loss: 2.568425  [    0/   80]
# Training loss: 2.568425
# Validation loss: 2.708192
#
# Epoch 7
# -------------------------------
# Current batch training loss: 2.566851  [    0/   80]
# Training loss: 2.566851
# Validation loss: 2.706370
#
# Epoch 8
# -------------------------------
# Current batch training loss: 2.564795  [    0/   80]
# Training loss: 2.564795
# Validation loss: 2.703808
#
# Epoch 9
# -------------------------------
# Current batch training loss: 2.561864  [    0/   80]
# Training loss: 2.561864
# Validation loss: 2.700030
#
# Epoch 10
# -------------------------------
# Current batch training loss: 2.557765  [    0/   80]
# Training loss: 2.557765
# Validation loss: 2.694562
#
# Epoch 11
# -------------------------------
# Current batch training loss: 2.552166  [    0/   80]
# Training loss: 2.552166
# Validation loss: 2.686410
#
# Epoch 12
# -------------------------------
# Current batch training loss: 2.544382  [    0/   80]
# Training loss: 2.544382
# Validation loss: 2.675124
#
# Epoch 13
# -------------------------------
# Current batch training loss: 2.533754  [    0/   80]
# Training loss: 2.533754
# Validation loss: 2.660244
#
# Epoch 14
# -------------------------------
# Current batch training loss: 2.519881  [    0/   80]
# Training loss: 2.519881
# Validation loss: 2.640360
#
# Epoch 15
# -------------------------------
# Current batch training loss: 2.501753  [    0/   80]
# Training loss: 2.501753
# Validation loss: 2.613668
#
# Epoch 16
# -------------------------------
# Current batch training loss: 2.478367  [    0/   80]
# Training loss: 2.478367
# Validation loss: 2.579221
#
# Epoch 17
# -------------------------------
# Current batch training loss: 2.449169  [    0/   80]
# Training loss: 2.449169
# Validation loss: 2.537764
#
# Epoch 18
# -------------------------------
# Current batch training loss: 2.414658  [    0/   80]
# Training loss: 2.414658
# Validation loss: 2.489815
#
# Epoch 19
# -------------------------------
# Current batch training loss: 2.375493  [    0/   80]
# Training loss: 2.375493
# Validation loss: 2.435110
#
# Epoch 20
# -------------------------------
# Current batch training loss: 2.330774  [    0/   80]
# Training loss: 2.330774
# Validation loss: 2.374574
#
# Epoch 21
# -------------------------------
# Current batch training loss: 2.278855  [    0/   80]
# Training loss: 2.278855
# Validation loss: 2.308870
#
# Epoch 22
# -------------------------------
# Current batch training loss: 2.219256  [    0/   80]
# Training loss: 2.219256
# Validation loss: 2.237751
#
# Epoch 23
# -------------------------------
# Current batch training loss: 2.154547  [    0/   80]
# Training loss: 2.154547
# Validation loss: 2.158859
#
# Epoch 24
# -------------------------------
# Current batch training loss: 2.091184  [    0/   80]
# Training loss: 2.091184
# Validation loss: 2.042464
#
# Epoch 25
# -------------------------------
# Current batch training loss: 2.033268  [    0/   80]
# Training loss: 2.033268
# Validation loss: 1.990452
#
# Epoch 26
# -------------------------------
# Current batch training loss: 2.009683  [    0/   80]
# Training loss: 2.009683
# Validation loss: 1.968393
#
# Epoch 27
# -------------------------------
# Current batch training loss: 2.001823  [    0/   80]
# Training loss: 2.001823
# Validation loss: 1.936907
#
# Epoch 28
# -------------------------------
# Current batch training loss: 1.971201  [    0/   80]
# Training loss: 1.971201
# Validation loss: 1.887682
#
# Epoch 29
# -------------------------------
# Current batch training loss: 1.916292  [    0/   80]
# Training loss: 1.916292
# Validation loss: 1.822624
#
# Epoch 30
# -------------------------------
# Current batch training loss: 1.842943  [    0/   80]
# Training loss: 1.842943
# Validation loss: 1.743813
#
# Epoch 31
# -------------------------------
# Current batch training loss: 1.757355  [    0/   80]
# Training loss: 1.757355
# Validation loss: 1.652305
#
# Epoch 32
# -------------------------------
# Current batch training loss: 1.662872  [    0/   80]
# Training loss: 1.662872
# Validation loss: 1.545702
#
# Epoch 33
# -------------------------------
# Current batch training loss: 1.556302  [    0/   80]
# Training loss: 1.556302
# Validation loss: 1.417255
#
# Epoch 34
# -------------------------------
# Current batch training loss: 1.430940  [    0/   80]
# Training loss: 1.430940
# Validation loss: 1.257490
#
# Epoch 35
# -------------------------------
# Current batch training loss: 1.278260  [    0/   80]
# Training loss: 1.278260
# Validation loss: 1.057532
#
# Epoch 36
# -------------------------------
# Current batch training loss: 1.090539  [    0/   80]
# Training loss: 1.090539
# Validation loss: 0.816560
#
# Epoch 37
# -------------------------------
# Current batch training loss: 0.865302  [    0/   80]
# Training loss: 0.865302
# Validation loss: 0.547122
#
# Epoch 38
# -------------------------------
# Current batch training loss: 0.609925  [    0/   80]
# Training loss: 0.609925
# Validation loss: 0.279141
#
# Epoch 39
# -------------------------------
# Current batch training loss: 0.344388  [    0/   80]
# Training loss: 0.344388
# Validation loss: 0.046440
#
# Epoch 40
# -------------------------------
# Current batch training loss: 0.098871  [    0/   80]
# Training loss: 0.098871
# Validation loss: -0.147647
#
# Epoch 41
# -------------------------------
# Current batch training loss: -0.111381  [    0/   80]
# Training loss: -0.111381
# Validation loss: -0.352643
#
# Epoch 42
# -------------------------------
# Current batch training loss: -0.330895  [    0/   80]
# Training loss: -0.330895
# Validation loss: -0.593780
#
# Epoch 43
# -------------------------------
# Current batch training loss: -0.576719  [    0/   80]
# Training loss: -0.576719
# Validation loss: -0.838878
#
# Epoch 44
# -------------------------------
# Current batch training loss: -0.784661  [    0/   80]
# Training loss: -0.784661
# Validation loss: -1.084662
#
# Epoch 45
# -------------------------------
# Current batch training loss: -1.007949  [    0/   80]
# Training loss: -1.007949
# Validation loss: -1.271139
#
# Epoch 46
# -------------------------------
# Current batch training loss: -1.248132  [    0/   80]
# Training loss: -1.248132
# Validation loss: -1.375728
#
# Epoch 47
# -------------------------------
# Current batch training loss: -1.368945  [    0/   80]
# Training loss: -1.368945
# Validation loss: -1.610914
#
# Epoch 48
# -------------------------------
# Current batch training loss: -1.584046  [    0/   80]
# Training loss: -1.584046
# Validation loss: -1.739056
#
# Epoch 49
# -------------------------------
# Current batch training loss: -1.766728  [    0/   80]
# Training loss: -1.766728
# Validation loss: -1.836463
#
# Epoch 50
# -------------------------------
# Current batch training loss: -1.913467  [    0/   80]
# Training loss: -1.913467
# Validation loss: -1.960208
#
# Epoch 51
# -------------------------------
# Current batch training loss: -2.051148  [    0/   80]
# Training loss: -2.051148
# Validation loss: -2.093673
#
# Epoch 52
# -------------------------------
# Current batch training loss: -2.155357  [    0/   80]
# Training loss: -2.155357
# Validation loss: -2.309821
#
# Epoch 53
# -------------------------------
# Warning: nan gradient found. The current loss is:  -2.2746591567993164
# Current batch training loss: -2.274659  [    0/   80]
# Training loss: -2.274659
# Validation loss: -2.309821
#
# Epoch 54
# -------------------------------
# Warning: nan gradient found. The current loss is:  -2.2746591567993164
# Current batch training loss: -2.274659  [    0/   80]
# Training loss: -2.274659
# Validation loss: -2.309821
#
# Stopping early!
# Done!

# %% [markdown]
# # Visualize Training

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses[~np.isnan(Training_losses)])+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('Negative Log Likelihood Loss')
plt.legend()

# %% [markdown]
# # Save the Model

# %%
torch.save(final_model, "../3D_Heteroscedastic_Convnet_models/3D_HSCDC_CNN_subM-256_arrow.pt")
print("Saved PyTorch Model State to ../3D_Heteroscedastic_Convnet_models/3D_HSCDC_CNN_subM-256_arrow.pt")
# Out:
# Saved PyTorch Model State to ../3D_Heteroscedastic_Convnet_models/3D_HSCDC_CNN_subM-256_arrow.pt
