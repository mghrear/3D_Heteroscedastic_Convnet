# %%
import torch
import copy
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
from torchvision import datasets

import matplotlib.pyplot as plt
import numpy as np
import os
import mytools
import pandas as pd

import spconv.pytorch as spconv
from spconv.pytorch import functional as Fsp
from spconv.pytorch.utils import PointToVoxel
from spconv.pytorch.hash import HashTable
import contextlib

# %% [markdown]
# # Prepare Data

# %%
# Read pandas dataframe with all information about sparse training tensors
st_info = pd.read_pickle('/home/majd/sparse_training_tensors/sparse_tensor_info.pk')
st_info.head()
# Out:
#                                                  dir  \
# 0  [-0.4198009988390553, -0.4440823098716106, 0.7...
# 1  [0.9292584753858835, 0.36787504773435054, -0.0...
# 2  [0.6975108938815566, -0.6644836831430804, 0.26...
# 3  [0.32184656062767913, 0.5144094887414011, 0.79...
# 4  [-0.5064111899864489, -0.6946257429389592, -0....
#
#                                               offset      diff
# 0  [-0.13160994280565688, 0.44427934344609393, -2...  0.020573
# 1  [-2.8848038745477615, -0.18587373584726274, -2...  0.032068
# 2  [-2.640509097021054, 0.40556093511292457, 0.66...  0.043303
# 3  [1.5512170253679882, -1.523265044801098, -2.37...  0.025124
# 4  [0.16089299282025019, 2.8954267960229534, 0.37...  0.016838

# %%
# Make custom dataset
MyDataset = mytools.CustomDataset(dir_loc='/home/majd/sparse_training_tensors/', st_info=st_info)

# Split datat into training, validation, and testing sets
train_dataset, val_dataset = torch.utils.data.random_split(MyDataset,[0.8, 0.2], generator=torch.Generator().manual_seed(42))

print("Training samples: ", len(train_dataset))
print("Validation samples: ", len(val_dataset))

# Create DataLoaders
batch_size = 64
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
# Out:
# Training samples:  1943113
# Validation samples:  485778

# %% [markdown]
# # Visualize Data

# %%
# Print tensor shapes
for X_plot, y_plot, offset_plot in train_dataloader:
    print(f"Shape of X [N, C, H, W, D]: {X_plot.shape}")
    print(f"Shape of y: {y_plot.shape} {y_plot.dtype}")
    print("Offsets: ", offset_plot.shape)
    break
# Out:
# Shape of X [N, C, H, W, D]: torch.Size([64, 1, 120, 120, 120])
# Shape of y: torch.Size([64, 3]) torch.float32
# Offsets:  torch.Size([64, 3])

# %%
#Record shape of voxel grid
grid_shape = X_plot.shape[2:]
print("Voxel grid shape: " , grid_shape)
# Out:
# Voxel grid shape:  torch.Size([120, 120, 120])

# %%
# Plot an example as a sanity check

# x/y/z length being kept in cm
eff_l = 3.0
# Voxel size in cm
vox_l = 0.05

index = 2
mytools.plot_tensor_dir(tensor = X_plot.to_dense().numpy()[index], start = offset_plot[index].numpy(), direction = y_plot[index].numpy(), eff_l=eff_l, vox_l=vox_l)

# %% [markdown]
# # Define Convnet Architecture

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Using {device} device")

class spConvnet_HSCDC(nn.Module):
    def __init__(self, shape):
        super(spConvnet_HSCDC, self).__init__()
        self.net = spconv.SparseSequential(
            spconv.SparseConv3d(in_channels=1, out_channels=50, kernel_size=6, stride=2, bias=True),
            nn.ReLU(),
            spconv.SparseMaxPool3d(kernel_size=2, stride=2),
            spconv.SparseConv3d(in_channels=50, out_channels=30, kernel_size=4, stride=1, bias=True),
            nn.ReLU(),
            spconv.SparseConv3d(in_channels=30, out_channels=20, kernel_size=3, stride=1, bias=True),
            nn.ReLU(),
            spconv.SparseMaxPool3d(kernel_size=2, stride=2),
            spconv.ToDense(),
            
        )

        self.fc1 = nn.Linear(12**3 *20, 100)
        self.fc2_1 = nn.Linear(100, 30)
        self.fc3_1 = nn.Linear(30, 3)
        self.fc2_2 = nn.Linear(100, 30)
        self.fc3_2 = nn.Linear(30, 1)
        
        self.shape = shape
        

    def forward(self, x: torch.Tensor):
        
        x_sp = spconv.SparseConvTensor.from_dense(x.reshape(-1, self.shape[0], self.shape[1], self.shape[2], 1))
        
        
        x = self.net(x_sp)
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x1 = torch.tanh(self.fc2_1(x))
        output1 = F.normalize(self.fc3_1(x1),dim=1)
        x2 = F.relu(self.fc2_2(x))
        # Training network to predict log(K) is more numerically stable?? 
        output2 = torch.log(F.softplus(self.fc3_2(x2)))
                
        return output1,output2
    

model = spConvnet_HSCDC(shape = grid_shape ).to(device)

# Print a nicer model summary
print(model)
# Out:
# Using cuda device
# NeuralNetwork(
#   (net): SparseSequential(
#     (0): SparseConv3d(1, 50, kernel_size=[6, 6, 6], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (1): ReLU()
#     (2): SparseMaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], algo=ConvAlgo.MaskImplicitGemm)
#     (3): SparseConv3d(50, 30, kernel_size=[4, 4, 4], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (4): ReLU()
#     (5): SparseConv3d(30, 20, kernel_size=[3, 3, 3], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.MaskImplicitGemm)
#     (6): ReLU()
#     (7): SparseMaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], algo=ConvAlgo.MaskImplicitGemm)
#     (8): ToDense()
#   )
#   (fc1): Linear(in_features=34560, out_features=100, bias=True)
#   (fc2_1): Linear(in_features=100, out_features=30, bias=True)
#   (fc3_1): Linear(in_features=30, out_features=3, bias=True)
#   (fc2_2): Linear(in_features=100, out_features=30, bias=True)
#   (fc3_2): Linear(in_features=30, out_features=1, bias=True)
# )

# %% [markdown]
# # Train the model

# %%
# Specify optimizer
optimizer = torch.optim.Adam(params = model.parameters(), lr=0.0001, betas=(0.94, 0.999), eps=1e-07)

# Define Loss function
def loss_fn(output, target):
    
    # target us the x parameters in the Kent distribution
    G = output[0] # \gamma_1 parameters in Kent distribution
    K = torch.exp(output[1]) # \kappa parameters in Kent distribution
    
    # Compute negative log likelihood using Kent distribution
    loss = torch.sum( -1.0*torch.log(torch.div(K,4*torch.pi*torch.sinh(K))).flatten() - ( K.flatten() * torch.sum(G*target,dim=1) ) )
    
    return loss

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 2

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 1000
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train(train_dataloader, model, loss_fn, optimizer, device))
    Validation_losses = np.append(Validation_losses, mytools.validate(val_dataloader, model, loss_fn, device))
    
    # Keep a running copy of the model with the lowest loss
    # Do not copy the model if loss in nan
    if (Validation_losses[-1] == np.min(Validation_losses)) and (~np.isnan(Validation_losses[-1])):
        final_model = copy.deepcopy(model)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Current batch training loss: 172.576202  [    0/1943113]
# Current batch training loss: 150.473969  [ 6400/1943113]
# Current batch training loss: 146.146881  [12800/1943113]
# Current batch training loss: 148.760803  [19200/1943113]
# Current batch training loss: 146.498932  [25600/1943113]
# Current batch training loss: 144.455856  [32000/1943113]
# Current batch training loss: 135.489960  [38400/1943113]
# Current batch training loss: 137.880707  [44800/1943113]
# Current batch training loss: 139.641754  [51200/1943113]
# Current batch training loss: 137.106750  [57600/1943113]
# Current batch training loss: 133.349640  [64000/1943113]
# Current batch training loss: 133.022766  [70400/1943113]
# Current batch training loss: 137.564972  [76800/1943113]
# Current batch training loss: 128.694855  [83200/1943113]
# Current batch training loss: 125.876015  [89600/1943113]
# Current batch training loss: 124.164886  [96000/1943113]
# Current batch training loss: 116.608078  [102400/1943113]
# Current batch training loss: 105.668442  [108800/1943113]
# Current batch training loss: 128.173065  [115200/1943113]
# Current batch training loss: 111.773285  [121600/1943113]
# Current batch training loss: 124.261780  [128000/1943113]
# Current batch training loss: 120.593788  [134400/1943113]
# Current batch training loss: 122.019913  [140800/1943113]
# Current batch training loss: 98.318558  [147200/1943113]
# Current batch training loss: 111.771317  [153600/1943113]
# Current batch training loss: 95.769096  [160000/1943113]
# Current batch training loss: 97.485741  [166400/1943113]
# Current batch training loss: 104.048042  [172800/1943113]
# Current batch training loss: 102.793098  [179200/1943113]
# Current batch training loss: 105.362289  [185600/1943113]
# Current batch training loss: 103.144188  [192000/1943113]
# Current batch training loss: 110.697021  [198400/1943113]
# Current batch training loss: 119.878044  [204800/1943113]
# Current batch training loss: 98.261063  [211200/1943113]
# Current batch training loss: 87.388176  [217600/1943113]
# Current batch training loss: 107.240631  [224000/1943113]
# Current batch training loss: 117.144424  [230400/1943113]
# Current batch training loss: 101.475784  [236800/1943113]
# Current batch training loss: 98.572495  [243200/1943113]
# Current batch training loss: 73.235596  [249600/1943113]
# Current batch training loss: 95.139832  [256000/1943113]
# Current batch training loss: 111.309578  [262400/1943113]
# Current batch training loss: 77.943054  [268800/1943113]
# Current batch training loss: 102.082230  [275200/1943113]
# Current batch training loss: 89.803482  [281600/1943113]
# Current batch training loss: 81.159462  [288000/1943113]
# Current batch training loss: 97.272842  [294400/1943113]
# Current batch training loss: 84.575706  [300800/1943113]
# Current batch training loss: 90.522430  [307200/1943113]
# Current batch training loss: 81.305878  [313600/1943113]
# Current batch training loss: 95.904182  [320000/1943113]
# Current batch training loss: 112.714584  [326400/1943113]
# Current batch training loss: 79.882477  [332800/1943113]
# Current batch training loss: 69.362946  [339200/1943113]
# Current batch training loss: 104.175568  [345600/1943113]
# Current batch training loss: 90.396690  [352000/1943113]
# Current batch training loss: 93.542809  [358400/1943113]
# Current batch training loss: 36.055782  [1625600/1943113]
# Current batch training loss: 39.733006  [1632000/1943113]
# Current batch training loss: 29.482401  [1638400/1943113]
# Current batch training loss: 51.279175  [1644800/1943113]
# Current batch training loss: 30.255816  [1651200/1943113]
# Current batch training loss: 39.304981  [1657600/1943113]
# Current batch training loss: 32.665413  [1664000/1943113]
# Current batch training loss: 28.556206  [1670400/1943113]
# Current batch training loss: 44.402725  [1676800/1943113]
# Current batch training loss: 57.416779  [1683200/1943113]
# Current batch training loss: 52.043076  [1689600/1943113]
# Current batch training loss: 45.526871  [1696000/1943113]
# Current batch training loss: 43.790661  [1702400/1943113]
# Current batch training loss: 59.742638  [1708800/1943113]
# Current batch training loss: 30.608467  [1715200/1943113]
# Current batch training loss: 31.994846  [1721600/1943113]
# Current batch training loss: 24.093153  [1728000/1943113]
# Current batch training loss: 45.496838  [1734400/1943113]
# Current batch training loss: 31.351624  [1740800/1943113]
# Current batch training loss: 57.079540  [1747200/1943113]
# Current batch training loss: 34.174717  [1753600/1943113]
# Current batch training loss: 35.670250  [1760000/1943113]
# Current batch training loss: 38.436073  [1766400/1943113]
# Current batch training loss: 68.498047  [1772800/1943113]
# Current batch training loss: 36.929737  [1779200/1943113]
# Current batch training loss: 64.259087  [1785600/1943113]
# Current batch training loss: 32.965759  [1792000/1943113]
# Current batch training loss: 33.910511  [1798400/1943113]
# Current batch training loss: 23.305000  [1804800/1943113]
# Current batch training loss: 39.789215  [1811200/1943113]
# Current batch training loss: 45.044228  [1817600/1943113]
# Current batch training loss: 24.587959  [1824000/1943113]
# Current batch training loss: 66.644180  [1830400/1943113]
# Current batch training loss: 34.996613  [1836800/1943113]
# Current batch training loss: 58.812450  [1843200/1943113]
# Current batch training loss: 50.363525  [1849600/1943113]
# Current batch training loss: 37.388512  [1856000/1943113]
# Current batch training loss: 43.897991  [1862400/1943113]
# Current batch training loss: 49.792709  [1868800/1943113]
# Current batch training loss: 61.546497  [1875200/1943113]
# Current batch training loss: 43.991257  [1881600/1943113]
# Current batch training loss: 50.872322  [1888000/1943113]
# Current batch training loss: 40.120052  [1894400/1943113]
# Current batch training loss: 32.874420  [1900800/1943113]
# Current batch training loss: 50.014763  [1907200/1943113]
# Current batch training loss: 35.381947  [1913600/1943113]
# Current batch training loss: 52.973076  [1920000/1943113]
# Current batch training loss: 35.277145  [1926400/1943113]
# Current batch training loss: 34.184380  [1932800/1943113]
# Current batch training loss: 43.182564  [1939200/1943113]
# Training loss: 65.627599

# %% [markdown]
# # Visualize Training

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses[~np.isnan(Training_losses)])

plt.plot(np.arange(len(Training_losses)),Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses)),Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('Cosine Similarity Loss')
plt.legend()

# %% [markdown]
# # Save the Model

# %%
torch.save(final_model, "../3D_Heteroscedastic_Convnet_models/3D_HSCDC_CNN_spconv.pt")
print("Saved PyTorch Model State to ../3D_Heteroscedastic_Convnet_models/3D_HSCDC_CNN_spconv.pt")
