# %%
import numpy as np
import pandas as pd
import torch
import copy
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
from torchvision import datasets
import spconv.pytorch as spconv
import matplotlib.pyplot as plt
import mytools
import mymodels

# %% [markdown]
# # Prepare Data

# %%
# Read pandas dataframe with all information about sparse training tensors
file_loc = '/mnt/scratch/lustre_01/scratch/majd/sparse_training_tensors/'
st_info = pd.read_pickle(file_loc+'sparse_tensor_info.pk')
st_info
# Out:
#                                                        dir  \
# 0        [0.5923457337920527, -0.5369941830475861, -0.6...
# 1        [-0.6164927192719855, 0.5695943083433039, -0.5...
# 2        [0.6322337566233259, -0.16773581669128113, -0....
# 3        [0.2908139608694231, -0.8484810341097399, -0.4...
# 4        [0.7738521869833273, -0.07925597736546798, -0....
# ...                                                    ...
# 2766793  [-0.2069418024409927, 0.2672370217202399, -0.9...
# 2766794  [0.5942730241053608, 0.6175260630673811, -0.51...
# 2766795  [0.3312106913072638, 0.5407131844563555, 0.773...
# 2766796  [-0.0071324298603245555, 0.623790473641556, 0....
# 2766797  [-0.06412683698521963, -0.9977986677530827, 0....
#
#                                                     offset      diff energy  \
# 0        [-0.851898273495669, 2.1253245532459824, 0.445...  0.046168     40
# 1        [-1.017085182270888, -1.6805460012244295, 1.10...  0.028843     40
# 2        [-0.10613203070195368, 0.22289410895907838, 1....  0.025293     40
# 3        [-1.0096727220437194, 1.2613684348817842, 1.42...  0.034410     40
# 4        [0.7752193984015442, 0.8404383794565299, 0.902...  0.033654     40
# ...                                                    ...       ...    ...
# 2766793  [-0.5891835692649702, -0.5092523892090935, 1.8...  0.043683     50
# 2766794  [-0.723736545709404, -0.10798660967928463, 0.6...  0.030250     50
# 2766795  [-0.3615579024644222, 1.934812461239543, -2.26...  0.030298     50
# 2766796  [0.7469683683355023, -2.603944946514045, -0.74...  0.039175     50
# 2766797  [1.8179965860730307, 1.618875928754491, -1.181...  0.024449     50
#
#         true_index
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
# ...            ...
# 2766793    2766793
# 2766794    2766794
# 2766795    2766795
# 2766796    2766796
# 2766797    2766797
#
# [2766798 rows x 5 columns]

# %%
# Make custom dataset
MyDataset = mytools.CustomDataset(dir_loc = file_loc, st_info = st_info)

# Split datat into training, validation, and testing sets
train_dataset, val_dataset = torch.utils.data.random_split(MyDataset,[0.8, 0.2], generator=torch.Generator().manual_seed(42))

print("Training samples: ", len(train_dataset))
print("Validation samples: ", len(val_dataset))

# Create training and validation DataLoaders
batch_size = 256
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
# Out:
# Training samples:  2213439
# Validation samples:  553359

# %%
# Print tensor shapes
for X_plot, y_plot, offset_plot in train_dataloader:
    print(f"Shape of X [N, C, H, W, D]: {X_plot.shape}")
    print(f"Shape of y: {y_plot.shape} {y_plot.dtype}")
    print("Offsets: ", offset_plot.shape)
    break
# Out:
# Shape of X [N, C, H, W, D]: torch.Size([256, 120, 120, 120, 1])
# Shape of y: torch.Size([256, 3]) torch.float32
# Offsets:  torch.Size([256, 3])

# %%
#Record shape of voxel grid
grid_shape = X_plot.shape[1:4]
print("Voxel grid shape: " , grid_shape)
# Out:
# Voxel grid shape:  torch.Size([120, 120, 120])

# %% [markdown]
# # Visualize a sample

# %%
# Plot an example as a sanity check

# x/y/z length being kept in cm
eff_l = mytools.voxel_grid['eff_l']
# Voxel size in cm
vox_l = mytools.voxel_grid['vox_l']

#Convert to dense, reshape and convert to numpy
X_plot = X_plot.to_dense().reshape(-1, 1, 120, 120, 120).numpy()

index = 2
mytools.plot_tensor_dir(tensor = X_plot[index], start = offset_plot[index].numpy(), direction = y_plot[index].numpy(), eff_l=eff_l, vox_l=vox_l)

# %% [markdown]
# # Initialize Convnet

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Using {device} device")

model = mymodels.spConvnet_subM(shape = grid_shape ).to(device)
print(model)
# Out:
# Using cuda device
# spConvnet_subM(
#   (net): SparseSequential(
#     (0): SubMConv3d(1, 32, kernel_size=[7, 7, 7], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (1): ReLU()
#     (2): SubMConv3d(32, 40, kernel_size=[5, 5, 5], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (3): ReLU()
#     (4): SparseConv3d(40, 50, kernel_size=[6, 6, 6], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (5): ReLU()
#     (6): SparseMaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], algo=ConvAlgo.MaskImplicitGemm)
#     (7): SparseConv3d(50, 30, kernel_size=[3, 3, 3], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.MaskImplicitGemm)
#     (8): ReLU()
#     (9): SparseConv3d(30, 10, kernel_size=[3, 3, 3], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.MaskImplicitGemm)
#     (10): ReLU()
#     (11): SparseMaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], algo=ConvAlgo.MaskImplicitGemm)
#     (12): ToDense()
#   )
#   (fc1): Linear(in_features=2160, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=60, bias=True)
#   (fc3): Linear(in_features=60, out_features=20, bias=True)
#   (fc4): Linear(in_features=20, out_features=3, bias=True)
# )

# %% [markdown]
# # Train the model

# %%
# Specify optimizer
optimizer = torch.optim.Adam(params = model.parameters(), lr=0.0001, betas=(0.94, 0.999), eps=1e-07)

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 2

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 1000
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train(train_dataloader, model, mytools.CSloss, optimizer, device))
    Validation_losses = np.append(Validation_losses, mytools.validate(val_dataloader, model, mytools.CSloss, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_model = copy.deepcopy(model)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Current batch training loss: -0.038607  [    0/2213439]
# Current batch training loss: -0.200693  [25600/2213439]
# Current batch training loss: -0.374399  [51200/2213439]
# Current batch training loss: -0.499057  [76800/2213439]
# Current batch training loss: -0.476188  [102400/2213439]
# Current batch training loss: -0.442318  [128000/2213439]
# Current batch training loss: -0.520935  [153600/2213439]
# Current batch training loss: -0.566553  [179200/2213439]
# Current batch training loss: -0.499829  [204800/2213439]
# Current batch training loss: -0.527794  [230400/2213439]
# Current batch training loss: -0.560439  [256000/2213439]
# Current batch training loss: -0.549180  [281600/2213439]
# Current batch training loss: -0.546777  [307200/2213439]
# Current batch training loss: -0.602297  [332800/2213439]
# Current batch training loss: -0.582130  [358400/2213439]
# Current batch training loss: -0.623816  [384000/2213439]
# Current batch training loss: -0.604584  [409600/2213439]
# Current batch training loss: -0.555753  [435200/2213439]
# Current batch training loss: -0.653123  [460800/2213439]
# Current batch training loss: -0.657065  [486400/2213439]
# Current batch training loss: -0.599262  [512000/2213439]
# Current batch training loss: -0.641870  [537600/2213439]
# Current batch training loss: -0.693924  [563200/2213439]
# Current batch training loss: -0.710541  [588800/2213439]
# Current batch training loss: -0.662064  [614400/2213439]
# Current batch training loss: -0.750605  [640000/2213439]
# Current batch training loss: -0.718515  [665600/2213439]
# Current batch training loss: -0.721748  [691200/2213439]
# Current batch training loss: -0.729919  [716800/2213439]
# Current batch training loss: -0.734712  [742400/2213439]
# Current batch training loss: -0.763842  [768000/2213439]
# Current batch training loss: -0.742936  [793600/2213439]
# Current batch training loss: -0.754918  [819200/2213439]
# Current batch training loss: -0.758668  [844800/2213439]
# Current batch training loss: -0.761058  [870400/2213439]
# Current batch training loss: -0.779402  [896000/2213439]
# Current batch training loss: -0.783309  [921600/2213439]
# Current batch training loss: -0.778416  [947200/2213439]
# Current batch training loss: -0.781173  [972800/2213439]
# Current batch training loss: -0.782391  [998400/2213439]
# Current batch training loss: -0.801317  [1024000/2213439]
# Current batch training loss: -0.812020  [1049600/2213439]
# Current batch training loss: -0.802152  [1075200/2213439]
# Current batch training loss: -0.816561  [1100800/2213439]
# Current batch training loss: -0.842520  [1126400/2213439]
# Current batch training loss: -0.810218  [1152000/2213439]
# Current batch training loss: -0.810487  [1177600/2213439]
# Current batch training loss: -0.814184  [1203200/2213439]
# Current batch training loss: -0.827932  [1228800/2213439]
# Current batch training loss: -0.813444  [1254400/2213439]
# Current batch training loss: -0.837074  [1280000/2213439]
# Current batch training loss: -0.843956  [1305600/2213439]
# Current batch training loss: -0.833748  [1331200/2213439]
# Current batch training loss: -0.846016  [1356800/2213439]
# Current batch training loss: -0.834230  [1382400/2213439]
# Current batch training loss: -0.824927  [1408000/2213439]
# Current batch training loss: -0.879244  [1433600/2213439]
# Current batch training loss: -0.856717  [1459200/2213439]
# Current batch training loss: -0.829962  [1484800/2213439]
# Current batch training loss: -0.870035  [1510400/2213439]
# Current batch training loss: -0.821007  [1536000/2213439]
# Current batch training loss: -0.837973  [1561600/2213439]
# Current batch training loss: -0.836692  [1587200/2213439]
# Current batch training loss: -0.845055  [1612800/2213439]
# Current batch training loss: -0.869889  [1638400/2213439]
# Current batch training loss: -0.834312  [1664000/2213439]
# Current batch training loss: -0.854628  [1689600/2213439]
# Current batch training loss: -0.838305  [1715200/2213439]
# Current batch training loss: -0.851917  [1740800/2213439]
# Current batch training loss: -0.875787  [1766400/2213439]
# Current batch training loss: -0.873590  [1792000/2213439]
# Current batch training loss: -0.876891  [1817600/2213439]
# Current batch training loss: -0.885229  [1843200/2213439]
# Current batch training loss: -0.844901  [1868800/2213439]
# Current batch training loss: -0.854580  [1894400/2213439]
# Current batch training loss: -0.827057  [1920000/2213439]
# Current batch training loss: -0.874016  [1945600/2213439]
# Current batch training loss: -0.868508  [1971200/2213439]
# Current batch training loss: -0.827923  [1996800/2213439]
# Current batch training loss: -0.886851  [2022400/2213439]
# Current batch training loss: -0.866871  [2048000/2213439]
# Current batch training loss: -0.851865  [2073600/2213439]
# Current batch training loss: -0.881279  [2099200/2213439]
# Current batch training loss: -0.871182  [2124800/2213439]
# Current batch training loss: -0.863271  [2150400/2213439]
# Current batch training loss: -0.868981  [2176000/2213439]
# Current batch training loss: -0.886892  [2201600/2213439]
# Training loss: -0.745491
# Validation loss: -0.874451
#
# Epoch 2
# -------------------------------
# Current batch training loss: -0.871060  [    0/2213439]
# Current batch training loss: -0.904845  [25600/2213439]
# Current batch training loss: -0.868711  [51200/2213439]
# Current batch training loss: -0.869998  [76800/2213439]
# Current batch training loss: -0.859043  [102400/2213439]
# Current batch training loss: -0.885256  [128000/2213439]
# Current batch training loss: -0.906212  [153600/2213439]
# Current batch training loss: -0.884934  [179200/2213439]
# Current batch training loss: -0.865517  [204800/2213439]
# Current batch training loss: -0.893624  [230400/2213439]
# Current batch training loss: -0.880679  [256000/2213439]
# Current batch training loss: -0.877257  [281600/2213439]
# Current batch training loss: -0.871154  [307200/2213439]
# Current batch training loss: -0.879326  [332800/2213439]
# Current batch training loss: -0.880499  [358400/2213439]
# Current batch training loss: -0.896279  [384000/2213439]
# Current batch training loss: -0.890332  [409600/2213439]
# Current batch training loss: -0.895953  [435200/2213439]
# Current batch training loss: -0.890002  [460800/2213439]
# Current batch training loss: -0.894517  [486400/2213439]
# Current batch training loss: -0.853457  [512000/2213439]
# Current batch training loss: -0.880383  [537600/2213439]
# Current batch training loss: -0.888096  [563200/2213439]
# Current batch training loss: -0.889118  [588800/2213439]
# Current batch training loss: -0.891706  [614400/2213439]
# Current batch training loss: -0.907602  [640000/2213439]
# Current batch training loss: -0.893309  [665600/2213439]
# Current batch training loss: -0.894220  [691200/2213439]
# Current batch training loss: -0.906264  [716800/2213439]
# Current batch training loss: -0.882287  [742400/2213439]
# Current batch training loss: -0.901682  [768000/2213439]
# Current batch training loss: -0.899859  [793600/2213439]
# Current batch training loss: -0.897686  [819200/2213439]
# Current batch training loss: -0.884357  [844800/2213439]
# Current batch training loss: -0.900912  [870400/2213439]
# Current batch training loss: -0.904054  [896000/2213439]
# Current batch training loss: -0.901210  [921600/2213439]
# Current batch training loss: -0.895366  [947200/2213439]
# Current batch training loss: -0.903836  [972800/2213439]
# Current batch training loss: -0.908331  [998400/2213439]
# Current batch training loss: -0.920886  [1024000/2213439]
# Current batch training loss: -0.913179  [1049600/2213439]
# Current batch training loss: -0.889181  [1075200/2213439]
# Current batch training loss: -0.914619  [1100800/2213439]
# Current batch training loss: -0.899277  [1126400/2213439]
# Current batch training loss: -0.904088  [1152000/2213439]
# Current batch training loss: -0.888990  [1177600/2213439]
# Current batch training loss: -0.903412  [1203200/2213439]
# Current batch training loss: -0.926493  [1228800/2213439]
# Current batch training loss: -0.898601  [1254400/2213439]
# Current batch training loss: -0.891829  [1280000/2213439]
# Current batch training loss: -0.908364  [1305600/2213439]
# Current batch training loss: -0.887068  [1331200/2213439]
# Current batch training loss: -0.906397  [1356800/2213439]
# Current batch training loss: -0.910512  [1382400/2213439]
# Current batch training loss: -0.911922  [1408000/2213439]
# Current batch training loss: -0.897691  [1433600/2213439]
# Current batch training loss: -0.914795  [1459200/2213439]
# Current batch training loss: -0.903539  [1484800/2213439]
# Current batch training loss: -0.907242  [1510400/2213439]
# Current batch training loss: -0.917603  [1536000/2213439]
# Current batch training loss: -0.924191  [1561600/2213439]
# Current batch training loss: -0.904394  [1587200/2213439]
# Current batch training loss: -0.889409  [1612800/2213439]
# Current batch training loss: -0.911912  [1638400/2213439]
# Current batch training loss: -0.926858  [1664000/2213439]
# Current batch training loss: -0.893616  [1689600/2213439]
# Current batch training loss: -0.891250  [1715200/2213439]
# Current batch training loss: -0.925153  [1740800/2213439]
# Current batch training loss: -0.921129  [1766400/2213439]
# Current batch training loss: -0.888748  [1792000/2213439]
# Current batch training loss: -0.917301  [1817600/2213439]
# Current batch training loss: -0.877737  [1843200/2213439]
# Current batch training loss: -0.877287  [1868800/2213439]
# Current batch training loss: -0.908163  [1894400/2213439]
# Current batch training loss: -0.895065  [1920000/2213439]
# Current batch training loss: -0.927659  [1945600/2213439]
# Current batch training loss: -0.903466  [1971200/2213439]
# Current batch training loss: -0.911325  [1996800/2213439]
# Current batch training loss: -0.910395  [2022400/2213439]
# Current batch training loss: -0.939314  [2048000/2213439]
# Current batch training loss: -0.920613  [2073600/2213439]
# Current batch training loss: -0.900119  [2099200/2213439]
# Current batch training loss: -0.922483  [2124800/2213439]
# Current batch training loss: -0.887089  [2150400/2213439]
# Current batch training loss: -0.906570  [2176000/2213439]
# Current batch training loss: -0.922696  [2201600/2213439]
# Training loss: -0.901273
# Validation loss: -0.911398
#
# Epoch 3
# -------------------------------
# Current batch training loss: -0.917709  [    0/2213439]
# Current batch training loss: -0.898044  [25600/2213439]
# Current batch training loss: -0.914331  [51200/2213439]
# Current batch training loss: -0.917629  [76800/2213439]
# Current batch training loss: -0.917171  [102400/2213439]
# Current batch training loss: -0.919284  [128000/2213439]
# Current batch training loss: -0.925227  [153600/2213439]
# Current batch training loss: -0.905523  [179200/2213439]
# Current batch training loss: -0.918368  [204800/2213439]
# Current batch training loss: -0.914581  [230400/2213439]
# Current batch training loss: -0.898172  [256000/2213439]
# Current batch training loss: -0.917200  [281600/2213439]
# Current batch training loss: -0.905942  [307200/2213439]
# Current batch training loss: -0.937351  [332800/2213439]
# Current batch training loss: -0.923677  [358400/2213439]
# Current batch training loss: -0.915817  [384000/2213439]
# Current batch training loss: -0.886754  [409600/2213439]
# Current batch training loss: -0.911773  [435200/2213439]
# Current batch training loss: -0.913344  [460800/2213439]
# Current batch training loss: -0.910527  [486400/2213439]
# Current batch training loss: -0.895788  [512000/2213439]
# Current batch training loss: -0.907462  [537600/2213439]
# Current batch training loss: -0.920100  [563200/2213439]
# Current batch training loss: -0.901070  [588800/2213439]
# Current batch training loss: -0.911238  [614400/2213439]
# Current batch training loss: -0.925342  [640000/2213439]
# Current batch training loss: -0.905365  [665600/2213439]
# Current batch training loss: -0.919991  [691200/2213439]
# Current batch training loss: -0.929807  [716800/2213439]
# Current batch training loss: -0.925063  [742400/2213439]
# Current batch training loss: -0.935335  [768000/2213439]
# Current batch training loss: -0.919597  [793600/2213439]
# Current batch training loss: -0.911145  [819200/2213439]
# Current batch training loss: -0.923109  [844800/2213439]
# Current batch training loss: -0.935621  [870400/2213439]
# Current batch training loss: -0.904294  [896000/2213439]
# Current batch training loss: -0.901582  [921600/2213439]
# Current batch training loss: -0.908825  [947200/2213439]
# Current batch training loss: -0.914512  [972800/2213439]
# Current batch training loss: -0.929959  [998400/2213439]
# Current batch training loss: -0.920056  [1024000/2213439]
# Current batch training loss: -0.914916  [1049600/2213439]
# Current batch training loss: -0.916756  [1075200/2213439]
# Current batch training loss: -0.930718  [1100800/2213439]
# Current batch training loss: -0.927530  [1126400/2213439]
# Current batch training loss: -0.906820  [1152000/2213439]
# Current batch training loss: -0.933248  [1177600/2213439]
# Current batch training loss: -0.911751  [1203200/2213439]
# Current batch training loss: -0.923648  [1228800/2213439]
# Current batch training loss: -0.904885  [1254400/2213439]
# Current batch training loss: -0.906484  [1280000/2213439]
# Current batch training loss: -0.901578  [1305600/2213439]
# Current batch training loss: -0.898381  [1331200/2213439]
# Current batch training loss: -0.915030  [1356800/2213439]
# Current batch training loss: -0.913526  [1382400/2213439]
# Current batch training loss: -0.903604  [1408000/2213439]
# Current batch training loss: -0.920973  [1433600/2213439]
# Current batch training loss: -0.934297  [1459200/2213439]
# Current batch training loss: -0.912741  [1484800/2213439]
# Current batch training loss: -0.924891  [1510400/2213439]
# Current batch training loss: -0.923373  [1536000/2213439]
# Current batch training loss: -0.933323  [1561600/2213439]
# Current batch training loss: -0.933307  [1587200/2213439]
# Current batch training loss: -0.926322  [1612800/2213439]
# Current batch training loss: -0.915964  [1638400/2213439]
# Current batch training loss: -0.928654  [1664000/2213439]
# Current batch training loss: -0.929643  [1689600/2213439]
# Current batch training loss: -0.929313  [1715200/2213439]
# Current batch training loss: -0.939446  [1740800/2213439]
# Current batch training loss: -0.904353  [1766400/2213439]
# Current batch training loss: -0.902941  [1792000/2213439]
# Current batch training loss: -0.931203  [1817600/2213439]
# Current batch training loss: -0.933630  [1843200/2213439]
# Current batch training loss: -0.931987  [1868800/2213439]
# Current batch training loss: -0.922185  [1894400/2213439]
# Current batch training loss: -0.922003  [1920000/2213439]
# Current batch training loss: -0.916413  [1945600/2213439]
# Current batch training loss: -0.926723  [1971200/2213439]
# Current batch training loss: -0.910471  [1996800/2213439]
# Current batch training loss: -0.915308  [2022400/2213439]
# Current batch training loss: -0.907492  [2048000/2213439]
# Current batch training loss: -0.923101  [2073600/2213439]
# Current batch training loss: -0.916270  [2099200/2213439]
# Current batch training loss: -0.916320  [2124800/2213439]
# Current batch training loss: -0.918172  [2150400/2213439]
# Current batch training loss: -0.900844  [2176000/2213439]
# Current batch training loss: -0.915992  [2201600/2213439]
# Training loss: -0.915936
# Validation loss: -0.915491
#
# Epoch 4
# -------------------------------
# Current batch training loss: -0.931686  [    0/2213439]
# Current batch training loss: -0.926929  [25600/2213439]
# Current batch training loss: -0.932413  [51200/2213439]
# Current batch training loss: -0.925574  [76800/2213439]
# Current batch training loss: -0.916853  [102400/2213439]
# Current batch training loss: -0.903216  [128000/2213439]
# Current batch training loss: -0.923583  [153600/2213439]
# Current batch training loss: -0.923145  [179200/2213439]
# Current batch training loss: -0.911309  [204800/2213439]
# Current batch training loss: -0.898722  [230400/2213439]
# Current batch training loss: -0.900949  [256000/2213439]
# Current batch training loss: -0.920035  [281600/2213439]
# Current batch training loss: -0.903809  [307200/2213439]
# Current batch training loss: -0.919333  [332800/2213439]
# Current batch training loss: -0.933735  [358400/2213439]
# Current batch training loss: -0.918313  [384000/2213439]
# Current batch training loss: -0.927544  [409600/2213439]
# Current batch training loss: -0.924443  [435200/2213439]
# Current batch training loss: -0.927324  [460800/2213439]
# Current batch training loss: -0.898979  [486400/2213439]
# Current batch training loss: -0.919848  [512000/2213439]
# Current batch training loss: -0.905809  [537600/2213439]
# Current batch training loss: -0.917405  [563200/2213439]
# Current batch training loss: -0.913414  [588800/2213439]
# Current batch training loss: -0.902836  [614400/2213439]
# Current batch training loss: -0.930035  [640000/2213439]
# Current batch training loss: -0.902760  [665600/2213439]
# Current batch training loss: -0.933733  [691200/2213439]
# Current batch training loss: -0.927796  [716800/2213439]
# Current batch training loss: -0.922749  [742400/2213439]
# Current batch training loss: -0.917290  [768000/2213439]
# Current batch training loss: -0.886056  [793600/2213439]
# Current batch training loss: -0.930659  [819200/2213439]
# Current batch training loss: -0.915961  [844800/2213439]
# Current batch training loss: -0.932990  [870400/2213439]
# Current batch training loss: -0.915970  [896000/2213439]
# Current batch training loss: -0.916014  [921600/2213439]
# Current batch training loss: -0.920777  [947200/2213439]
# Current batch training loss: -0.928982  [972800/2213439]
# Current batch training loss: -0.940657  [998400/2213439]
# Current batch training loss: -0.918405  [1024000/2213439]
# Current batch training loss: -0.928988  [1049600/2213439]
# Current batch training loss: -0.930882  [1075200/2213439]
# Current batch training loss: -0.926459  [1100800/2213439]
# Current batch training loss: -0.931643  [1126400/2213439]
# Current batch training loss: -0.923695  [1152000/2213439]
# Current batch training loss: -0.916946  [1177600/2213439]
# Current batch training loss: -0.920762  [1203200/2213439]
# Current batch training loss: -0.936455  [1228800/2213439]
# Current batch training loss: -0.934596  [1254400/2213439]
# Current batch training loss: -0.892279  [1280000/2213439]
# Current batch training loss: -0.928472  [1305600/2213439]
# Current batch training loss: -0.932505  [1331200/2213439]
# Current batch training loss: -0.918728  [1356800/2213439]
# Current batch training loss: -0.902512  [1382400/2213439]
# Current batch training loss: -0.922195  [1408000/2213439]
# Current batch training loss: -0.923644  [1433600/2213439]
# Current batch training loss: -0.916034  [1459200/2213439]
# Current batch training loss: -0.902393  [1484800/2213439]
# Current batch training loss: -0.912387  [1510400/2213439]
# Current batch training loss: -0.922189  [1536000/2213439]
# Current batch training loss: -0.922959  [1561600/2213439]
# Current batch training loss: -0.924590  [1587200/2213439]
# Current batch training loss: -0.914396  [1612800/2213439]
# Current batch training loss: -0.926565  [1638400/2213439]
# Current batch training loss: -0.925536  [1664000/2213439]
# Current batch training loss: -0.936130  [1689600/2213439]
# Current batch training loss: -0.913664  [1715200/2213439]
# Current batch training loss: -0.911174  [1740800/2213439]
# Current batch training loss: -0.930143  [1766400/2213439]
# Current batch training loss: -0.927695  [1792000/2213439]
# Current batch training loss: -0.904075  [1817600/2213439]
# Current batch training loss: -0.904116  [1843200/2213439]
# Current batch training loss: -0.926322  [1868800/2213439]
# Current batch training loss: -0.898205  [1894400/2213439]
# Current batch training loss: -0.916996  [1920000/2213439]
# Current batch training loss: -0.916856  [1945600/2213439]
# Current batch training loss: -0.934895  [1971200/2213439]
# Current batch training loss: -0.903087  [1996800/2213439]
# Current batch training loss: -0.925014  [2022400/2213439]
# Current batch training loss: -0.917106  [2048000/2213439]
# Current batch training loss: -0.923487  [2073600/2213439]
# Current batch training loss: -0.918207  [2099200/2213439]
# Current batch training loss: -0.928513  [2124800/2213439]
# Current batch training loss: -0.938251  [2150400/2213439]
# Current batch training loss: -0.916277  [2176000/2213439]
# Current batch training loss: -0.913560  [2201600/2213439]
# Training loss: -0.919685
# Validation loss: -0.918249
#
# Epoch 5
# -------------------------------
# Current batch training loss: -0.935963  [    0/2213439]
# Current batch training loss: -0.910613  [25600/2213439]
# Current batch training loss: -0.905540  [51200/2213439]
# Current batch training loss: -0.901492  [76800/2213439]
# Current batch training loss: -0.935706  [102400/2213439]
# Current batch training loss: -0.933412  [128000/2213439]
# Current batch training loss: -0.910633  [153600/2213439]
# Current batch training loss: -0.921817  [179200/2213439]
# Current batch training loss: -0.916224  [204800/2213439]
# Current batch training loss: -0.915033  [230400/2213439]
# Current batch training loss: -0.920246  [256000/2213439]
# Current batch training loss: -0.913878  [281600/2213439]
# Current batch training loss: -0.933725  [307200/2213439]
# Current batch training loss: -0.926542  [332800/2213439]
# Current batch training loss: -0.931587  [358400/2213439]
# Current batch training loss: -0.917935  [384000/2213439]
# Current batch training loss: -0.916178  [409600/2213439]
# Current batch training loss: -0.929713  [435200/2213439]
# Current batch training loss: -0.913347  [460800/2213439]
# Current batch training loss: -0.912310  [486400/2213439]
# Current batch training loss: -0.935641  [512000/2213439]
# Current batch training loss: -0.929777  [537600/2213439]
# Current batch training loss: -0.932015  [563200/2213439]
# Current batch training loss: -0.935772  [588800/2213439]
# Current batch training loss: -0.940577  [614400/2213439]
# Current batch training loss: -0.921222  [640000/2213439]
# Current batch training loss: -0.923411  [665600/2213439]
# Current batch training loss: -0.917159  [691200/2213439]
# Current batch training loss: -0.915913  [716800/2213439]
# Current batch training loss: -0.941058  [742400/2213439]
# Current batch training loss: -0.912982  [768000/2213439]
# Current batch training loss: -0.913154  [793600/2213439]
# Current batch training loss: -0.921328  [819200/2213439]
# Current batch training loss: -0.921258  [844800/2213439]
# Current batch training loss: -0.919963  [870400/2213439]
# Current batch training loss: -0.922364  [896000/2213439]
# Current batch training loss: -0.927428  [921600/2213439]
# Current batch training loss: -0.920164  [947200/2213439]
# Current batch training loss: -0.916973  [972800/2213439]
# Current batch training loss: -0.904869  [998400/2213439]
# Current batch training loss: -0.922682  [1024000/2213439]
# Current batch training loss: -0.907364  [1049600/2213439]
# Current batch training loss: -0.918736  [1075200/2213439]
# Current batch training loss: -0.914196  [1100800/2213439]
# Current batch training loss: -0.916500  [1126400/2213439]
# Current batch training loss: -0.912793  [1152000/2213439]
# Current batch training loss: -0.922744  [1177600/2213439]
# Current batch training loss: -0.909836  [1203200/2213439]
# Current batch training loss: -0.911318  [1228800/2213439]
# Current batch training loss: -0.919968  [1254400/2213439]
# Current batch training loss: -0.918995  [1280000/2213439]
# Current batch training loss: -0.906153  [1305600/2213439]
# Current batch training loss: -0.909559  [1331200/2213439]
# Current batch training loss: -0.904407  [1356800/2213439]
# Current batch training loss: -0.924132  [1382400/2213439]
# Current batch training loss: -0.936041  [1408000/2213439]
# Current batch training loss: -0.907096  [1433600/2213439]
# Current batch training loss: -0.911710  [1459200/2213439]
# Current batch training loss: -0.933204  [1484800/2213439]
# Current batch training loss: -0.922202  [1510400/2213439]
# Current batch training loss: -0.923962  [1536000/2213439]
# Current batch training loss: -0.941062  [1561600/2213439]
# Current batch training loss: -0.922246  [1587200/2213439]
# Current batch training loss: -0.926914  [1612800/2213439]
# Current batch training loss: -0.919423  [1638400/2213439]
# Current batch training loss: -0.934308  [1664000/2213439]
# Current batch training loss: -0.912961  [1689600/2213439]
# Current batch training loss: -0.928119  [1715200/2213439]
# Current batch training loss: -0.919667  [1740800/2213439]
# Current batch training loss: -0.951235  [1766400/2213439]
# Current batch training loss: -0.919462  [1792000/2213439]
# Current batch training loss: -0.905764  [1817600/2213439]
# Current batch training loss: -0.929705  [1843200/2213439]
# Current batch training loss: -0.906588  [1868800/2213439]
# Current batch training loss: -0.919629  [1894400/2213439]
# Current batch training loss: -0.902135  [1920000/2213439]
# Current batch training loss: -0.934923  [1945600/2213439]
# Current batch training loss: -0.911339  [1971200/2213439]
# Current batch training loss: -0.926244  [1996800/2213439]
# Current batch training loss: -0.932996  [2022400/2213439]
# Current batch training loss: -0.939433  [2048000/2213439]
# Current batch training loss: -0.933040  [2073600/2213439]
# Current batch training loss: -0.920749  [2099200/2213439]
# Current batch training loss: -0.915108  [2124800/2213439]
# Current batch training loss: -0.947157  [2150400/2213439]
# Current batch training loss: -0.926769  [2176000/2213439]
# Current batch training loss: -0.915273  [2201600/2213439]
# Training loss: -0.922005
# Validation loss: -0.919670
#
# Epoch 6
# -------------------------------
# Current batch training loss: -0.924746  [    0/2213439]
# Current batch training loss: -0.918819  [25600/2213439]
# Current batch training loss: -0.923517  [51200/2213439]
# Current batch training loss: -0.927612  [76800/2213439]
# Current batch training loss: -0.923082  [102400/2213439]
# Current batch training loss: -0.920365  [128000/2213439]
# Current batch training loss: -0.927805  [153600/2213439]
# Current batch training loss: -0.926016  [179200/2213439]
# Current batch training loss: -0.910686  [204800/2213439]
# Current batch training loss: -0.942559  [230400/2213439]
# Current batch training loss: -0.932903  [256000/2213439]
# Current batch training loss: -0.906691  [281600/2213439]
# Current batch training loss: -0.920486  [307200/2213439]
# Current batch training loss: -0.916484  [332800/2213439]
# Current batch training loss: -0.937074  [358400/2213439]
# Current batch training loss: -0.921195  [384000/2213439]
# Current batch training loss: -0.935997  [409600/2213439]
# Current batch training loss: -0.934283  [435200/2213439]
# Current batch training loss: -0.912580  [460800/2213439]
# Current batch training loss: -0.922936  [486400/2213439]
# Current batch training loss: -0.912740  [512000/2213439]
# Current batch training loss: -0.934498  [537600/2213439]
# Current batch training loss: -0.924278  [563200/2213439]
# Current batch training loss: -0.930204  [588800/2213439]
# Current batch training loss: -0.915415  [614400/2213439]
# Current batch training loss: -0.929086  [640000/2213439]
# Current batch training loss: -0.931513  [665600/2213439]
# Current batch training loss: -0.912755  [691200/2213439]
# Current batch training loss: -0.917118  [716800/2213439]
# Current batch training loss: -0.939342  [742400/2213439]
# Current batch training loss: -0.917448  [768000/2213439]
# Current batch training loss: -0.923619  [793600/2213439]
# Current batch training loss: -0.917048  [819200/2213439]
# Current batch training loss: -0.930279  [844800/2213439]
# Current batch training loss: -0.933843  [870400/2213439]
# Current batch training loss: -0.935102  [896000/2213439]
# Current batch training loss: -0.941828  [921600/2213439]
# Current batch training loss: -0.934036  [947200/2213439]
# Current batch training loss: -0.919409  [972800/2213439]
# Current batch training loss: -0.915708  [998400/2213439]
# Current batch training loss: -0.902204  [1024000/2213439]
# Current batch training loss: -0.945531  [1049600/2213439]
# Current batch training loss: -0.930405  [1075200/2213439]
# Current batch training loss: -0.925431  [1100800/2213439]
# Current batch training loss: -0.934930  [1126400/2213439]
# Current batch training loss: -0.947609  [1152000/2213439]
# Current batch training loss: -0.912052  [1177600/2213439]
# Current batch training loss: -0.928303  [1203200/2213439]
# Current batch training loss: -0.925771  [1228800/2213439]
# Current batch training loss: -0.914999  [1254400/2213439]
# Current batch training loss: -0.929390  [1280000/2213439]
# Current batch training loss: -0.907537  [1305600/2213439]
# Current batch training loss: -0.933930  [1331200/2213439]
# Current batch training loss: -0.909112  [1356800/2213439]
# Current batch training loss: -0.925395  [1382400/2213439]
# Current batch training loss: -0.930050  [1408000/2213439]
# Current batch training loss: -0.923184  [1433600/2213439]
# Current batch training loss: -0.943765  [1459200/2213439]
# Current batch training loss: -0.914379  [1484800/2213439]
# Current batch training loss: -0.922783  [1510400/2213439]
# Current batch training loss: -0.910775  [1536000/2213439]
# Current batch training loss: -0.930319  [1561600/2213439]
# Current batch training loss: -0.931134  [1587200/2213439]
# Current batch training loss: -0.917311  [1612800/2213439]
# Current batch training loss: -0.933209  [1638400/2213439]
# Current batch training loss: -0.937188  [1664000/2213439]
# Current batch training loss: -0.925925  [1689600/2213439]
# Current batch training loss: -0.928452  [1715200/2213439]
# Current batch training loss: -0.917293  [1740800/2213439]
# Current batch training loss: -0.936417  [1766400/2213439]
# Current batch training loss: -0.942922  [1792000/2213439]
# Current batch training loss: -0.930742  [1817600/2213439]
# Current batch training loss: -0.930821  [1843200/2213439]
# Current batch training loss: -0.919804  [1868800/2213439]
# Current batch training loss: -0.927010  [1894400/2213439]
# Current batch training loss: -0.916111  [1920000/2213439]
# Current batch training loss: -0.915588  [1945600/2213439]
# Current batch training loss: -0.937132  [1971200/2213439]
# Current batch training loss: -0.930784  [1996800/2213439]
# Current batch training loss: -0.922925  [2022400/2213439]
# Current batch training loss: -0.913184  [2048000/2213439]
# Current batch training loss: -0.908273  [2073600/2213439]
# Current batch training loss: -0.891985  [2099200/2213439]
# Current batch training loss: -0.897863  [2124800/2213439]
# Current batch training loss: -0.911709  [2150400/2213439]
# Current batch training loss: -0.916544  [2176000/2213439]
# Current batch training loss: -0.938777  [2201600/2213439]
# Training loss: -0.923731
# Validation loss: -0.919980
#
# Epoch 7
# -------------------------------
# Current batch training loss: -0.915943  [    0/2213439]
# Current batch training loss: -0.932355  [25600/2213439]
# Current batch training loss: -0.930860  [51200/2213439]
# Current batch training loss: -0.921196  [76800/2213439]
# Current batch training loss: -0.905941  [102400/2213439]
# Current batch training loss: -0.928779  [128000/2213439]
# Current batch training loss: -0.917888  [153600/2213439]
# Current batch training loss: -0.932076  [179200/2213439]
# Current batch training loss: -0.933933  [204800/2213439]
# Current batch training loss: -0.921789  [230400/2213439]
# Current batch training loss: -0.926311  [256000/2213439]
# Current batch training loss: -0.925447  [281600/2213439]
# Current batch training loss: -0.897665  [307200/2213439]
# Current batch training loss: -0.933582  [332800/2213439]
# Current batch training loss: -0.924363  [358400/2213439]
# Current batch training loss: -0.928605  [384000/2213439]
# Current batch training loss: -0.909634  [409600/2213439]
# Current batch training loss: -0.934257  [435200/2213439]
# Current batch training loss: -0.927449  [460800/2213439]
# Current batch training loss: -0.920622  [486400/2213439]
# Current batch training loss: -0.924741  [512000/2213439]
# Current batch training loss: -0.934419  [537600/2213439]
# Current batch training loss: -0.931251  [563200/2213439]
# Current batch training loss: -0.938271  [588800/2213439]
# Current batch training loss: -0.923620  [614400/2213439]
# Current batch training loss: -0.936606  [640000/2213439]
# Current batch training loss: -0.916509  [665600/2213439]
# Current batch training loss: -0.939886  [691200/2213439]
# Current batch training loss: -0.919861  [716800/2213439]
# Current batch training loss: -0.932304  [742400/2213439]
# Current batch training loss: -0.930045  [768000/2213439]
# Current batch training loss: -0.911574  [793600/2213439]
# Current batch training loss: -0.932876  [819200/2213439]
# Current batch training loss: -0.924190  [844800/2213439]
# Current batch training loss: -0.931218  [870400/2213439]
# Current batch training loss: -0.930804  [896000/2213439]
# Current batch training loss: -0.922806  [921600/2213439]
# Current batch training loss: -0.942540  [947200/2213439]
# Current batch training loss: -0.914414  [972800/2213439]
# Current batch training loss: -0.939932  [998400/2213439]
# Current batch training loss: -0.923542  [1024000/2213439]
# Current batch training loss: -0.922956  [1049600/2213439]
# Current batch training loss: -0.926615  [1075200/2213439]
# Current batch training loss: -0.940260  [1100800/2213439]
# Current batch training loss: -0.923274  [1126400/2213439]
# Current batch training loss: -0.924954  [1152000/2213439]
# Current batch training loss: -0.934902  [1177600/2213439]
# Current batch training loss: -0.929527  [1203200/2213439]
# Current batch training loss: -0.920384  [1228800/2213439]
# Current batch training loss: -0.936077  [1254400/2213439]
# Current batch training loss: -0.914087  [1280000/2213439]
# Current batch training loss: -0.924827  [1305600/2213439]
# Current batch training loss: -0.935254  [1331200/2213439]
# Current batch training loss: -0.914317  [1356800/2213439]
# Current batch training loss: -0.926269  [1382400/2213439]
# Current batch training loss: -0.941476  [1408000/2213439]
# Current batch training loss: -0.904843  [1433600/2213439]
# Current batch training loss: -0.915008  [1459200/2213439]
# Current batch training loss: -0.926048  [1484800/2213439]
# Current batch training loss: -0.929451  [1510400/2213439]
# Current batch training loss: -0.915524  [1536000/2213439]
# Current batch training loss: -0.926272  [1561600/2213439]
# Current batch training loss: -0.936383  [1587200/2213439]
# Current batch training loss: -0.912320  [1612800/2213439]
# Current batch training loss: -0.942031  [1638400/2213439]
# Current batch training loss: -0.938206  [1664000/2213439]
# Current batch training loss: -0.923998  [1689600/2213439]
# Current batch training loss: -0.939685  [1715200/2213439]
# Current batch training loss: -0.909851  [1740800/2213439]
# Current batch training loss: -0.938789  [1766400/2213439]
# Current batch training loss: -0.927961  [1792000/2213439]
# Current batch training loss: -0.925395  [1817600/2213439]
# Current batch training loss: -0.929790  [1843200/2213439]
# Current batch training loss: -0.937733  [1868800/2213439]
# Current batch training loss: -0.911372  [1894400/2213439]
# Current batch training loss: -0.917983  [1920000/2213439]
# Current batch training loss: -0.921118  [1945600/2213439]
# Current batch training loss: -0.919288  [1971200/2213439]
# Current batch training loss: -0.929015  [1996800/2213439]
# Current batch training loss: -0.912404  [2022400/2213439]
# Current batch training loss: -0.936579  [2048000/2213439]
# Current batch training loss: -0.932666  [2073600/2213439]
# Current batch training loss: -0.926400  [2099200/2213439]
# Current batch training loss: -0.936685  [2124800/2213439]
# Current batch training loss: -0.933126  [2150400/2213439]
# Current batch training loss: -0.948295  [2176000/2213439]
# Current batch training loss: -0.910297  [2201600/2213439]
# Training loss: -0.925134
# Validation loss: -0.917207
#
# Epoch 8
# -------------------------------
# Current batch training loss: -0.935467  [    0/2213439]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 13
#      10 for t in range(epochs):
#      11     print(f"Epoch {t+1}\n-------------------------------")
# ---> 13     Training_losses = np.append(Training_losses, mytools.train(train_dataloader, model, mytools.CSloss, optimizer, device))
#      14     Validation_losses = np.append(Validation_losses, mytools.validate(val_dataloader, model, mytools.CSloss, device))
#      16     # Keep a running copy of the model with the lowest loss
#
# File ~/3D_Heteroscedastic_Convnet/mytools.py:122, in train(dataloader, model, loss_fn, optimizer, device)
#     120 # Backpropagation
#     121 optimizer.zero_grad()
# --> 122 loss.backward()
#     123 optimizer.step()
#     125 train_loss += loss.item()
#
# File ~/.conda/envs/mypt/lib/python3.10/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/.conda/envs/mypt/lib/python3.10/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %% [markdown]
# # Visualize Training

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('Cosine Similarity Loss')
plt.legend()

# %% [markdown]
# # Save the Model

# %%
torch.save(final_model, "../3D_Heteroscedastic_Convnet_models/3D_CNN_subM-256.pt")
print("Saved PyTorch Model State to ../3D_Heteroscedastic_Convnet_models/3D_CNN_subM-256.pt")
# Out:
# Saved PyTorch Model State to ../3D_Heteroscedastic_Convnet_models/3D_CNN_subM-256.pt
