# %%
import numpy as np
import pandas as pd
import torch
import copy
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
from torchvision import datasets
import spconv.pytorch as spconv
import matplotlib.pyplot as plt
import mytools
import mymodels

# %% [markdown]
# # Prepare Data

# %%
# Read pandas dataframe with all information about sparse training tensors
st_info = pd.read_pickle('/home/majd/sparse_training_tensors_test/sparse_tensor_info.pk')
st_info.head()
# Out:
#                                                  dir  \
# 0  [0.026361450114195585, 0.8711186313268745, -0....
# 1  [0.46959426569273266, 0.811740192412494, -0.34...
# 2  [-0.15171981821024536, -0.8855858913527752, 0....
# 3  [0.21180233188851963, 0.08083834636858116, 0.9...
# 4  [0.9167803756423292, -0.39745952868971435, -0....
#
#                                               offset      diff energy
# 0  [0.3281184960483522, -2.4369016024112162, -0.1...  0.017067     50
# 1  [-2.7931684707802567, -2.6652880089994215, -0....  0.039308     50
# 2  [-1.1201619593568408, 2.5015106225271837, 0.26...  0.041201     50
# 3  [1.2717487893835637, -1.7885720595904964, -2.3...  0.018807     50
# 4  [-2.753222599501232, -0.5248287871094732, -0.8...  0.027700     50

# %%
# Make custom dataset
MyDataset = mytools.CustomDataset(dir_loc='/home/majd/sparse_training_tensors_test/', st_info=st_info)

# Split datat into training, validation, and testing sets
train_dataset, val_dataset = torch.utils.data.random_split(MyDataset,[0.8, 0.2], generator=torch.Generator().manual_seed(42))

print("Training samples: ", len(train_dataset))
print("Validation samples: ", len(val_dataset))

# Create training and validation DataLoaders
batch_size = 64
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
# Out:
# Training samples:  131055
# Validation samples:  32763

# %%
# Print tensor shapes
for X_plot, y_plot, offset_plot in train_dataloader:
    print(f"Shape of X [N, C, H, W, D]: {X_plot.shape}")
    print(f"Shape of y: {y_plot.shape} {y_plot.dtype}")
    print("Offsets: ", offset_plot.shape)
    break
# Out:
# Shape of X [N, C, H, W, D]: torch.Size([64, 120, 120, 120, 1])
# Shape of y: torch.Size([64, 3]) torch.float32
# Offsets:  torch.Size([64, 3])

# %%
#Record shape of voxel grid
grid_shape = X_plot.shape[1:4]
print("Voxel grid shape: " , grid_shape)
# Out:
# Voxel grid shape:  torch.Size([120, 120, 120])

# %% [markdown]
# # Visualize a sample

# %%
# Plot an example as a sanity check

# x/y/z length being kept in cm
eff_l = mytools.voxel_grid['eff_l']
# Voxel size in cm
vox_l = mytools.voxel_grid['vox_l']

#Convert to dense, reshape and convert to numpy
X_plot = X_plot.to_dense().reshape(-1, 1, 120, 120, 120).numpy()

index = 2
mytools.plot_tensor_dir(tensor = X_plot[index], start = offset_plot[index].numpy(), direction = y_plot[index].numpy(), eff_l=eff_l, vox_l=vox_l)

# %% [markdown]
# # Initialize Convnet

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Using {device} device")

model = mymodels.spConvnet_HSCDC(shape = grid_shape ).to(device)
print(model)
# Out:
# Using cuda device
# spConvnet_HSCDC(
#   (net): SparseSequential(
#     (0): SparseConv3d(1, 50, kernel_size=[6, 6, 6], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (1): ReLU()
#     (2): SparseMaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], algo=ConvAlgo.MaskImplicitGemm)
#     (3): SparseConv3d(50, 30, kernel_size=[4, 4, 4], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (4): ReLU()
#     (5): SparseConv3d(30, 20, kernel_size=[3, 3, 3], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.MaskImplicitGemm)
#     (6): ReLU()
#     (7): SparseMaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], algo=ConvAlgo.MaskImplicitGemm)
#     (8): ToDense()
#   )
#   (fc1): Linear(in_features=34560, out_features=100, bias=True)
#   (fc2_1): Linear(in_features=100, out_features=30, bias=True)
#   (fc3_1): Linear(in_features=30, out_features=3, bias=True)
#   (fc2_2): Linear(in_features=100, out_features=30, bias=True)
#   (fc3_2): Linear(in_features=30, out_features=1, bias=True)
# )

# %% [markdown]
# # Train the model

# %%
# Specify optimizer
optimizer = torch.optim.Adam(params = model.parameters(), lr=0.0001, betas=(0.94, 0.999), eps=1e-07)

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 2

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 1000
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train(train_dataloader, model, mytools.NLLloss, optimizer, device))
    Validation_losses = np.append(Validation_losses, mytools.validate(val_dataloader, model, mytools.NLLloss, device))
    
    # Keep a running copy of the model with the lowest loss
    # Do not copy the model if loss in nan
    if (Validation_losses[-1] == np.min(Validation_losses)) and (~np.isnan(Validation_losses[-1])):
        final_model = copy.deepcopy(model)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Current batch training loss: 2.600240  [    0/131055]
# Current batch training loss: 2.336635  [ 6400/131055]
# Current batch training loss: 2.394570  [12800/131055]
# Current batch training loss: 2.139461  [19200/131055]
# Current batch training loss: 2.166540  [25600/131055]
# Current batch training loss: 2.213661  [32000/131055]
# Current batch training loss: 2.230722  [38400/131055]
# Current batch training loss: 2.360096  [44800/131055]
# Current batch training loss: 2.019103  [51200/131055]
# Current batch training loss: 2.089268  [57600/131055]
# Current batch training loss: 2.148362  [64000/131055]
# Current batch training loss: 2.026295  [70400/131055]
# Current batch training loss: 2.286670  [76800/131055]
# Current batch training loss: 2.065527  [83200/131055]
# Current batch training loss: 2.166465  [89600/131055]
# Current batch training loss: 1.823326  [96000/131055]
# Current batch training loss: 1.844274  [102400/131055]
# Current batch training loss: 2.086184  [108800/131055]
# Current batch training loss: 1.710597  [115200/131055]
# Current batch training loss: 2.014978  [121600/131055]
# Current batch training loss: 1.933392  [128000/131055]
# Training loss: 2.128592
# Validation loss: 1.911890
#
# Epoch 2
# -------------------------------
# Current batch training loss: 1.958985  [    0/131055]
# Current batch training loss: 2.128193  [ 6400/131055]
# Current batch training loss: 1.681385  [12800/131055]
# Current batch training loss: 1.724146  [19200/131055]
# Current batch training loss: 1.583916  [25600/131055]
# Current batch training loss: 1.977612  [32000/131055]
# Current batch training loss: 1.778175  [38400/131055]
# Current batch training loss: 1.682880  [44800/131055]
# Current batch training loss: 1.429199  [51200/131055]
# Current batch training loss: 1.654035  [57600/131055]
# Current batch training loss: 1.694388  [64000/131055]
# Current batch training loss: 1.802958  [70400/131055]
# Current batch training loss: 1.848205  [76800/131055]
# Current batch training loss: 1.548050  [83200/131055]
# Current batch training loss: 1.616850  [89600/131055]
# Current batch training loss: 1.585664  [96000/131055]
# Current batch training loss: 1.662944  [102400/131055]
# Current batch training loss: 1.696543  [108800/131055]
# Current batch training loss: 1.748137  [115200/131055]
# Current batch training loss: 1.754350  [121600/131055]
# Current batch training loss: 1.737020  [128000/131055]
# Training loss: 1.718429
# Validation loss: 1.588926
#
# Epoch 3
# -------------------------------
# Current batch training loss: 1.591196  [    0/131055]
# Current batch training loss: 1.405835  [ 6400/131055]
# Current batch training loss: 1.645989  [12800/131055]
# Current batch training loss: 1.632151  [19200/131055]
# Current batch training loss: 1.644214  [25600/131055]
# Current batch training loss: 1.302601  [32000/131055]
# Current batch training loss: 1.480929  [38400/131055]
# Current batch training loss: 1.269685  [44800/131055]
# Current batch training loss: 1.375489  [51200/131055]
# Current batch training loss: 1.383454  [57600/131055]
# Current batch training loss: 1.493968  [64000/131055]
# Current batch training loss: 1.676216  [70400/131055]
# Current batch training loss: 1.312319  [76800/131055]
# Current batch training loss: 1.385746  [83200/131055]
# Current batch training loss: 1.360863  [89600/131055]
# Current batch training loss: 1.294488  [96000/131055]
# Current batch training loss: 1.263325  [102400/131055]
# Current batch training loss: 1.334499  [108800/131055]
# Current batch training loss: 1.049851  [115200/131055]
# Current batch training loss: 1.439438  [121600/131055]
# Current batch training loss: 1.421707  [128000/131055]
# Training loss: 1.442232
# Validation loss: 1.398360
#
# Epoch 4
# -------------------------------
# Current batch training loss: 1.311249  [    0/131055]
# Current batch training loss: 1.018077  [ 6400/131055]
# Current batch training loss: 1.570015  [12800/131055]
# Current batch training loss: 1.148198  [19200/131055]
# Current batch training loss: 1.429855  [25600/131055]
# Current batch training loss: 1.284148  [32000/131055]
# Current batch training loss: 1.089459  [38400/131055]
# Current batch training loss: 1.321198  [44800/131055]
# Current batch training loss: 1.071028  [51200/131055]
# Current batch training loss: 1.291959  [57600/131055]
# Current batch training loss: 1.055468  [64000/131055]
# Current batch training loss: 1.327941  [70400/131055]
# Current batch training loss: 1.448411  [76800/131055]
# Current batch training loss: 1.479457  [83200/131055]
# Current batch training loss: 1.191251  [89600/131055]
# Current batch training loss: 1.131148  [96000/131055]
# Current batch training loss: 1.028286  [102400/131055]
# Current batch training loss: 1.100455  [108800/131055]
# Current batch training loss: 1.254098  [115200/131055]
# Current batch training loss: 1.109014  [121600/131055]
# Current batch training loss: 0.976891  [128000/131055]
# Training loss: 1.223378
# Validation loss: 1.300320
#
# Epoch 5
# -------------------------------
# Current batch training loss: 0.933375  [    0/131055]
# Current batch training loss: 1.076285  [ 6400/131055]
# Current batch training loss: 1.323989  [12800/131055]
# Current batch training loss: 1.081354  [19200/131055]
# Current batch training loss: 0.921789  [25600/131055]
# Current batch training loss: 1.271609  [32000/131055]
# Current batch training loss: 1.092338  [38400/131055]
# Current batch training loss: 0.831354  [44800/131055]
# Current batch training loss: 1.435863  [51200/131055]
# Current batch training loss: 1.013704  [57600/131055]
# Current batch training loss: 0.877703  [64000/131055]
# Current batch training loss: 1.113582  [70400/131055]
# Current batch training loss: 1.039365  [76800/131055]
# Current batch training loss: 1.019418  [83200/131055]
# Current batch training loss: 1.169937  [89600/131055]
# Current batch training loss: 0.973344  [96000/131055]
# Current batch training loss: 1.214395  [102400/131055]
# Current batch training loss: 1.119021  [108800/131055]
# Current batch training loss: 0.911632  [115200/131055]
# Current batch training loss: 0.972699  [121600/131055]
# Current batch training loss: 1.124921  [128000/131055]
# Training loss: 1.023346
# Validation loss: 1.252486
#
# Done!

# %% [markdown]
# # Visualize Training

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses[~np.isnan(Training_losses)])+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('Negative Log Likelihood Loss')
plt.legend()

# %% [markdown]
# # Save the Model

# %%
torch.save(final_model, "../3D_Heteroscedastic_Convnet_models/3D_HSCDC_CNN_spconv.pt")
print("Saved PyTorch Model State to ../3D_Heteroscedastic_Convnet_models/3D_HSCDC_CNN_spconv.pt")
# Out:
# Saved PyTorch Model State to ../3D_Heteroscedastic_Convnet_models/3D_HSCDC_CNN_spconv.pt
