# %%
import numpy as np
import pandas as pd
import torch
import copy
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
from torchvision import datasets
import spconv.pytorch as spconv
import matplotlib.pyplot as plt
import mytools
import mymodels

# %% [markdown]
# # Prepare Data

# %%
# Read pandas dataframe with all information about sparse training tensors
file_loc = '/mnt/scratch/lustre_01/scratch/majd/sparse_training_tensors/'
st_info = pd.read_pickle(file_loc+'sparse_tensor_info.pk')
st_info
# Out:
#                                                        dir  \
# 0        [0.5923457337920527, -0.5369941830475861, -0.6...
# 1        [-0.6164927192719855, 0.5695943083433039, -0.5...
# 2        [0.6322337566233259, -0.16773581669128113, -0....
# 3        [0.2908139608694231, -0.8484810341097399, -0.4...
# 4        [0.7738521869833273, -0.07925597736546798, -0....
# ...                                                    ...
# 2766793  [-0.2069418024409927, 0.2672370217202399, -0.9...
# 2766794  [0.5942730241053608, 0.6175260630673811, -0.51...
# 2766795  [0.3312106913072638, 0.5407131844563555, 0.773...
# 2766796  [-0.0071324298603245555, 0.623790473641556, 0....
# 2766797  [-0.06412683698521963, -0.9977986677530827, 0....
#
#                                                     offset      diff energy  \
# 0        [-0.851898273495669, 2.1253245532459824, 0.445...  0.046168     40
# 1        [-1.017085182270888, -1.6805460012244295, 1.10...  0.028843     40
# 2        [-0.10613203070195368, 0.22289410895907838, 1....  0.025293     40
# 3        [-1.0096727220437194, 1.2613684348817842, 1.42...  0.034410     40
# 4        [0.7752193984015442, 0.8404383794565299, 0.902...  0.033654     40
# ...                                                    ...       ...    ...
# 2766793  [-0.5891835692649702, -0.5092523892090935, 1.8...  0.043683     50
# 2766794  [-0.723736545709404, -0.10798660967928463, 0.6...  0.030250     50
# 2766795  [-0.3615579024644222, 1.934812461239543, -2.26...  0.030298     50
# 2766796  [0.7469683683355023, -2.603944946514045, -0.74...  0.039175     50
# 2766797  [1.8179965860730307, 1.618875928754491, -1.181...  0.024449     50
#
#         true_index
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
# ...            ...
# 2766793    2766793
# 2766794    2766794
# 2766795    2766795
# 2766796    2766796
# 2766797    2766797
#
# [2766798 rows x 5 columns]

# %%
# Make custom dataset
MyDataset = mytools.CustomDataset(dir_loc = file_loc, st_info = st_info)

# Split datat into training, validation, and testing sets
train_dataset, val_dataset = torch.utils.data.random_split(MyDataset,[0.8, 0.2], generator=torch.Generator().manual_seed(42))

print("Training samples: ", len(train_dataset))
print("Validation samples: ", len(val_dataset))

# Create training and validation DataLoaders
batch_size = 256
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
# Out:
# Training samples:  2213439
# Validation samples:  553359

# %%
# Print tensor shapes
for X_plot, y_plot, offset_plot in train_dataloader:
    print(f"Shape of X [N, C, H, W, D]: {X_plot.shape}")
    print(f"Shape of y: {y_plot.shape} {y_plot.dtype}")
    print("Offsets: ", offset_plot.shape)
    break
# Out:
# Shape of X [N, C, H, W, D]: torch.Size([256, 120, 120, 120, 1])
# Shape of y: torch.Size([256, 3]) torch.float32
# Offsets:  torch.Size([256, 3])

# %%
#Record shape of voxel grid
grid_shape = X_plot.shape[1:4]
print("Voxel grid shape: " , grid_shape)
# Out:
# Voxel grid shape:  torch.Size([120, 120, 120])

# %% [markdown]
# # Visualize a sample

# %%
# Plot an example as a sanity check

# x/y/z length being kept in cm
eff_l = mytools.voxel_grid['eff_l']
# Voxel size in cm
vox_l = mytools.voxel_grid['vox_l']

#Convert to dense, reshape and convert to numpy
X_plot = X_plot.to_dense().reshape(-1, 1, 120, 120, 120).numpy()

index = 2
mytools.plot_tensor_dir(tensor = X_plot[index], start = offset_plot[index].numpy(), direction = y_plot[index].numpy(), eff_l=eff_l, vox_l=vox_l)

# %% [markdown]
# # Initialize Convnet

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Using {device} device")

model = mymodels.spConvnet_HSCDC_subM(shape = grid_shape ).to(device)
print(model)
# Out:
# Using cuda device
# spConvnet_HSCDC_subM(
#   (net): SparseSequential(
#     (0): SubMConv3d(1, 32, kernel_size=[7, 7, 7], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (1): ReLU()
#     (2): SubMConv3d(32, 40, kernel_size=[5, 5, 5], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (3): ReLU()
#     (4): SparseConv3d(40, 50, kernel_size=[6, 6, 6], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (5): ReLU()
#     (6): SparseMaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], algo=ConvAlgo.MaskImplicitGemm)
#     (7): SparseConv3d(50, 30, kernel_size=[3, 3, 3], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.MaskImplicitGemm)
#     (8): ReLU()
#     (9): SparseConv3d(30, 10, kernel_size=[3, 3, 3], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.MaskImplicitGemm)
#     (10): ReLU()
#     (11): SparseMaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], algo=ConvAlgo.MaskImplicitGemm)
#     (12): ToDense()
#   )
#   (fc1): Linear(in_features=2160, out_features=500, bias=True)
#   (fc2_1): Linear(in_features=500, out_features=200, bias=True)
#   (fc3_1): Linear(in_features=200, out_features=50, bias=True)
#   (fc4_1): Linear(in_features=50, out_features=3, bias=True)
#   (fc2_2): Linear(in_features=500, out_features=200, bias=True)
#   (fc3_2): Linear(in_features=200, out_features=50, bias=True)
#   (fc4_2): Linear(in_features=50, out_features=1, bias=True)
# )

# %% [markdown]
# # Train the model

# %%
# Specify optimizer
optimizer = torch.optim.Adam(params = model.parameters(), lr=0.0001, betas=(0.94, 0.999), eps=1e-07)

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 2

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 1000
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clip(train_dataloader, model, mytools.NLLloss, optimizer, device))
    Validation_losses = np.append(Validation_losses, mytools.validate(val_dataloader, model, mytools.NLLloss, device))
    
    # Keep a running copy of the model with the lowest loss
    # Do not copy the model if loss in nan
    if (Validation_losses[-1] == np.min(Validation_losses)) and (~np.isnan(Validation_losses[-1])):
        final_model = copy.deepcopy(model)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Current batch training loss: 2.584175  [    0/2213439]
# Current batch training loss: 2.462947  [25600/2213439]
# Current batch training loss: 2.315059  [51200/2213439]
# Current batch training loss: 2.152939  [76800/2213439]
# Current batch training loss: 2.198846  [102400/2213439]
# Current batch training loss: 2.105978  [128000/2213439]
# Current batch training loss: 2.021311  [153600/2213439]
# Current batch training loss: 2.027074  [179200/2213439]
# Current batch training loss: 2.024220  [204800/2213439]
# Current batch training loss: 1.935768  [230400/2213439]
# Current batch training loss: 2.009424  [256000/2213439]
# Current batch training loss: 1.972970  [281600/2213439]
# Current batch training loss: 1.764260  [307200/2213439]
# Current batch training loss: 1.818831  [332800/2213439]
# Current batch training loss: 1.718756  [358400/2213439]
# Current batch training loss: 1.728626  [384000/2213439]
# Current batch training loss: 1.702191  [409600/2213439]
# Current batch training loss: 1.584137  [435200/2213439]
# Current batch training loss: 1.604755  [460800/2213439]
# Current batch training loss: 1.514354  [486400/2213439]
# Current batch training loss: 1.490194  [512000/2213439]
# Current batch training loss: 1.452152  [537600/2213439]
# Current batch training loss: 1.369230  [563200/2213439]
# Current batch training loss: 1.425053  [588800/2213439]
# Current batch training loss: 1.399872  [614400/2213439]
# Current batch training loss: 1.409563  [640000/2213439]
# Current batch training loss: 1.285004  [665600/2213439]
# Current batch training loss: 1.239100  [691200/2213439]
# Current batch training loss: 1.206620  [716800/2213439]
# Current batch training loss: 1.205822  [742400/2213439]
# Current batch training loss: 1.169891  [768000/2213439]
# Current batch training loss: 1.047667  [793600/2213439]
# Current batch training loss: 1.205140  [819200/2213439]
# Current batch training loss: 1.017848  [844800/2213439]
# Current batch training loss: 1.046731  [870400/2213439]
# Current batch training loss: 0.910079  [896000/2213439]
# Current batch training loss: 0.924879  [921600/2213439]
# Current batch training loss: 0.950435  [947200/2213439]
# Current batch training loss: 0.929475  [972800/2213439]
# Current batch training loss: 0.803484  [998400/2213439]
# Current batch training loss: 1.055089  [1024000/2213439]
# Current batch training loss: 1.019968  [1049600/2213439]
# Current batch training loss: 0.977923  [1075200/2213439]
# Current batch training loss: 0.772955  [1100800/2213439]
# Current batch training loss: 0.753735  [1126400/2213439]
# Current batch training loss: 0.863321  [1152000/2213439]
# Current batch training loss: 0.926754  [1177600/2213439]
# Current batch training loss: 0.926286  [1203200/2213439]
# Current batch training loss: 1.032544  [1228800/2213439]
# Current batch training loss: 0.905228  [1254400/2213439]
# Current batch training loss: 0.702385  [1280000/2213439]
# Current batch training loss: 0.759892  [1305600/2213439]
# Current batch training loss: 0.884612  [1331200/2213439]
# Current batch training loss: 0.973458  [1356800/2213439]
# Current batch training loss: 0.754193  [1382400/2213439]
# Current batch training loss: 0.890915  [1408000/2213439]
# Current batch training loss: 0.700385  [1433600/2213439]
# Current batch training loss: 0.693733  [1459200/2213439]
# Current batch training loss: 0.821603  [1484800/2213439]
# Current batch training loss: 0.653151  [1510400/2213439]
# Current batch training loss: 0.645967  [1536000/2213439]
# Current batch training loss: 0.625230  [1561600/2213439]
# Current batch training loss: 0.697559  [1587200/2213439]
# Current batch training loss: 0.738186  [1612800/2213439]
# Current batch training loss: 0.521972  [1638400/2213439]
# Current batch training loss: 0.553768  [1664000/2213439]
# Current batch training loss: 0.594951  [1689600/2213439]
# Current batch training loss: 0.653123  [1715200/2213439]
# Current batch training loss: 0.620112  [1740800/2213439]
# Current batch training loss: 0.497032  [1766400/2213439]
# Current batch training loss: 0.685526  [1792000/2213439]
# Current batch training loss: 0.814774  [1817600/2213439]
# Current batch training loss: 0.673956  [1843200/2213439]
# Current batch training loss: 0.662632  [1868800/2213439]
# Current batch training loss: 1.027514  [1894400/2213439]
# Current batch training loss: 0.451676  [1920000/2213439]
# Current batch training loss: 0.855884  [1945600/2213439]
# Current batch training loss: 0.643416  [1971200/2213439]
# Current batch training loss: 0.690872  [1996800/2213439]
# Current batch training loss: 0.530287  [2022400/2213439]
# Current batch training loss: 0.662807  [2048000/2213439]
# Current batch training loss: 0.694647  [2073600/2213439]
# Current batch training loss: 0.513841  [2099200/2213439]
# Current batch training loss: 0.501995  [2124800/2213439]
# Current batch training loss: 0.516162  [2150400/2213439]
# Current batch training loss: 0.499812  [2176000/2213439]
# Current batch training loss: 0.443698  [2201600/2213439]
# Training loss: 1.096188
# Validation loss: 0.536226
#
# Epoch 2
# -------------------------------
# Current batch training loss: 0.589828  [    0/2213439]
# Current batch training loss: 0.762157  [25600/2213439]
# Current batch training loss: 0.507475  [51200/2213439]
# Current batch training loss: 0.353037  [76800/2213439]
# Current batch training loss: 0.554608  [102400/2213439]
# Current batch training loss: 0.405962  [128000/2213439]
# Current batch training loss: 0.437804  [153600/2213439]
# Current batch training loss: 0.817614  [179200/2213439]
# Current batch training loss: 0.424707  [204800/2213439]
# Current batch training loss: 0.364021  [230400/2213439]
# Current batch training loss: 0.521599  [256000/2213439]
# Current batch training loss: 0.430285  [281600/2213439]
# Current batch training loss: 0.489500  [307200/2213439]
# Current batch training loss: 0.538984  [332800/2213439]
# Current batch training loss: 0.452997  [358400/2213439]
# Current batch training loss: 0.789229  [384000/2213439]
# Current batch training loss: 0.601094  [409600/2213439]
# Current batch training loss: 0.529030  [435200/2213439]
# Current batch training loss: 0.301311  [460800/2213439]
# Current batch training loss: 0.252957  [486400/2213439]
# Current batch training loss: 0.174300  [512000/2213439]
# Current batch training loss: 0.463471  [537600/2213439]
# Current batch training loss: 0.424095  [563200/2213439]
# Current batch training loss: 0.199890  [588800/2213439]
# Current batch training loss: 0.439055  [614400/2213439]
# Current batch training loss: 0.415681  [640000/2213439]
# Current batch training loss: 0.565598  [665600/2213439]
# Current batch training loss: 0.390369  [691200/2213439]
# Current batch training loss: 0.260982  [716800/2213439]
# Current batch training loss: 0.264717  [742400/2213439]
# Current batch training loss: 0.406664  [768000/2213439]
# Current batch training loss: 0.404142  [793600/2213439]
# Current batch training loss: 0.288978  [819200/2213439]
# Current batch training loss: 0.428527  [844800/2213439]
# Current batch training loss: 0.256483  [870400/2213439]
# Current batch training loss: 0.280693  [896000/2213439]
# Current batch training loss: 0.428214  [921600/2213439]
# Current batch training loss: 0.304945  [947200/2213439]
# Current batch training loss: 0.275961  [972800/2213439]
# Current batch training loss: 0.536110  [998400/2213439]
# Current batch training loss: 0.221488  [1024000/2213439]
# Current batch training loss: 0.160110  [1049600/2213439]
# Current batch training loss: 0.345729  [1075200/2213439]
# Current batch training loss: 0.271418  [1100800/2213439]
# Current batch training loss: 0.270691  [1126400/2213439]
# Current batch training loss: 0.192941  [1152000/2213439]
# Current batch training loss: 0.455112  [1177600/2213439]
# Current batch training loss: 0.553272  [1203200/2213439]
# Current batch training loss: 0.408636  [1228800/2213439]
# Current batch training loss: 0.167814  [1254400/2213439]
# Current batch training loss: 0.222161  [1280000/2213439]
# Current batch training loss: 0.229282  [1305600/2213439]
# Current batch training loss: 0.185618  [1331200/2213439]
# Current batch training loss: 0.250392  [1356800/2213439]
# Current batch training loss: 0.438398  [1382400/2213439]
# Current batch training loss: 0.190627  [1408000/2213439]
# Current batch training loss: 0.269506  [1433600/2213439]
# Current batch training loss: 0.249202  [1459200/2213439]
# Current batch training loss: 0.347849  [1484800/2213439]
# Current batch training loss: 0.299717  [1510400/2213439]
# Current batch training loss: 0.224183  [1536000/2213439]
# Current batch training loss: 0.215482  [1561600/2213439]
# Current batch training loss: 0.258118  [1587200/2213439]
# Current batch training loss: 0.163883  [1612800/2213439]
# Current batch training loss: 0.200348  [1638400/2213439]
# Current batch training loss: 0.468238  [1664000/2213439]
# Current batch training loss: 0.188224  [1689600/2213439]
# Current batch training loss: 0.289128  [1715200/2213439]
# Current batch training loss: 0.040424  [1740800/2213439]
# Current batch training loss: 0.263660  [1766400/2213439]
# Current batch training loss: 0.145340  [1792000/2213439]
# Current batch training loss: 0.098190  [1817600/2213439]
# Current batch training loss: 0.222121  [1843200/2213439]
# Current batch training loss: 0.513960  [1868800/2213439]
# Current batch training loss: 0.334620  [1894400/2213439]
# Current batch training loss: 0.286070  [1920000/2213439]
# Current batch training loss: 0.431003  [1945600/2213439]
# Current batch training loss: 0.148497  [1971200/2213439]
# Current batch training loss: 0.143826  [1996800/2213439]
# Current batch training loss: 0.210289  [2022400/2213439]
# Current batch training loss: 0.189923  [2048000/2213439]
# Current batch training loss: 0.313950  [2073600/2213439]
# Current batch training loss: 0.395905  [2099200/2213439]
# Current batch training loss: 0.288689  [2124800/2213439]
# Current batch training loss: 0.136032  [2150400/2213439]
# Current batch training loss: 0.459520  [2176000/2213439]
# Current batch training loss: 0.297568  [2201600/2213439]
# Training loss: 0.352206
# Validation loss: 0.259163
#
# Epoch 3
# -------------------------------
# Current batch training loss: 0.275459  [    0/2213439]
# Current batch training loss: 0.387098  [25600/2213439]
# Current batch training loss: 0.246971  [51200/2213439]
# Current batch training loss: 0.310372  [76800/2213439]
# Current batch training loss: 0.177639  [102400/2213439]
# Current batch training loss: 0.151233  [128000/2213439]
# Current batch training loss: 0.169043  [153600/2213439]
# Current batch training loss: 0.367921  [179200/2213439]
# Current batch training loss: 0.190162  [204800/2213439]
# Current batch training loss: 0.593411  [230400/2213439]
# Current batch training loss: 0.036483  [256000/2213439]
# Current batch training loss: 0.263279  [281600/2213439]
# Current batch training loss: 0.164988  [307200/2213439]
# Current batch training loss: 0.348539  [332800/2213439]
# Current batch training loss: 0.052623  [358400/2213439]
# Current batch training loss: 0.113770  [384000/2213439]
# Current batch training loss: 0.150368  [409600/2213439]
# Current batch training loss: 0.405802  [435200/2213439]
# Current batch training loss: 0.107462  [460800/2213439]
# Current batch training loss: 0.502164  [486400/2213439]
# Current batch training loss: 0.224947  [512000/2213439]
# Current batch training loss: 0.354383  [537600/2213439]
# Current batch training loss: 0.297260  [563200/2213439]
# Current batch training loss: 0.118723  [588800/2213439]
# Current batch training loss: 0.148960  [614400/2213439]
# Current batch training loss: 0.094763  [640000/2213439]
# Current batch training loss: 0.185464  [665600/2213439]
# Current batch training loss: 0.282923  [691200/2213439]
# Current batch training loss: 0.381904  [716800/2213439]
# Current batch training loss: 0.221063  [742400/2213439]
# Current batch training loss: -0.019602  [768000/2213439]
# Current batch training loss: 0.169849  [793600/2213439]
# Current batch training loss: 0.078910  [819200/2213439]
# Current batch training loss: 0.194677  [844800/2213439]
# Current batch training loss: 0.249143  [870400/2213439]
# Current batch training loss: 0.041374  [896000/2213439]
# Current batch training loss: 0.220902  [921600/2213439]
# Current batch training loss: 0.235940  [947200/2213439]
# Current batch training loss: 0.138318  [972800/2213439]
# Current batch training loss: 0.454019  [998400/2213439]
# Current batch training loss: 0.173593  [1024000/2213439]
# Current batch training loss: 0.097400  [1049600/2213439]
# Current batch training loss: 0.241788  [1075200/2213439]
# Current batch training loss: 0.253299  [1100800/2213439]
# Current batch training loss: 0.344482  [1126400/2213439]
# Current batch training loss: 0.373718  [1152000/2213439]
# Current batch training loss: 0.288464  [1177600/2213439]
# Current batch training loss: 0.300405  [1203200/2213439]
# Current batch training loss: 0.242654  [1228800/2213439]
# Current batch training loss: 0.247228  [1254400/2213439]
# Current batch training loss: 0.188194  [1280000/2213439]
# Current batch training loss: 0.241927  [1305600/2213439]
# Current batch training loss: 0.208727  [1331200/2213439]
# Current batch training loss: 0.439619  [1356800/2213439]
# Current batch training loss: 0.356599  [1382400/2213439]
# Current batch training loss: 0.176106  [1408000/2213439]
# Current batch training loss: 0.248533  [1433600/2213439]
# Current batch training loss: 0.394432  [1459200/2213439]
# Current batch training loss: 0.323854  [1484800/2213439]
# Current batch training loss: 0.392140  [1510400/2213439]
# Current batch training loss: 0.294756  [1536000/2213439]
# Current batch training loss: 0.141868  [1561600/2213439]
# Current batch training loss: 0.354937  [1587200/2213439]
# Current batch training loss: 0.162896  [1612800/2213439]
# Current batch training loss: 0.115967  [1638400/2213439]
# Current batch training loss: 0.120032  [1664000/2213439]
# Current batch training loss: 0.229270  [1689600/2213439]
# Current batch training loss: 0.078243  [1715200/2213439]
# Current batch training loss: 0.176792  [1740800/2213439]
# Current batch training loss: 0.251853  [1766400/2213439]
# Current batch training loss: 0.287679  [1792000/2213439]
# Current batch training loss: 0.356705  [1817600/2213439]
# Current batch training loss: 0.198965  [1843200/2213439]
# Current batch training loss: 0.230977  [1868800/2213439]
# Current batch training loss: 0.159728  [1894400/2213439]
# Current batch training loss: 0.314802  [1920000/2213439]
# Current batch training loss: 0.203615  [1945600/2213439]
# Current batch training loss: 0.215912  [1971200/2213439]
# Current batch training loss: 0.187775  [1996800/2213439]
# Current batch training loss: 0.265265  [2022400/2213439]
# Current batch training loss: 0.044526  [2048000/2213439]
# Current batch training loss: 0.161957  [2073600/2213439]
# Current batch training loss: 0.199853  [2099200/2213439]
# Current batch training loss: 0.075849  [2124800/2213439]
# Current batch training loss: 0.306931  [2150400/2213439]
# Current batch training loss: 0.197970  [2176000/2213439]
# Current batch training loss: 0.072087  [2201600/2213439]
# Training loss: 0.220018
# Validation loss: 0.213723
#
# Epoch 4
# -------------------------------
# Current batch training loss: 0.345398  [    0/2213439]
# Current batch training loss: 0.230759  [25600/2213439]
# Current batch training loss: 0.201620  [51200/2213439]
# Current batch training loss: 0.051605  [76800/2213439]
# Current batch training loss: 0.138143  [102400/2213439]
# Current batch training loss: 0.203170  [128000/2213439]
# Current batch training loss: 0.404198  [153600/2213439]
# Current batch training loss: 0.215664  [179200/2213439]
# Current batch training loss: 0.224564  [204800/2213439]
# Current batch training loss: 0.195695  [230400/2213439]
# Current batch training loss: 0.607214  [256000/2213439]
# Current batch training loss: 0.209836  [281600/2213439]
# Current batch training loss: 0.158171  [307200/2213439]
# Current batch training loss: 0.255499  [332800/2213439]
# Current batch training loss: 0.177699  [358400/2213439]
# Current batch training loss: 0.113715  [384000/2213439]
# Current batch training loss: -0.027802  [409600/2213439]
# Current batch training loss: 0.306518  [435200/2213439]
# Current batch training loss: 0.233303  [460800/2213439]
# Current batch training loss: 0.094435  [486400/2213439]
# Current batch training loss: 0.035588  [512000/2213439]
# Current batch training loss: 0.182016  [537600/2213439]
# Current batch training loss: 0.110933  [563200/2213439]
# Current batch training loss: 0.036466  [588800/2213439]
# Current batch training loss: -0.198637  [614400/2213439]
# Current batch training loss: 0.214751  [640000/2213439]
# Current batch training loss: 0.129524  [665600/2213439]
# Current batch training loss: 0.089662  [691200/2213439]
# Current batch training loss: -0.034246  [716800/2213439]
# Current batch training loss: 0.293806  [742400/2213439]
# Current batch training loss: 0.165858  [768000/2213439]
# Current batch training loss: 0.038692  [793600/2213439]
# Current batch training loss: 0.246616  [819200/2213439]
# Current batch training loss: 0.416461  [844800/2213439]
# Current batch training loss: 0.254401  [870400/2213439]
# Current batch training loss: 0.118135  [896000/2213439]
# Current batch training loss: 0.264856  [921600/2213439]
# Current batch training loss: 0.249413  [947200/2213439]
# Current batch training loss: 0.127587  [972800/2213439]
# Current batch training loss: 0.182020  [998400/2213439]
# Current batch training loss: 0.141970  [1024000/2213439]
# Current batch training loss: 0.089999  [1049600/2213439]
# Current batch training loss: 0.227430  [1075200/2213439]
# Current batch training loss: 0.165582  [1100800/2213439]
# Current batch training loss: 0.161773  [1126400/2213439]
# Current batch training loss: 0.211282  [1152000/2213439]
# Current batch training loss: 0.248078  [1177600/2213439]
# Current batch training loss: -0.061676  [1203200/2213439]
# Current batch training loss: 0.059618  [1228800/2213439]
# Current batch training loss: 0.190160  [1254400/2213439]
# Current batch training loss: 0.200012  [1280000/2213439]
# Current batch training loss: 0.151772  [1305600/2213439]
# Current batch training loss: 0.194307  [1331200/2213439]
# Current batch training loss: 0.090487  [1356800/2213439]
# Current batch training loss: 0.291438  [1382400/2213439]
# Current batch training loss: 0.243046  [1408000/2213439]
# Current batch training loss: 0.035679  [1433600/2213439]
# Current batch training loss: 0.132727  [1459200/2213439]
# Current batch training loss: 0.183522  [1484800/2213439]
# Current batch training loss: 0.111567  [1510400/2213439]
# Current batch training loss: 0.252776  [1536000/2213439]
# Current batch training loss: 0.470749  [1561600/2213439]
# Current batch training loss: 0.173837  [1587200/2213439]
# Current batch training loss: 0.356321  [1612800/2213439]
# Current batch training loss: 0.161102  [1638400/2213439]
# Current batch training loss: 0.321421  [1664000/2213439]
# Current batch training loss: 0.049925  [1689600/2213439]
# Current batch training loss: -0.085532  [1715200/2213439]
# Current batch training loss: 0.147828  [1740800/2213439]
# Current batch training loss: 0.111781  [1766400/2213439]
# Current batch training loss: 0.261861  [1792000/2213439]
# Current batch training loss: 0.090530  [1817600/2213439]
# Current batch training loss: 0.117996  [1843200/2213439]
# Current batch training loss: 0.157476  [1868800/2213439]
# Current batch training loss: 0.094092  [1894400/2213439]
# Current batch training loss: 0.267848  [1920000/2213439]
# Current batch training loss: 0.191258  [1945600/2213439]
# Current batch training loss: 0.405112  [1971200/2213439]
# Current batch training loss: 0.123219  [1996800/2213439]
# Current batch training loss: 0.012241  [2022400/2213439]
# Current batch training loss: 0.230183  [2048000/2213439]
# Current batch training loss: 0.068346  [2073600/2213439]
# Current batch training loss: 0.131283  [2099200/2213439]
# Current batch training loss: 0.183951  [2124800/2213439]
# Current batch training loss: 0.045009  [2150400/2213439]
# Current batch training loss: 0.037940  [2176000/2213439]
# Current batch training loss: 0.206128  [2201600/2213439]
# Training loss: 0.177112
# Validation loss: 0.194447
#
# Epoch 5
# -------------------------------
# Current batch training loss: 0.314001  [    0/2213439]
# Current batch training loss: 0.237881  [25600/2213439]
# Current batch training loss: 0.050841  [51200/2213439]
# Current batch training loss: 0.018317  [76800/2213439]
# Current batch training loss: 0.216242  [102400/2213439]
# Current batch training loss: 0.207426  [128000/2213439]
# Current batch training loss: 0.158104  [153600/2213439]
# Current batch training loss: 0.123191  [179200/2213439]
# Current batch training loss: 0.009792  [204800/2213439]
# Current batch training loss: 0.063349  [230400/2213439]
# Current batch training loss: 0.037657  [256000/2213439]
# Current batch training loss: -0.052098  [281600/2213439]
# Current batch training loss: 0.233234  [307200/2213439]
# Current batch training loss: 0.257287  [332800/2213439]
# Current batch training loss: 0.333686  [358400/2213439]
# Current batch training loss: 0.229557  [384000/2213439]
# Current batch training loss: 0.156587  [409600/2213439]
# Current batch training loss: 0.056992  [435200/2213439]
# Current batch training loss: 0.140034  [460800/2213439]
# Current batch training loss: 0.147043  [486400/2213439]
# Current batch training loss: 0.309252  [512000/2213439]
# Current batch training loss: 0.116816  [537600/2213439]
# Current batch training loss: -0.031573  [563200/2213439]
# Current batch training loss: 0.060749  [588800/2213439]
# Current batch training loss: 0.117319  [614400/2213439]
# Current batch training loss: 0.211910  [640000/2213439]
# Current batch training loss: 0.115998  [665600/2213439]
# Current batch training loss: 0.000770  [691200/2213439]
# Current batch training loss: 0.100386  [716800/2213439]
# Current batch training loss: 0.137098  [742400/2213439]
# Current batch training loss: -0.094748  [768000/2213439]
# Current batch training loss: 0.209469  [793600/2213439]
# Current batch training loss: 0.172863  [819200/2213439]
# Current batch training loss: -0.116583  [844800/2213439]
# Current batch training loss: 0.129806  [870400/2213439]
# Current batch training loss: 0.100977  [896000/2213439]
# Current batch training loss: 0.279751  [921600/2213439]
# Current batch training loss: 0.306743  [947200/2213439]
# Current batch training loss: 0.278243  [972800/2213439]
# Current batch training loss: -0.069463  [998400/2213439]
# Current batch training loss: 0.198821  [1024000/2213439]
# Current batch training loss: 0.211503  [1049600/2213439]
# Current batch training loss: 0.289450  [1075200/2213439]
# Current batch training loss: 0.215311  [1100800/2213439]
# Current batch training loss: 0.330568  [1126400/2213439]
# Current batch training loss: 0.196371  [1152000/2213439]
# Current batch training loss: 0.204715  [1177600/2213439]
# Current batch training loss: 0.527531  [1203200/2213439]
# Current batch training loss: 0.012676  [1228800/2213439]
# Current batch training loss: 0.083421  [1254400/2213439]
# Current batch training loss: 0.240311  [1280000/2213439]
# Current batch training loss: 0.101694  [1305600/2213439]
# Current batch training loss: 0.250625  [1331200/2213439]
# Current batch training loss: 0.465690  [1356800/2213439]
# Current batch training loss: 0.109467  [1382400/2213439]
# Current batch training loss: 0.176885  [1408000/2213439]
# Current batch training loss: 0.031138  [1433600/2213439]
# Current batch training loss: 0.002898  [1459200/2213439]
# Current batch training loss: 0.013863  [1484800/2213439]
# Current batch training loss: 0.130355  [1510400/2213439]
# Current batch training loss: 0.215245  [1536000/2213439]
# Current batch training loss: 0.354636  [1561600/2213439]
# Current batch training loss: 0.131090  [1587200/2213439]
# Current batch training loss: 0.231130  [1612800/2213439]
# Current batch training loss: 0.019186  [1638400/2213439]
# Current batch training loss: 0.178961  [1664000/2213439]
# Current batch training loss: 0.015087  [1689600/2213439]
# Current batch training loss: 0.046097  [1715200/2213439]
# Current batch training loss: 0.324785  [1740800/2213439]
# Current batch training loss: -0.097356  [1766400/2213439]
# Current batch training loss: 0.328174  [1792000/2213439]
# Current batch training loss: 0.430233  [1817600/2213439]
# Current batch training loss: 0.030475  [1843200/2213439]
# Current batch training loss: 0.238560  [1868800/2213439]
# Current batch training loss: 0.109329  [1894400/2213439]
# Current batch training loss: 0.328328  [1920000/2213439]
# Current batch training loss: 0.084732  [1945600/2213439]
# Current batch training loss: 0.156200  [1971200/2213439]
# Current batch training loss: 0.088677  [1996800/2213439]
# Current batch training loss: 0.199681  [2022400/2213439]
# Current batch training loss: 0.143354  [2048000/2213439]
# Current batch training loss: 0.236843  [2073600/2213439]
# Current batch training loss: 0.145710  [2099200/2213439]
# Current batch training loss: 0.502501  [2124800/2213439]
# Current batch training loss: 0.174990  [2150400/2213439]
# Current batch training loss: 0.052279  [2176000/2213439]
# Current batch training loss: 0.086434  [2201600/2213439]
# Training loss: 0.149875
# Validation loss: 0.197388
#
# Epoch 6
# -------------------------------
# Current batch training loss: 0.017509  [    0/2213439]
# Current batch training loss: 0.001419  [25600/2213439]
# Current batch training loss: 0.237668  [51200/2213439]
# Current batch training loss: 0.004471  [76800/2213439]
# Current batch training loss: 0.263328  [102400/2213439]
# Current batch training loss: 0.014247  [128000/2213439]
# Current batch training loss: 0.185580  [153600/2213439]
# Current batch training loss: 0.108226  [179200/2213439]
# Current batch training loss: -0.027318  [204800/2213439]
# Current batch training loss: 0.129490  [230400/2213439]
# Current batch training loss: -0.000904  [256000/2213439]
# Current batch training loss: -0.031117  [281600/2213439]
# Current batch training loss: 0.102748  [307200/2213439]
# Current batch training loss: 0.182758  [332800/2213439]
# Current batch training loss: 0.120016  [358400/2213439]
# Current batch training loss: 0.075089  [384000/2213439]
# Current batch training loss: 0.111933  [409600/2213439]
# Current batch training loss: 0.134451  [435200/2213439]
# Current batch training loss: 0.250000  [460800/2213439]
# Current batch training loss: 0.087524  [486400/2213439]
# Current batch training loss: -0.055530  [512000/2213439]
# Current batch training loss: 0.295844  [537600/2213439]
# Current batch training loss: 0.167955  [563200/2213439]
# Current batch training loss: -0.004123  [588800/2213439]
# Current batch training loss: 0.146700  [614400/2213439]
# Current batch training loss: 0.084755  [640000/2213439]
# Current batch training loss: 0.092544  [665600/2213439]
# Current batch training loss: -0.066390  [691200/2213439]
# Current batch training loss: 0.045808  [716800/2213439]
# Current batch training loss: 0.363712  [742400/2213439]
# Current batch training loss: 0.055888  [768000/2213439]
# Current batch training loss: 0.266095  [793600/2213439]
# Current batch training loss: 0.330655  [819200/2213439]
# Current batch training loss: 0.173881  [844800/2213439]
# Current batch training loss: 0.120686  [870400/2213439]
# Current batch training loss: 0.423586  [896000/2213439]
# Current batch training loss: 0.225241  [921600/2213439]
# Current batch training loss: -0.013542  [947200/2213439]
# Current batch training loss: -0.033192  [972800/2213439]
# Current batch training loss: 0.017771  [998400/2213439]
# Current batch training loss: 0.218488  [1024000/2213439]
# Current batch training loss: 0.370381  [1049600/2213439]
# Current batch training loss: 0.053646  [1075200/2213439]
# Current batch training loss: 0.021033  [1100800/2213439]
# Current batch training loss: 0.074375  [1126400/2213439]
# Current batch training loss: 0.322038  [1152000/2213439]
# Current batch training loss: 0.236332  [1177600/2213439]
# Current batch training loss: 0.137748  [1203200/2213439]
# Current batch training loss: -0.065609  [1228800/2213439]
# Current batch training loss: 0.381248  [1254400/2213439]
# Current batch training loss: 0.002742  [1280000/2213439]
# Current batch training loss: -0.046485  [1305600/2213439]
# Current batch training loss: 0.120520  [1331200/2213439]
# Current batch training loss: 0.279645  [1356800/2213439]
# Current batch training loss: 0.049359  [1382400/2213439]
# Current batch training loss: 0.142614  [1408000/2213439]
# Current batch training loss: 0.048753  [1433600/2213439]
# Current batch training loss: 0.264132  [1459200/2213439]
# Current batch training loss: 0.202331  [1484800/2213439]
# Current batch training loss: 0.232996  [1510400/2213439]
# Current batch training loss: 0.235903  [1536000/2213439]
# Current batch training loss: 0.056796  [1561600/2213439]
# Current batch training loss: 0.179351  [1587200/2213439]
# Current batch training loss: 0.233043  [1612800/2213439]
# Current batch training loss: -0.122894  [1638400/2213439]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 13
#      10 for t in range(epochs):
#      11     print(f"Epoch {t+1}\n-------------------------------")
# ---> 13     Training_losses = np.append(Training_losses, mytools.train_clip(train_dataloader, model, mytools.NLLloss, optimizer, device))
#      14     Validation_losses = np.append(Validation_losses, mytools.validate(val_dataloader, model, mytools.NLLloss, device))
#      16     # Keep a running copy of the model with the lowest loss
#      17     # Do not copy the model if loss in nan
#
# File ~/3D_Heteroscedastic_Convnet/mytools.py:140, in train_clip(dataloader, model, loss_fn, optimizer, device)
#     138 model.train()
#     139 train_loss = 0
# --> 140 for batch, (X, y, offset) in enumerate(dataloader):
#     142     X, y = X.type(torch.FloatTensor).to(device), y.to(device)
#     144     X = X.coalesce()
#
# File ~/.conda/envs/mypt/lib/python3.10/site-packages/torch/utils/data/dataloader.py:634, in _BaseDataLoaderIter.__next__(self)
#     631 if self._sampler_iter is None:
#     632     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     633     self._reset()  # type: ignore[call-arg]
# --> 634 data = self._next_data()
#     635 self._num_yielded += 1
#     636 if self._dataset_kind == _DatasetKind.Iterable and \
#     637         self._IterableDataset_len_called is not None and \
#     638         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/.conda/envs/mypt/lib/python3.10/site-packages/torch/utils/data/dataloader.py:678, in _SingleProcessDataLoaderIter._next_data(self)
#     676 def _next_data(self):
#     677     index = self._next_index()  # may raise StopIteration
# --> 678     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     679     if self._pin_memory:
#     680         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/.conda/envs/mypt/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/.conda/envs/mypt/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/.conda/envs/mypt/lib/python3.10/site-packages/torch/utils/data/dataset.py:298, in Subset.__getitem__(self, idx)
#     296 if isinstance(idx, list):
#     297     return self.dataset[[self.indices[i] for i in idx]]
# --> 298 return self.dataset[self.indices[idx]]
#
# File ~/3D_Heteroscedastic_Convnet/mytools.py:80, in CustomDataset.__getitem__(self, idx)
#      79 def __getitem__(self,idx):
# ---> 80     return ( torch.load(self.dir_loc + 'sparse_recoils_' + str(idx) + '.pt' ), torch.Tensor(self.st_info.iloc[idx].dir), torch.Tensor(self.st_info.iloc[idx].offset) )
#
# File ~/.conda/envs/mypt/lib/python3.10/site-packages/torch/serialization.py:791, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     788 if 'encoding' not in pickle_load_args.keys():
#     789     pickle_load_args['encoding'] = 'utf-8'
# --> 791 with _open_file_like(f, 'rb') as opened_file:
#     792     if _is_zipfile(opened_file):
#     793         # The zipfile reader is going to advance the current file position.
#     794         # If we want to actually tail call to torch.jit.load, we need to
#     795         # reset back to the original position.
#     796         orig_position = opened_file.tell()
#
# File ~/.conda/envs/mypt/lib/python3.10/site-packages/torch/serialization.py:271, in _open_file_like(name_or_buffer, mode)
#     269 def _open_file_like(name_or_buffer, mode):
#     270     if _is_path(name_or_buffer):
# --> 271         return _open_file(name_or_buffer, mode)
#     272     else:
#     273         if 'w' in mode:
#
# File ~/.conda/envs/mypt/lib/python3.10/site-packages/torch/serialization.py:252, in _open_file.__init__(self, name, mode)
#     251 def __init__(self, name, mode):
# --> 252     super().__init__(open(name, mode))
#
# OSError: [Errno 5] Input/output error: '/mnt/scratch/lustre_01/scratch/majd/sparse_training_tensors/sparse_recoils_175580.pt'

# %% [markdown]
# # Visualize Training

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses[~np.isnan(Training_losses)])+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('Negative Log Likelihood Loss')
plt.legend()

# %% [markdown]
# # Save the Model

# %%
torch.save(final_model, "../3D_Heteroscedastic_Convnet_models/3D_HSCDC_CNN_subM-256.pt")
print("Saved PyTorch Model State to ../3D_Heteroscedastic_Convnet_models/3D_HSCDC_CNN_subM-256.pt")
# Out:
# Saved PyTorch Model State to ../3D_Heteroscedastic_Convnet_models/3D_HSCDC_CNN_subM-256.pt
