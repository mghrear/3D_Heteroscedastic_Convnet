# %%
import numpy as np
import pandas as pd
import torch
import copy
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
from torchvision import datasets
import spconv.pytorch as spconv
import matplotlib.pyplot as plt
import mytools
import mymodels

# %% [markdown]
# # Prepare Data

# %%
# Read pandas dataframe with all information about sparse training tensors
file_loc = '/mnt/scratch/lustre_01/scratch/majd/sparse_training_tensors/'
st_info = pd.read_pickle(file_loc+'sparse_tensor_info.pk')
st_info
# Out:
#                                                        dir  \
# 0        [0.5923457337920527, -0.5369941830475861, -0.6...
# 1        [-0.6164927192719855, 0.5695943083433039, -0.5...
# 2        [0.6322337566233259, -0.16773581669128113, -0....
# 3        [0.2908139608694231, -0.8484810341097399, -0.4...
# 4        [0.7738521869833273, -0.07925597736546798, -0....
# ...                                                    ...
# 2766793  [-0.2069418024409927, 0.2672370217202399, -0.9...
# 2766794  [0.5942730241053608, 0.6175260630673811, -0.51...
# 2766795  [0.3312106913072638, 0.5407131844563555, 0.773...
# 2766796  [-0.0071324298603245555, 0.623790473641556, 0....
# 2766797  [-0.06412683698521963, -0.9977986677530827, 0....
#
#                                                     offset      diff energy  \
# 0        [-0.851898273495669, 2.1253245532459824, 0.445...  0.046168     40
# 1        [-1.017085182270888, -1.6805460012244295, 1.10...  0.028843     40
# 2        [-0.10613203070195368, 0.22289410895907838, 1....  0.025293     40
# 3        [-1.0096727220437194, 1.2613684348817842, 1.42...  0.034410     40
# 4        [0.7752193984015442, 0.8404383794565299, 0.902...  0.033654     40
# ...                                                    ...       ...    ...
# 2766793  [-0.5891835692649702, -0.5092523892090935, 1.8...  0.043683     50
# 2766794  [-0.723736545709404, -0.10798660967928463, 0.6...  0.030250     50
# 2766795  [-0.3615579024644222, 1.934812461239543, -2.26...  0.030298     50
# 2766796  [0.7469683683355023, -2.603944946514045, -0.74...  0.039175     50
# 2766797  [1.8179965860730307, 1.618875928754491, -1.181...  0.024449     50
#
#         true_index
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
# ...            ...
# 2766793    2766793
# 2766794    2766794
# 2766795    2766795
# 2766796    2766796
# 2766797    2766797
#
# [2766798 rows x 5 columns]

# %%
# Make custom dataset
MyDataset = mytools.CustomDataset(dir_loc = file_loc, st_info = st_info)

# Split datat into training, validation, and testing sets
train_dataset, val_dataset = torch.utils.data.random_split(MyDataset,[0.8, 0.2], generator=torch.Generator().manual_seed(42))

print("Training samples: ", len(train_dataset))
print("Validation samples: ", len(val_dataset))

# Create training and validation DataLoaders
batch_size = 256
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
# Out:
# Training samples:  2213439
# Validation samples:  553359

# %%
# Print tensor shapes
for X_plot, y_plot, offset_plot in train_dataloader:
    print(f"Shape of X [N, C, H, W, D]: {X_plot.shape}")
    print(f"Shape of y: {y_plot.shape} {y_plot.dtype}")
    print("Offsets: ", offset_plot.shape)
    break
# Out:
# Shape of X [N, C, H, W, D]: torch.Size([256, 120, 120, 120, 1])
# Shape of y: torch.Size([256, 3]) torch.float32
# Offsets:  torch.Size([256, 3])

# %%
#Record shape of voxel grid
grid_shape = X_plot.shape[1:4]
print("Voxel grid shape: " , grid_shape)
# Out:
# Voxel grid shape:  torch.Size([120, 120, 120])

# %% [markdown]
# # Visualize a sample

# %%
# Plot an example as a sanity check

# x/y/z length being kept in cm
eff_l = mytools.voxel_grid['eff_l']
# Voxel size in cm
vox_l = mytools.voxel_grid['vox_l']

#Convert to dense, reshape and convert to numpy
X_plot = X_plot.to_dense().reshape(-1, 1, 120, 120, 120).numpy()

index = 2
mytools.plot_tensor_dir(tensor = X_plot[index], start = offset_plot[index].numpy(), direction = y_plot[index].numpy(), eff_l=eff_l, vox_l=vox_l)

# %% [markdown]
# # Initialize Convnet

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Using {device} device")

model = mymodels.spConvnet_subM(shape = grid_shape ).to(device)
print(model)
# Out:
# Using cuda device
# spConvnet_subM(
#   (net): SparseSequential(
#     (0): SubMConv3d(1, 32, kernel_size=[7, 7, 7], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (1): ReLU()
#     (2): SubMConv3d(32, 40, kernel_size=[5, 5, 5], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (3): ReLU()
#     (4): SparseConv3d(40, 50, kernel_size=[6, 6, 6], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.Native)
#     (5): ReLU()
#     (6): SparseMaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], algo=ConvAlgo.MaskImplicitGemm)
#     (7): SparseConv3d(50, 30, kernel_size=[3, 3, 3], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.MaskImplicitGemm)
#     (8): ReLU()
#     (9): SparseConv3d(30, 10, kernel_size=[3, 3, 3], stride=[1, 1, 1], padding=[0, 0, 0], dilation=[1, 1, 1], output_padding=[0, 0, 0], algo=ConvAlgo.MaskImplicitGemm)
#     (10): ReLU()
#     (11): SparseMaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=[0, 0, 0], dilation=[1, 1, 1], algo=ConvAlgo.MaskImplicitGemm)
#     (12): ToDense()
#   )
#   (fc1): Linear(in_features=2160, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=60, bias=True)
#   (fc3): Linear(in_features=60, out_features=20, bias=True)
#   (fc4): Linear(in_features=20, out_features=3, bias=True)
# )

# %% [markdown]
# # Train the model

# %%
# Specify optimizer
optimizer = torch.optim.Adam(params = model.parameters(), lr=0.0001, betas=(0.94, 0.999), eps=1e-07)

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 2

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 1000
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train(train_dataloader, model, mytools.CSloss, optimizer, device))
    Validation_losses = np.append(Validation_losses, mytools.validate(val_dataloader, model, mytools.CSloss, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_model = copy.deepcopy(model)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Current batch training loss: -0.009331  [    0/2213439]
# Current batch training loss: -0.217106  [25600/2213439]
# Current batch training loss: -0.325041  [51200/2213439]
# Current batch training loss: -0.437489  [76800/2213439]
# Current batch training loss: -0.459927  [102400/2213439]
# Current batch training loss: -0.419444  [128000/2213439]
# Current batch training loss: -0.493566  [153600/2213439]
# Current batch training loss: -0.546166  [179200/2213439]
# Current batch training loss: -0.526239  [204800/2213439]
# Current batch training loss: -0.541427  [230400/2213439]
# Current batch training loss: -0.552277  [256000/2213439]
# Current batch training loss: -0.583275  [281600/2213439]
# Current batch training loss: -0.580584  [307200/2213439]
# Current batch training loss: -0.608099  [332800/2213439]
# Current batch training loss: -0.631068  [358400/2213439]
# Current batch training loss: -0.605905  [384000/2213439]
# Current batch training loss: -0.616109  [409600/2213439]
# Current batch training loss: -0.630897  [435200/2213439]
# Current batch training loss: -0.654379  [460800/2213439]
# Current batch training loss: -0.675391  [486400/2213439]
# Current batch training loss: -0.665909  [512000/2213439]
# Current batch training loss: -0.735948  [537600/2213439]
# Current batch training loss: -0.676004  [563200/2213439]
# Current batch training loss: -0.708795  [588800/2213439]
# Current batch training loss: -0.744436  [614400/2213439]
# Current batch training loss: -0.757844  [640000/2213439]
# Current batch training loss: -0.736935  [665600/2213439]
# Current batch training loss: -0.710178  [691200/2213439]
# Current batch training loss: -0.765894  [716800/2213439]
# Current batch training loss: -0.789355  [742400/2213439]
# Current batch training loss: -0.758922  [768000/2213439]
# Current batch training loss: -0.789315  [793600/2213439]
# Current batch training loss: -0.802936  [819200/2213439]
# Current batch training loss: -0.786734  [844800/2213439]
# Current batch training loss: -0.783573  [870400/2213439]
# Current batch training loss: -0.752895  [896000/2213439]
# Current batch training loss: -0.769273  [921600/2213439]
# Current batch training loss: -0.774522  [947200/2213439]
# Current batch training loss: -0.798156  [972800/2213439]
# Current batch training loss: -0.809707  [998400/2213439]
# Current batch training loss: -0.815057  [1024000/2213439]
# Current batch training loss: -0.838842  [1049600/2213439]
# Current batch training loss: -0.815524  [1075200/2213439]
# Current batch training loss: -0.852349  [1100800/2213439]
# Current batch training loss: -0.842630  [1126400/2213439]
# Current batch training loss: -0.825759  [1152000/2213439]
# Current batch training loss: -0.854533  [1177600/2213439]
# Current batch training loss: -0.838822  [1203200/2213439]
# Current batch training loss: -0.848964  [1228800/2213439]
# Current batch training loss: -0.807946  [1254400/2213439]
# Current batch training loss: -0.849424  [1280000/2213439]
# Current batch training loss: -0.807037  [1305600/2213439]
# Current batch training loss: -0.854011  [1331200/2213439]
# Current batch training loss: -0.831235  [1356800/2213439]
# Current batch training loss: -0.848050  [1382400/2213439]
# Current batch training loss: -0.827535  [1408000/2213439]
# Current batch training loss: -0.835385  [1433600/2213439]
# Current batch training loss: -0.832469  [1459200/2213439]
# Current batch training loss: -0.862910  [1484800/2213439]
# Current batch training loss: -0.852230  [1510400/2213439]
# Current batch training loss: -0.836697  [1536000/2213439]
# Current batch training loss: -0.864808  [1561600/2213439]
# Current batch training loss: -0.811976  [1587200/2213439]
# Current batch training loss: -0.853348  [1612800/2213439]
# Current batch training loss: -0.855642  [1638400/2213439]
# Current batch training loss: -0.862540  [1664000/2213439]
# Current batch training loss: -0.845289  [1689600/2213439]
# Current batch training loss: -0.853133  [1715200/2213439]
# Current batch training loss: -0.853615  [1740800/2213439]
# Current batch training loss: -0.869264  [1766400/2213439]
# Current batch training loss: -0.865104  [1792000/2213439]
# Current batch training loss: -0.852840  [1817600/2213439]
# Current batch training loss: -0.875689  [1843200/2213439]
# Current batch training loss: -0.878506  [1868800/2213439]
# Current batch training loss: -0.862958  [1894400/2213439]
# Current batch training loss: -0.865370  [1920000/2213439]
# Current batch training loss: -0.835773  [1945600/2213439]
# Current batch training loss: -0.860291  [1971200/2213439]
# Current batch training loss: -0.842234  [1996800/2213439]
# Current batch training loss: -0.848067  [2022400/2213439]
# Current batch training loss: -0.886460  [2048000/2213439]
# Current batch training loss: -0.873431  [2073600/2213439]
# Current batch training loss: -0.867178  [2099200/2213439]
# Current batch training loss: -0.889114  [2124800/2213439]
# Current batch training loss: -0.860773  [2150400/2213439]
# Current batch training loss: -0.858785  [2176000/2213439]
# Current batch training loss: -0.870407  [2201600/2213439]
# Training loss: -0.757998
# Validation loss: -0.881664
#
# Epoch 2
# -------------------------------
# Current batch training loss: -0.882015  [    0/2213439]
# Current batch training loss: -0.860057  [25600/2213439]
# Current batch training loss: -0.884480  [51200/2213439]
# Current batch training loss: -0.872915  [76800/2213439]
# Current batch training loss: -0.910972  [102400/2213439]
# Current batch training loss: -0.895598  [128000/2213439]
# Current batch training loss: -0.856526  [153600/2213439]
# Current batch training loss: -0.873864  [179200/2213439]
# Current batch training loss: -0.874764  [204800/2213439]
# Current batch training loss: -0.881543  [230400/2213439]
# Current batch training loss: -0.912657  [256000/2213439]
# Current batch training loss: -0.888435  [281600/2213439]
# Current batch training loss: -0.882723  [307200/2213439]
# Current batch training loss: -0.886127  [332800/2213439]
# Current batch training loss: -0.879240  [358400/2213439]
# Current batch training loss: -0.898889  [384000/2213439]
# Current batch training loss: -0.885885  [409600/2213439]
# Current batch training loss: -0.921506  [435200/2213439]
# Current batch training loss: -0.903025  [460800/2213439]
# Current batch training loss: -0.877261  [486400/2213439]
# Current batch training loss: -0.895511  [512000/2213439]
# Current batch training loss: -0.901803  [537600/2213439]
# Current batch training loss: -0.876438  [563200/2213439]
# Current batch training loss: -0.909769  [588800/2213439]
# Current batch training loss: -0.905029  [614400/2213439]
# Current batch training loss: -0.902350  [640000/2213439]
# Current batch training loss: -0.908513  [665600/2213439]
# Current batch training loss: -0.889025  [691200/2213439]
# Current batch training loss: -0.888389  [716800/2213439]
# Current batch training loss: -0.889352  [742400/2213439]
# Current batch training loss: -0.904080  [768000/2213439]
# Current batch training loss: -0.896054  [793600/2213439]
# Current batch training loss: -0.906941  [819200/2213439]
# Current batch training loss: -0.909225  [844800/2213439]
# Current batch training loss: -0.909416  [870400/2213439]
# Current batch training loss: -0.894491  [896000/2213439]
# Current batch training loss: -0.919802  [921600/2213439]
# Current batch training loss: -0.876227  [947200/2213439]
# Current batch training loss: -0.922535  [972800/2213439]
# Current batch training loss: -0.899265  [998400/2213439]
# Current batch training loss: -0.916998  [1024000/2213439]
# Current batch training loss: -0.904396  [1049600/2213439]
# Current batch training loss: -0.911224  [1075200/2213439]
# Current batch training loss: -0.897663  [1100800/2213439]
# Current batch training loss: -0.887630  [1126400/2213439]
# Current batch training loss: -0.900439  [1152000/2213439]
# Current batch training loss: -0.905781  [1177600/2213439]
# Current batch training loss: -0.914169  [1203200/2213439]
# Current batch training loss: -0.929949  [1228800/2213439]
# Current batch training loss: -0.913051  [1254400/2213439]
# Current batch training loss: -0.927274  [1280000/2213439]
# Current batch training loss: -0.906660  [1305600/2213439]
# Current batch training loss: -0.902112  [1331200/2213439]
# Current batch training loss: -0.926469  [1356800/2213439]
# Current batch training loss: -0.896850  [1382400/2213439]
# Current batch training loss: -0.925891  [1408000/2213439]
# Current batch training loss: -0.905563  [1433600/2213439]
# Current batch training loss: -0.915534  [1459200/2213439]
# Current batch training loss: -0.914258  [1484800/2213439]
# Current batch training loss: -0.918940  [1510400/2213439]
# Current batch training loss: -0.902537  [1536000/2213439]
# Current batch training loss: -0.906895  [1561600/2213439]
# Current batch training loss: -0.918022  [1587200/2213439]
# Current batch training loss: -0.922128  [1612800/2213439]
# Current batch training loss: -0.892737  [1638400/2213439]
# Current batch training loss: -0.903444  [1664000/2213439]
# Current batch training loss: -0.932707  [1689600/2213439]
# Current batch training loss: -0.895787  [1715200/2213439]
# Current batch training loss: -0.916492  [1740800/2213439]
# Current batch training loss: -0.910587  [1766400/2213439]
# Current batch training loss: -0.903344  [1792000/2213439]
# Current batch training loss: -0.926464  [1817600/2213439]
# Current batch training loss: -0.917070  [1843200/2213439]
# Current batch training loss: -0.901760  [1868800/2213439]
# Current batch training loss: -0.930997  [1894400/2213439]
# Current batch training loss: -0.904863  [1920000/2213439]
# Current batch training loss: -0.905101  [1945600/2213439]
# Current batch training loss: -0.897761  [1971200/2213439]
# Current batch training loss: -0.909715  [1996800/2213439]
# Current batch training loss: -0.916123  [2022400/2213439]
# Current batch training loss: -0.899158  [2048000/2213439]
# Current batch training loss: -0.914578  [2073600/2213439]
# Current batch training loss: -0.911947  [2099200/2213439]
# Current batch training loss: -0.925155  [2124800/2213439]
# Current batch training loss: -0.926176  [2150400/2213439]
# Current batch training loss: -0.903441  [2176000/2213439]
# Current batch training loss: -0.918166  [2201600/2213439]
# Training loss: -0.903597
# Validation loss: -0.913751
#
# Epoch 3
# -------------------------------
# Current batch training loss: -0.905937  [    0/2213439]
# Current batch training loss: -0.914022  [25600/2213439]
# Current batch training loss: -0.932156  [51200/2213439]
# Current batch training loss: -0.894660  [76800/2213439]
# Current batch training loss: -0.910418  [102400/2213439]
# Current batch training loss: -0.918604  [128000/2213439]
# Current batch training loss: -0.920295  [153600/2213439]
# Current batch training loss: -0.888412  [179200/2213439]
# Current batch training loss: -0.914726  [204800/2213439]
# Current batch training loss: -0.925211  [230400/2213439]
# Current batch training loss: -0.920730  [256000/2213439]
# Current batch training loss: -0.880264  [281600/2213439]
# Current batch training loss: -0.915800  [307200/2213439]
# Current batch training loss: -0.901585  [332800/2213439]
# Current batch training loss: -0.919108  [358400/2213439]
# Current batch training loss: -0.918720  [384000/2213439]
# Current batch training loss: -0.909041  [409600/2213439]
# Current batch training loss: -0.912105  [435200/2213439]
# Current batch training loss: -0.926887  [460800/2213439]
# Current batch training loss: -0.931631  [486400/2213439]
# Current batch training loss: -0.923278  [512000/2213439]
# Current batch training loss: -0.931983  [537600/2213439]
# Current batch training loss: -0.923124  [563200/2213439]
# Current batch training loss: -0.919427  [588800/2213439]
# Current batch training loss: -0.936356  [614400/2213439]
# Current batch training loss: -0.912699  [640000/2213439]
# Current batch training loss: -0.921075  [665600/2213439]
# Current batch training loss: -0.913073  [691200/2213439]
# Current batch training loss: -0.932133  [716800/2213439]
# Current batch training loss: -0.902784  [742400/2213439]
# Current batch training loss: -0.914857  [768000/2213439]
# Current batch training loss: -0.915876  [793600/2213439]
# Current batch training loss: -0.918364  [819200/2213439]
# Current batch training loss: -0.937053  [844800/2213439]
# Current batch training loss: -0.929569  [870400/2213439]
# Current batch training loss: -0.934492  [896000/2213439]
# Current batch training loss: -0.892571  [921600/2213439]
# Current batch training loss: -0.894576  [947200/2213439]
# Current batch training loss: -0.912516  [972800/2213439]
# Current batch training loss: -0.933373  [998400/2213439]
# Current batch training loss: -0.917762  [1024000/2213439]
# Current batch training loss: -0.928586  [1049600/2213439]
# Current batch training loss: -0.915588  [1075200/2213439]
# Current batch training loss: -0.918313  [1100800/2213439]
# Current batch training loss: -0.912364  [1126400/2213439]
# Current batch training loss: -0.932237  [1152000/2213439]
# Current batch training loss: -0.934591  [1177600/2213439]
# Current batch training loss: -0.911032  [1203200/2213439]
# Current batch training loss: -0.899947  [1228800/2213439]
# Current batch training loss: -0.932814  [1254400/2213439]
# Current batch training loss: -0.928497  [1280000/2213439]
# Current batch training loss: -0.917073  [1305600/2213439]
# Current batch training loss: -0.915937  [1331200/2213439]
# Current batch training loss: -0.920045  [1356800/2213439]
# Current batch training loss: -0.910139  [1382400/2213439]
# Current batch training loss: -0.919719  [1408000/2213439]
# Current batch training loss: -0.909101  [1433600/2213439]
# Current batch training loss: -0.904582  [1459200/2213439]
# Current batch training loss: -0.910736  [1484800/2213439]
# Current batch training loss: -0.921595  [1510400/2213439]
# Current batch training loss: -0.923498  [1536000/2213439]
# Current batch training loss: -0.898019  [1561600/2213439]
# Current batch training loss: -0.914895  [1587200/2213439]
# Current batch training loss: -0.929650  [1612800/2213439]
# Current batch training loss: -0.926939  [1638400/2213439]
# Current batch training loss: -0.901968  [1664000/2213439]
# Current batch training loss: -0.925295  [1689600/2213439]
# Current batch training loss: -0.916691  [1715200/2213439]
# Current batch training loss: -0.921926  [1740800/2213439]
# Current batch training loss: -0.923257  [1766400/2213439]
# Current batch training loss: -0.902923  [1792000/2213439]
# Current batch training loss: -0.923805  [1817600/2213439]
# Current batch training loss: -0.916567  [1843200/2213439]
# Current batch training loss: -0.912689  [1868800/2213439]
# Current batch training loss: -0.921399  [1894400/2213439]
# Current batch training loss: -0.915119  [1920000/2213439]
# Current batch training loss: -0.921199  [1945600/2213439]
# Current batch training loss: -0.911254  [1971200/2213439]
# Current batch training loss: -0.929490  [1996800/2213439]
# Current batch training loss: -0.923371  [2022400/2213439]
# Current batch training loss: -0.885890  [2048000/2213439]
# Current batch training loss: -0.927151  [2073600/2213439]
# Current batch training loss: -0.920243  [2099200/2213439]
# Current batch training loss: -0.913912  [2124800/2213439]
# Current batch training loss: -0.933717  [2150400/2213439]
# Current batch training loss: -0.910228  [2176000/2213439]
# Current batch training loss: -0.938390  [2201600/2213439]
# Training loss: -0.915890
# Validation loss: -0.917248
#
# Epoch 4
# -------------------------------
# Current batch training loss: -0.911713  [    0/2213439]
# Current batch training loss: -0.905070  [25600/2213439]
# Current batch training loss: -0.916575  [51200/2213439]
# Current batch training loss: -0.905328  [76800/2213439]
# Current batch training loss: -0.926836  [102400/2213439]
# Current batch training loss: -0.901525  [128000/2213439]
# Current batch training loss: -0.925116  [153600/2213439]
# Current batch training loss: -0.923037  [179200/2213439]
# Current batch training loss: -0.928222  [204800/2213439]
# Current batch training loss: -0.929857  [230400/2213439]
# Current batch training loss: -0.910602  [256000/2213439]
# Current batch training loss: -0.922494  [281600/2213439]
# Current batch training loss: -0.920681  [307200/2213439]
# Current batch training loss: -0.920874  [332800/2213439]
# Current batch training loss: -0.930735  [358400/2213439]
# Current batch training loss: -0.914676  [384000/2213439]
# Current batch training loss: -0.897600  [409600/2213439]
# Current batch training loss: -0.896776  [435200/2213439]
# Current batch training loss: -0.914990  [460800/2213439]
# Current batch training loss: -0.921297  [486400/2213439]
# Current batch training loss: -0.932754  [512000/2213439]
# Current batch training loss: -0.927509  [537600/2213439]
# Current batch training loss: -0.922846  [563200/2213439]
# Current batch training loss: -0.909282  [588800/2213439]
# Current batch training loss: -0.920606  [614400/2213439]
# Current batch training loss: -0.919696  [640000/2213439]
# Current batch training loss: -0.911142  [665600/2213439]
# Current batch training loss: -0.926001  [691200/2213439]
# Current batch training loss: -0.928365  [716800/2213439]
# Current batch training loss: -0.907708  [742400/2213439]
# Current batch training loss: -0.905270  [768000/2213439]
# Current batch training loss: -0.918539  [793600/2213439]
# Current batch training loss: -0.915126  [819200/2213439]
# Current batch training loss: -0.927966  [844800/2213439]
# Current batch training loss: -0.908246  [870400/2213439]
# Current batch training loss: -0.930379  [896000/2213439]
# Current batch training loss: -0.915417  [921600/2213439]
# Current batch training loss: -0.895782  [947200/2213439]
# Current batch training loss: -0.927620  [972800/2213439]
# Current batch training loss: -0.928313  [998400/2213439]
# Current batch training loss: -0.914122  [1024000/2213439]
# Current batch training loss: -0.913978  [1049600/2213439]
# Current batch training loss: -0.911023  [1075200/2213439]
# Current batch training loss: -0.926576  [1100800/2213439]
# Current batch training loss: -0.919934  [1126400/2213439]
# Current batch training loss: -0.906806  [1152000/2213439]
# Current batch training loss: -0.904260  [1177600/2213439]
# Current batch training loss: -0.920992  [1203200/2213439]
# Current batch training loss: -0.909573  [1228800/2213439]
# Current batch training loss: -0.922045  [1254400/2213439]
# Current batch training loss: -0.921981  [1280000/2213439]
# Current batch training loss: -0.922422  [1305600/2213439]
# Current batch training loss: -0.916716  [1331200/2213439]
# Current batch training loss: -0.946615  [1356800/2213439]
# Current batch training loss: -0.922251  [1382400/2213439]
# Current batch training loss: -0.926837  [1408000/2213439]
# Current batch training loss: -0.916016  [1433600/2213439]
# Current batch training loss: -0.922621  [1459200/2213439]
# Current batch training loss: -0.914858  [1484800/2213439]
# Current batch training loss: -0.931179  [1510400/2213439]
# Current batch training loss: -0.907930  [1536000/2213439]
# Current batch training loss: -0.916990  [1561600/2213439]
# Current batch training loss: -0.944469  [1587200/2213439]
# Current batch training loss: -0.934248  [1612800/2213439]
# Current batch training loss: -0.897868  [1638400/2213439]
# Current batch training loss: -0.891010  [1664000/2213439]
# Current batch training loss: -0.918469  [1689600/2213439]
# Current batch training loss: -0.931510  [1715200/2213439]
# Current batch training loss: -0.910285  [1740800/2213439]
# Current batch training loss: -0.910451  [1766400/2213439]
# Current batch training loss: -0.921992  [1792000/2213439]
# Current batch training loss: -0.925410  [1817600/2213439]
# Current batch training loss: -0.937443  [1843200/2213439]
# Current batch training loss: -0.928943  [1868800/2213439]
# Current batch training loss: -0.926530  [1894400/2213439]
# Current batch training loss: -0.934005  [1920000/2213439]
# Current batch training loss: -0.910050  [1945600/2213439]
# Current batch training loss: -0.900334  [1971200/2213439]
# Current batch training loss: -0.891207  [1996800/2213439]
# Current batch training loss: -0.918198  [2022400/2213439]
# Current batch training loss: -0.919230  [2048000/2213439]
# Current batch training loss: -0.908122  [2073600/2213439]
# Current batch training loss: -0.911973  [2099200/2213439]
# Current batch training loss: -0.927078  [2124800/2213439]
# Current batch training loss: -0.922733  [2150400/2213439]
# Current batch training loss: -0.945120  [2176000/2213439]
# Current batch training loss: -0.912864  [2201600/2213439]
# Training loss: -0.919630
# Validation loss: -0.918768
#
# Epoch 5
# -------------------------------
# Current batch training loss: -0.935955  [    0/2213439]
# Current batch training loss: -0.936797  [25600/2213439]
# Current batch training loss: -0.928643  [51200/2213439]
# Current batch training loss: -0.929338  [76800/2213439]
# Current batch training loss: -0.939142  [102400/2213439]
# Current batch training loss: -0.940542  [128000/2213439]
# Current batch training loss: -0.913705  [153600/2213439]
# Current batch training loss: -0.925516  [179200/2213439]
# Current batch training loss: -0.923668  [204800/2213439]
# Current batch training loss: -0.934765  [230400/2213439]
# Current batch training loss: -0.929937  [256000/2213439]
# Current batch training loss: -0.925452  [281600/2213439]
# Current batch training loss: -0.929509  [307200/2213439]
# Current batch training loss: -0.934985  [332800/2213439]
# Current batch training loss: -0.935135  [358400/2213439]
# Current batch training loss: -0.926464  [384000/2213439]
# Current batch training loss: -0.935135  [409600/2213439]
# Current batch training loss: -0.900329  [435200/2213439]
# Current batch training loss: -0.918061  [460800/2213439]
# Current batch training loss: -0.925098  [486400/2213439]
# Current batch training loss: -0.938465  [512000/2213439]
# Current batch training loss: -0.914575  [537600/2213439]
# Current batch training loss: -0.926786  [563200/2213439]
# Current batch training loss: -0.930885  [588800/2213439]
# Current batch training loss: -0.916472  [614400/2213439]
# Current batch training loss: -0.936093  [640000/2213439]
# Current batch training loss: -0.907900  [665600/2213439]
# Current batch training loss: -0.921923  [691200/2213439]
# Current batch training loss: -0.932880  [716800/2213439]
# Current batch training loss: -0.918489  [742400/2213439]
# Current batch training loss: -0.909183  [768000/2213439]
# Current batch training loss: -0.927797  [793600/2213439]
# Current batch training loss: -0.932231  [819200/2213439]
# Current batch training loss: -0.938902  [844800/2213439]
# Current batch training loss: -0.927688  [870400/2213439]
# Current batch training loss: -0.931316  [896000/2213439]
# Current batch training loss: -0.918270  [921600/2213439]
# Current batch training loss: -0.918396  [947200/2213439]
# Current batch training loss: -0.917690  [972800/2213439]
# Current batch training loss: -0.917070  [998400/2213439]
# Current batch training loss: -0.930555  [1024000/2213439]
# Current batch training loss: -0.933766  [1049600/2213439]
# Current batch training loss: -0.919384  [1075200/2213439]
# Current batch training loss: -0.899341  [1100800/2213439]
# Current batch training loss: -0.941766  [1126400/2213439]
# Current batch training loss: -0.906042  [1152000/2213439]
# Current batch training loss: -0.928180  [1177600/2213439]
# Current batch training loss: -0.926314  [1203200/2213439]
# Current batch training loss: -0.921617  [1228800/2213439]
# Current batch training loss: -0.926470  [1254400/2213439]
# Current batch training loss: -0.925422  [1280000/2213439]
# Current batch training loss: -0.919882  [1305600/2213439]
# Current batch training loss: -0.905949  [1331200/2213439]
# Current batch training loss: -0.911310  [1356800/2213439]
# Current batch training loss: -0.907796  [1382400/2213439]
# Current batch training loss: -0.929355  [1408000/2213439]
# Current batch training loss: -0.925047  [1433600/2213439]
# Current batch training loss: -0.921709  [1459200/2213439]
# Current batch training loss: -0.919237  [1484800/2213439]
# Current batch training loss: -0.912562  [1510400/2213439]
# Current batch training loss: -0.908599  [1536000/2213439]
# Current batch training loss: -0.929465  [1561600/2213439]
# Current batch training loss: -0.900465  [1587200/2213439]
# Current batch training loss: -0.896580  [1612800/2213439]
# Current batch training loss: -0.897856  [1638400/2213439]
# Current batch training loss: -0.928359  [1664000/2213439]
# Current batch training loss: -0.897988  [1689600/2213439]
# Current batch training loss: -0.916890  [1715200/2213439]
# Current batch training loss: -0.910440  [1740800/2213439]
# Current batch training loss: -0.937182  [1766400/2213439]
# Current batch training loss: -0.931657  [1792000/2213439]
# Current batch training loss: -0.912349  [1817600/2213439]
# Current batch training loss: -0.896160  [1843200/2213439]
# Current batch training loss: -0.923890  [1868800/2213439]
# Current batch training loss: -0.918113  [1894400/2213439]
# Current batch training loss: -0.915440  [1920000/2213439]
# Current batch training loss: -0.916640  [1945600/2213439]
# Current batch training loss: -0.919814  [1971200/2213439]
# Current batch training loss: -0.917848  [1996800/2213439]
# Current batch training loss: -0.928599  [2022400/2213439]
# Current batch training loss: -0.912329  [2048000/2213439]
# Current batch training loss: -0.928041  [2073600/2213439]
# Current batch training loss: -0.913244  [2099200/2213439]
# Current batch training loss: -0.904489  [2124800/2213439]
# Current batch training loss: -0.912138  [2150400/2213439]
# Current batch training loss: -0.919332  [2176000/2213439]
# Current batch training loss: -0.917799  [2201600/2213439]
# Training loss: -0.921767
# Validation loss: -0.920117
#
# Epoch 6
# -------------------------------
# Current batch training loss: -0.931597  [    0/2213439]
# Current batch training loss: -0.927577  [25600/2213439]
# Current batch training loss: -0.910864  [51200/2213439]
# Current batch training loss: -0.912179  [76800/2213439]
# Current batch training loss: -0.931545  [102400/2213439]
# Current batch training loss: -0.935826  [128000/2213439]
# Current batch training loss: -0.927431  [153600/2213439]
# Current batch training loss: -0.931706  [179200/2213439]
# Current batch training loss: -0.930904  [204800/2213439]
# Current batch training loss: -0.930714  [230400/2213439]
# Current batch training loss: -0.923330  [256000/2213439]
# Current batch training loss: -0.938381  [281600/2213439]
# Current batch training loss: -0.905270  [307200/2213439]
# Current batch training loss: -0.908856  [332800/2213439]
# Current batch training loss: -0.910209  [358400/2213439]
# Current batch training loss: -0.911040  [384000/2213439]
# Current batch training loss: -0.939012  [409600/2213439]
# Current batch training loss: -0.930723  [435200/2213439]
# Current batch training loss: -0.927628  [460800/2213439]
# Current batch training loss: -0.912945  [486400/2213439]
# Current batch training loss: -0.929392  [512000/2213439]
# Current batch training loss: -0.929141  [537600/2213439]
# Current batch training loss: -0.911391  [563200/2213439]
# Current batch training loss: -0.922526  [588800/2213439]
# Current batch training loss: -0.918663  [614400/2213439]
# Current batch training loss: -0.927253  [640000/2213439]
# Current batch training loss: -0.921343  [665600/2213439]
# Current batch training loss: -0.924614  [691200/2213439]
# Current batch training loss: -0.929588  [716800/2213439]
# Current batch training loss: -0.926589  [742400/2213439]
# Current batch training loss: -0.921291  [768000/2213439]
# Current batch training loss: -0.925105  [793600/2213439]
# Current batch training loss: -0.922591  [819200/2213439]
# Current batch training loss: -0.933940  [844800/2213439]
# Current batch training loss: -0.913999  [870400/2213439]
# Current batch training loss: -0.921975  [896000/2213439]
# Current batch training loss: -0.935093  [921600/2213439]
# Current batch training loss: -0.935975  [947200/2213439]
# Current batch training loss: -0.934947  [972800/2213439]
# Current batch training loss: -0.914626  [998400/2213439]
# Current batch training loss: -0.933093  [1024000/2213439]
# Current batch training loss: -0.921012  [1049600/2213439]
# Current batch training loss: -0.924850  [1075200/2213439]
# Current batch training loss: -0.921231  [1100800/2213439]
# Current batch training loss: -0.924220  [1126400/2213439]
# Current batch training loss: -0.939103  [1152000/2213439]
# Current batch training loss: -0.927542  [1177600/2213439]
# Current batch training loss: -0.913254  [1203200/2213439]
# Current batch training loss: -0.899587  [1228800/2213439]
# Current batch training loss: -0.936636  [1254400/2213439]
# Current batch training loss: -0.913186  [1280000/2213439]
# Current batch training loss: -0.935356  [1305600/2213439]
# Current batch training loss: -0.922247  [1331200/2213439]
# Current batch training loss: -0.922140  [1356800/2213439]
# Current batch training loss: -0.917959  [1382400/2213439]
# Current batch training loss: -0.918347  [1408000/2213439]
# Current batch training loss: -0.907858  [1433600/2213439]
# Current batch training loss: -0.925577  [1459200/2213439]
# Current batch training loss: -0.931903  [1484800/2213439]
# Current batch training loss: -0.912226  [1510400/2213439]
# Current batch training loss: -0.934340  [1536000/2213439]
# Current batch training loss: -0.922014  [1561600/2213439]
# Current batch training loss: -0.938309  [1587200/2213439]
# Current batch training loss: -0.926399  [1612800/2213439]
# Current batch training loss: -0.910518  [1638400/2213439]
# Current batch training loss: -0.947029  [1664000/2213439]
# Current batch training loss: -0.921553  [1689600/2213439]
# Current batch training loss: -0.936453  [1715200/2213439]
# Current batch training loss: -0.898832  [1740800/2213439]
# Current batch training loss: -0.921667  [1766400/2213439]
# Current batch training loss: -0.936123  [1792000/2213439]
# Current batch training loss: -0.942050  [1817600/2213439]
# Current batch training loss: -0.927723  [1843200/2213439]
# Current batch training loss: -0.921174  [1868800/2213439]
# Current batch training loss: -0.912192  [1894400/2213439]
# Current batch training loss: -0.904443  [1920000/2213439]
# Current batch training loss: -0.933955  [1945600/2213439]
# Current batch training loss: -0.923192  [1971200/2213439]
# Current batch training loss: -0.922287  [1996800/2213439]
# Current batch training loss: -0.921415  [2022400/2213439]
# Current batch training loss: -0.936713  [2048000/2213439]
# Current batch training loss: -0.940113  [2073600/2213439]
# Current batch training loss: -0.927292  [2099200/2213439]
# Current batch training loss: -0.930725  [2124800/2213439]
# Current batch training loss: -0.920900  [2150400/2213439]
# Current batch training loss: -0.917228  [2176000/2213439]
# Current batch training loss: -0.925562  [2201600/2213439]
# Training loss: -0.923543
# Validation loss: -0.919756
#
# Epoch 7
# -------------------------------
# Current batch training loss: -0.933668  [    0/2213439]
# Current batch training loss: -0.927912  [25600/2213439]
# Current batch training loss: -0.925503  [51200/2213439]
# Current batch training loss: -0.937328  [76800/2213439]
# Current batch training loss: -0.944708  [102400/2213439]
# Current batch training loss: -0.907136  [128000/2213439]
# Current batch training loss: -0.923197  [153600/2213439]
# Current batch training loss: -0.920434  [179200/2213439]
# Current batch training loss: -0.929792  [204800/2213439]
# Current batch training loss: -0.928887  [230400/2213439]
# Current batch training loss: -0.909469  [256000/2213439]
# Current batch training loss: -0.917012  [281600/2213439]
# Current batch training loss: -0.923135  [307200/2213439]
# Current batch training loss: -0.912114  [332800/2213439]
# Current batch training loss: -0.934686  [358400/2213439]
# Current batch training loss: -0.918264  [384000/2213439]
# Current batch training loss: -0.936535  [409600/2213439]
# Current batch training loss: -0.910959  [435200/2213439]
# Current batch training loss: -0.919474  [460800/2213439]
# Current batch training loss: -0.925219  [486400/2213439]
# Current batch training loss: -0.928419  [512000/2213439]
# Current batch training loss: -0.932940  [537600/2213439]
# Current batch training loss: -0.938405  [563200/2213439]
# Current batch training loss: -0.919325  [588800/2213439]
# Current batch training loss: -0.931138  [614400/2213439]
# Current batch training loss: -0.937842  [640000/2213439]
# Current batch training loss: -0.921153  [665600/2213439]
# Current batch training loss: -0.897966  [691200/2213439]
# Current batch training loss: -0.907198  [716800/2213439]
# Current batch training loss: -0.920982  [742400/2213439]
# Current batch training loss: -0.934806  [768000/2213439]
# Current batch training loss: -0.916543  [793600/2213439]
# Current batch training loss: -0.930312  [819200/2213439]
# Current batch training loss: -0.932710  [844800/2213439]
# Current batch training loss: -0.931244  [870400/2213439]
# Current batch training loss: -0.929919  [896000/2213439]
# Current batch training loss: -0.932819  [921600/2213439]
# Current batch training loss: -0.919656  [947200/2213439]
# Current batch training loss: -0.919733  [972800/2213439]
# Current batch training loss: -0.931135  [998400/2213439]
# Current batch training loss: -0.928326  [1024000/2213439]
# Current batch training loss: -0.907207  [1049600/2213439]
# Current batch training loss: -0.921802  [1075200/2213439]
# Current batch training loss: -0.925809  [1100800/2213439]
# Current batch training loss: -0.923435  [1126400/2213439]
# Current batch training loss: -0.922639  [1152000/2213439]
# Current batch training loss: -0.929928  [1177600/2213439]
# Current batch training loss: -0.924454  [1203200/2213439]
# Current batch training loss: -0.919249  [1228800/2213439]
# Current batch training loss: -0.937321  [1254400/2213439]
# Current batch training loss: -0.935023  [1280000/2213439]
# Current batch training loss: -0.903887  [1305600/2213439]
# Current batch training loss: -0.928860  [1331200/2213439]
# Current batch training loss: -0.941472  [1356800/2213439]
# Current batch training loss: -0.931223  [1382400/2213439]
# Current batch training loss: -0.927193  [1408000/2213439]
# Current batch training loss: -0.934077  [1433600/2213439]
# Current batch training loss: -0.918252  [1459200/2213439]
# Current batch training loss: -0.908889  [1484800/2213439]
# Current batch training loss: -0.927256  [1510400/2213439]
# Current batch training loss: -0.923001  [1536000/2213439]
# Current batch training loss: -0.915514  [1561600/2213439]
# Current batch training loss: -0.935606  [1587200/2213439]
# Current batch training loss: -0.922391  [1612800/2213439]
# Current batch training loss: -0.921661  [1638400/2213439]
# Current batch training loss: -0.934390  [1664000/2213439]
# Current batch training loss: -0.918817  [1689600/2213439]
# Current batch training loss: -0.920892  [1715200/2213439]
# Current batch training loss: -0.926637  [1740800/2213439]
# Current batch training loss: -0.920250  [1766400/2213439]
# Current batch training loss: -0.932908  [1792000/2213439]
# Current batch training loss: -0.926723  [1817600/2213439]
# Current batch training loss: -0.908798  [1843200/2213439]
# Current batch training loss: -0.919317  [1868800/2213439]
# Current batch training loss: -0.935139  [1894400/2213439]
# Current batch training loss: -0.932087  [1920000/2213439]
# Current batch training loss: -0.914258  [1945600/2213439]
# Current batch training loss: -0.923037  [1971200/2213439]
# Current batch training loss: -0.937894  [1996800/2213439]
# Current batch training loss: -0.915392  [2022400/2213439]
# Current batch training loss: -0.926070  [2048000/2213439]
# Current batch training loss: -0.915883  [2073600/2213439]
# Current batch training loss: -0.928600  [2099200/2213439]
# Current batch training loss: -0.926157  [2124800/2213439]
# Current batch training loss: -0.928868  [2150400/2213439]
# Current batch training loss: -0.929415  [2176000/2213439]
# Current batch training loss: -0.907573  [2201600/2213439]
# Training loss: -0.924990
# Validation loss: -0.920637
#
# Epoch 8
# -------------------------------
# Current batch training loss: -0.920820  [    0/2213439]
# Current batch training loss: -0.927867  [25600/2213439]
# Current batch training loss: -0.916622  [51200/2213439]
# Current batch training loss: -0.937206  [76800/2213439]
# Current batch training loss: -0.936899  [102400/2213439]
# Current batch training loss: -0.919981  [128000/2213439]
# Current batch training loss: -0.943390  [153600/2213439]
# Current batch training loss: -0.930468  [179200/2213439]
# Current batch training loss: -0.929614  [204800/2213439]
# Current batch training loss: -0.937898  [230400/2213439]
# Current batch training loss: -0.924252  [256000/2213439]
# Current batch training loss: -0.943518  [281600/2213439]
# Current batch training loss: -0.918788  [307200/2213439]
# Current batch training loss: -0.917008  [332800/2213439]
# Current batch training loss: -0.934630  [358400/2213439]
# Current batch training loss: -0.923116  [384000/2213439]
# Current batch training loss: -0.920359  [409600/2213439]
# Current batch training loss: -0.915723  [435200/2213439]
# Current batch training loss: -0.920211  [460800/2213439]
# Current batch training loss: -0.918679  [486400/2213439]
# Current batch training loss: -0.931432  [512000/2213439]
# Current batch training loss: -0.930328  [537600/2213439]
# Current batch training loss: -0.914921  [563200/2213439]
# Current batch training loss: -0.927190  [588800/2213439]
# Current batch training loss: -0.935326  [614400/2213439]
# Current batch training loss: -0.931977  [640000/2213439]
# Current batch training loss: -0.927503  [665600/2213439]
# Current batch training loss: -0.929654  [691200/2213439]
# Current batch training loss: -0.909093  [716800/2213439]
# Current batch training loss: -0.914921  [742400/2213439]
# Current batch training loss: -0.934357  [768000/2213439]
# Current batch training loss: -0.914252  [793600/2213439]
# Current batch training loss: -0.920793  [819200/2213439]
# Current batch training loss: -0.890738  [844800/2213439]
# Current batch training loss: -0.936186  [870400/2213439]
# Current batch training loss: -0.934674  [896000/2213439]
# Current batch training loss: -0.928053  [921600/2213439]
# Current batch training loss: -0.939099  [947200/2213439]
# Current batch training loss: -0.940481  [972800/2213439]
# Current batch training loss: -0.918688  [998400/2213439]
# Current batch training loss: -0.943900  [1024000/2213439]
# Current batch training loss: -0.929317  [1049600/2213439]
# Current batch training loss: -0.924407  [1075200/2213439]
# Current batch training loss: -0.926708  [1100800/2213439]
# Current batch training loss: -0.936912  [1126400/2213439]
# Current batch training loss: -0.932367  [1152000/2213439]
# Current batch training loss: -0.921890  [1177600/2213439]
# Current batch training loss: -0.929544  [1203200/2213439]
# Current batch training loss: -0.943289  [1228800/2213439]
# Current batch training loss: -0.930603  [1254400/2213439]
# Current batch training loss: -0.904170  [1280000/2213439]
# Current batch training loss: -0.946624  [1305600/2213439]
# Current batch training loss: -0.925819  [1331200/2213439]
# Current batch training loss: -0.910058  [1356800/2213439]
# Current batch training loss: -0.925690  [1382400/2213439]
# Current batch training loss: -0.925954  [1408000/2213439]
# Current batch training loss: -0.942850  [1433600/2213439]
# Current batch training loss: -0.918337  [1459200/2213439]
# Current batch training loss: -0.917088  [1484800/2213439]
# Current batch training loss: -0.936526  [1510400/2213439]
# Current batch training loss: -0.922648  [1536000/2213439]
# Current batch training loss: -0.913467  [1561600/2213439]
# Current batch training loss: -0.923544  [1587200/2213439]
# Current batch training loss: -0.940109  [1612800/2213439]
# Current batch training loss: -0.944583  [1638400/2213439]
# Current batch training loss: -0.940981  [1664000/2213439]
# Current batch training loss: -0.936753  [1689600/2213439]
# Current batch training loss: -0.922262  [1715200/2213439]
# Current batch training loss: -0.915715  [1740800/2213439]
# Current batch training loss: -0.928756  [1766400/2213439]
# Current batch training loss: -0.919325  [1792000/2213439]
# Current batch training loss: -0.921355  [1817600/2213439]
# Current batch training loss: -0.930937  [1843200/2213439]
# Current batch training loss: -0.936653  [1868800/2213439]
# Current batch training loss: -0.923951  [1894400/2213439]
# Current batch training loss: -0.936364  [1920000/2213439]
# Current batch training loss: -0.924327  [1945600/2213439]
# Current batch training loss: -0.918896  [1971200/2213439]
# Current batch training loss: -0.933227  [1996800/2213439]
# Current batch training loss: -0.927958  [2022400/2213439]
# Current batch training loss: -0.938809  [2048000/2213439]
# Current batch training loss: -0.918294  [2073600/2213439]
# Current batch training loss: -0.920733  [2099200/2213439]
# Current batch training loss: -0.931446  [2124800/2213439]
# Current batch training loss: -0.933514  [2150400/2213439]
# Current batch training loss: -0.914829  [2176000/2213439]
# Current batch training loss: -0.930816  [2201600/2213439]
# Training loss: -0.926205
# Validation loss: -0.920842
#
# Epoch 9
# -------------------------------
# Current batch training loss: -0.932389  [    0/2213439]
# Current batch training loss: -0.931995  [25600/2213439]
# Current batch training loss: -0.932401  [51200/2213439]
# Current batch training loss: -0.928279  [76800/2213439]
# Current batch training loss: -0.927908  [102400/2213439]
# Current batch training loss: -0.917606  [128000/2213439]
# Current batch training loss: -0.936281  [153600/2213439]
# Current batch training loss: -0.928949  [179200/2213439]
# Current batch training loss: -0.930818  [204800/2213439]
# Current batch training loss: -0.929598  [230400/2213439]
# Current batch training loss: -0.902043  [256000/2213439]
# Current batch training loss: -0.945955  [281600/2213439]
# Current batch training loss: -0.949497  [307200/2213439]
# Current batch training loss: -0.918230  [332800/2213439]
# Current batch training loss: -0.911806  [358400/2213439]
# Current batch training loss: -0.935393  [384000/2213439]
# Current batch training loss: -0.934006  [409600/2213439]
# Current batch training loss: -0.937925  [435200/2213439]
# Current batch training loss: -0.920174  [460800/2213439]
# Current batch training loss: -0.929799  [486400/2213439]
# Current batch training loss: -0.928027  [512000/2213439]
# Current batch training loss: -0.934738  [537600/2213439]
# Current batch training loss: -0.925061  [563200/2213439]
# Current batch training loss: -0.903900  [588800/2213439]
# Current batch training loss: -0.930323  [614400/2213439]
# Current batch training loss: -0.924386  [640000/2213439]
# Current batch training loss: -0.929622  [665600/2213439]
# Current batch training loss: -0.940903  [691200/2213439]
# Current batch training loss: -0.906088  [716800/2213439]
# Current batch training loss: -0.922263  [742400/2213439]
# Current batch training loss: -0.929905  [768000/2213439]
# Current batch training loss: -0.924055  [793600/2213439]
# Current batch training loss: -0.914879  [819200/2213439]
# Current batch training loss: -0.932812  [844800/2213439]
# Current batch training loss: -0.926451  [870400/2213439]
# Current batch training loss: -0.918298  [896000/2213439]
# Current batch training loss: -0.930725  [921600/2213439]
# Current batch training loss: -0.910175  [947200/2213439]
# Current batch training loss: -0.923582  [972800/2213439]
# Current batch training loss: -0.935290  [998400/2213439]
# Current batch training loss: -0.951535  [1024000/2213439]
# Current batch training loss: -0.945957  [1049600/2213439]
# Current batch training loss: -0.929522  [1075200/2213439]
# Current batch training loss: -0.938134  [1100800/2213439]
# Current batch training loss: -0.924074  [1126400/2213439]
# Current batch training loss: -0.924128  [1152000/2213439]
# Current batch training loss: -0.941123  [1177600/2213439]
# Current batch training loss: -0.936795  [1203200/2213439]
# Current batch training loss: -0.915383  [1228800/2213439]
# Current batch training loss: -0.923694  [1254400/2213439]
# Current batch training loss: -0.920230  [1280000/2213439]
# Current batch training loss: -0.927189  [1305600/2213439]
# Current batch training loss: -0.911137  [1331200/2213439]
# Current batch training loss: -0.938234  [1356800/2213439]
# Current batch training loss: -0.938604  [1382400/2213439]
# Current batch training loss: -0.927005  [1408000/2213439]
# Current batch training loss: -0.916755  [1433600/2213439]
# Current batch training loss: -0.929134  [1459200/2213439]
# Current batch training loss: -0.931400  [1484800/2213439]
# Current batch training loss: -0.920477  [1510400/2213439]
# Current batch training loss: -0.938889  [1536000/2213439]
# Current batch training loss: -0.918063  [1561600/2213439]
# Current batch training loss: -0.905786  [1587200/2213439]
# Current batch training loss: -0.924050  [1612800/2213439]
# Current batch training loss: -0.922660  [1638400/2213439]
# Current batch training loss: -0.924513  [1664000/2213439]
# Current batch training loss: -0.927759  [1689600/2213439]
# Current batch training loss: -0.940086  [1715200/2213439]
# Current batch training loss: -0.945450  [1740800/2213439]
# Current batch training loss: -0.922592  [1766400/2213439]
# Current batch training loss: -0.918017  [1792000/2213439]
# Current batch training loss: -0.946181  [1817600/2213439]
# Current batch training loss: -0.939530  [1843200/2213439]
# Current batch training loss: -0.930975  [1868800/2213439]
# Current batch training loss: -0.924491  [1894400/2213439]
# Current batch training loss: -0.939859  [1920000/2213439]
# Current batch training loss: -0.923620  [1945600/2213439]
# Current batch training loss: -0.916587  [1971200/2213439]
# Current batch training loss: -0.931814  [1996800/2213439]
# Current batch training loss: -0.927859  [2022400/2213439]
# Current batch training loss: -0.944096  [2048000/2213439]
# Current batch training loss: -0.915336  [2073600/2213439]
# Current batch training loss: -0.930599  [2099200/2213439]
# Current batch training loss: -0.933730  [2124800/2213439]
# Current batch training loss: -0.918097  [2150400/2213439]
# Current batch training loss: -0.923150  [2176000/2213439]
# Current batch training loss: -0.938764  [2201600/2213439]
# Training loss: -0.927372
# Validation loss: -0.921376
#
# Epoch 10
# -------------------------------
# Current batch training loss: -0.946463  [    0/2213439]
# Current batch training loss: -0.938094  [25600/2213439]
# Current batch training loss: -0.942399  [51200/2213439]
# Current batch training loss: -0.943149  [76800/2213439]
# Current batch training loss: -0.931878  [102400/2213439]
# Current batch training loss: -0.912585  [128000/2213439]
# Current batch training loss: -0.929135  [153600/2213439]
# Current batch training loss: -0.930786  [179200/2213439]
# Current batch training loss: -0.937784  [204800/2213439]
# Current batch training loss: -0.896062  [230400/2213439]
# Current batch training loss: -0.941331  [256000/2213439]
# Current batch training loss: -0.914329  [281600/2213439]
# Current batch training loss: -0.926910  [307200/2213439]
# Current batch training loss: -0.919427  [332800/2213439]
# Current batch training loss: -0.932294  [358400/2213439]
# Current batch training loss: -0.936525  [384000/2213439]
# Current batch training loss: -0.911697  [409600/2213439]
# Current batch training loss: -0.940697  [435200/2213439]
# Current batch training loss: -0.927780  [460800/2213439]
# Current batch training loss: -0.935935  [486400/2213439]
# Current batch training loss: -0.944805  [512000/2213439]
# Current batch training loss: -0.925154  [537600/2213439]
# Current batch training loss: -0.944721  [563200/2213439]
# Current batch training loss: -0.916457  [588800/2213439]
# Current batch training loss: -0.944370  [614400/2213439]
# Current batch training loss: -0.937702  [640000/2213439]
# Current batch training loss: -0.933815  [665600/2213439]
# Current batch training loss: -0.927036  [691200/2213439]
# Current batch training loss: -0.925671  [716800/2213439]
# Current batch training loss: -0.938351  [742400/2213439]
# Current batch training loss: -0.926920  [768000/2213439]
# Current batch training loss: -0.923375  [793600/2213439]
# Current batch training loss: -0.922893  [819200/2213439]
# Current batch training loss: -0.937598  [844800/2213439]
# Current batch training loss: -0.937765  [870400/2213439]
# Current batch training loss: -0.939439  [896000/2213439]
# Current batch training loss: -0.937660  [921600/2213439]
# Current batch training loss: -0.935675  [947200/2213439]
# Current batch training loss: -0.934177  [972800/2213439]
# Current batch training loss: -0.936413  [998400/2213439]
# Current batch training loss: -0.938431  [1024000/2213439]
# Current batch training loss: -0.909617  [1049600/2213439]
# Current batch training loss: -0.931185  [1075200/2213439]
# Current batch training loss: -0.931195  [1100800/2213439]
# Current batch training loss: -0.930526  [1126400/2213439]
# Current batch training loss: -0.936147  [1152000/2213439]
# Current batch training loss: -0.919267  [1177600/2213439]
# Current batch training loss: -0.931151  [1203200/2213439]
# Current batch training loss: -0.911499  [1228800/2213439]
# Current batch training loss: -0.940609  [1254400/2213439]
# Current batch training loss: -0.923213  [1280000/2213439]
# Current batch training loss: -0.927344  [1305600/2213439]
# Current batch training loss: -0.922965  [1331200/2213439]
# Current batch training loss: -0.942571  [1356800/2213439]
# Current batch training loss: -0.937860  [1382400/2213439]
# Current batch training loss: -0.921322  [1408000/2213439]
# Current batch training loss: -0.948221  [1433600/2213439]
# Current batch training loss: -0.939145  [1459200/2213439]
# Current batch training loss: -0.930833  [1484800/2213439]
# Current batch training loss: -0.928297  [1510400/2213439]
# Current batch training loss: -0.938962  [1536000/2213439]
# Current batch training loss: -0.930047  [1561600/2213439]
# Current batch training loss: -0.923523  [1587200/2213439]
# Current batch training loss: -0.927900  [1612800/2213439]
# Current batch training loss: -0.931351  [1638400/2213439]
# Current batch training loss: -0.937303  [1664000/2213439]
# Current batch training loss: -0.933299  [1689600/2213439]
# Current batch training loss: -0.926052  [1715200/2213439]
# Current batch training loss: -0.933109  [1740800/2213439]
# Current batch training loss: -0.927199  [1766400/2213439]
# Current batch training loss: -0.921919  [1792000/2213439]
# Current batch training loss: -0.927750  [1817600/2213439]
# Current batch training loss: -0.933135  [1843200/2213439]
# Current batch training loss: -0.938704  [1868800/2213439]
# Current batch training loss: -0.912467  [1894400/2213439]
# Current batch training loss: -0.912931  [1920000/2213439]
# Current batch training loss: -0.928411  [1945600/2213439]
# Current batch training loss: -0.936764  [1971200/2213439]
# Current batch training loss: -0.924935  [1996800/2213439]
# Current batch training loss: -0.947476  [2022400/2213439]
# Current batch training loss: -0.906948  [2048000/2213439]
# Current batch training loss: -0.927051  [2073600/2213439]
# Current batch training loss: -0.946966  [2099200/2213439]
# Current batch training loss: -0.904646  [2124800/2213439]
# Current batch training loss: -0.926294  [2150400/2213439]
# Current batch training loss: -0.921113  [2176000/2213439]
# Current batch training loss: -0.947249  [2201600/2213439]
# Training loss: -0.928358
# Validation loss: -0.921020
#
# Epoch 11
# -------------------------------
# Current batch training loss: -0.933202  [    0/2213439]
# Current batch training loss: -0.902343  [25600/2213439]
# Current batch training loss: -0.916384  [51200/2213439]
# Current batch training loss: -0.923224  [76800/2213439]
# Current batch training loss: -0.924935  [102400/2213439]
# Current batch training loss: -0.934254  [128000/2213439]
# Current batch training loss: -0.919521  [153600/2213439]
# Current batch training loss: -0.927966  [179200/2213439]
# Current batch training loss: -0.933775  [204800/2213439]
# Current batch training loss: -0.945699  [230400/2213439]
# Current batch training loss: -0.928695  [256000/2213439]
# Current batch training loss: -0.913626  [281600/2213439]
# Current batch training loss: -0.924026  [307200/2213439]
# Current batch training loss: -0.922004  [332800/2213439]
# Current batch training loss: -0.929985  [358400/2213439]
# Current batch training loss: -0.936179  [384000/2213439]
# Current batch training loss: -0.933871  [409600/2213439]
# Current batch training loss: -0.930145  [435200/2213439]
# Current batch training loss: -0.929512  [460800/2213439]
# Current batch training loss: -0.932993  [486400/2213439]
# Current batch training loss: -0.919616  [512000/2213439]
# Current batch training loss: -0.925807  [537600/2213439]
# Current batch training loss: -0.914201  [563200/2213439]
# Current batch training loss: -0.931013  [588800/2213439]
# Current batch training loss: -0.922685  [614400/2213439]
# Current batch training loss: -0.934061  [640000/2213439]
# Current batch training loss: -0.925949  [665600/2213439]
# Current batch training loss: -0.930532  [691200/2213439]
# Current batch training loss: -0.945047  [716800/2213439]
# Current batch training loss: -0.899194  [742400/2213439]
# Current batch training loss: -0.922688  [768000/2213439]
# Current batch training loss: -0.919801  [793600/2213439]
# Current batch training loss: -0.934390  [819200/2213439]
# Current batch training loss: -0.935813  [844800/2213439]
# Current batch training loss: -0.940418  [870400/2213439]
# Current batch training loss: -0.938686  [896000/2213439]
# Current batch training loss: -0.917913  [921600/2213439]
# Current batch training loss: -0.931508  [947200/2213439]
# Current batch training loss: -0.912388  [972800/2213439]
# Current batch training loss: -0.946980  [998400/2213439]
# Current batch training loss: -0.939277  [1024000/2213439]
# Current batch training loss: -0.920960  [1049600/2213439]
# Current batch training loss: -0.920552  [1075200/2213439]
# Current batch training loss: -0.944823  [1100800/2213439]
# Current batch training loss: -0.927262  [1126400/2213439]
# Current batch training loss: -0.935050  [1152000/2213439]
# Current batch training loss: -0.914297  [1177600/2213439]
# Current batch training loss: -0.917877  [1203200/2213439]
# Current batch training loss: -0.911259  [1228800/2213439]
# Current batch training loss: -0.928811  [1254400/2213439]
# Current batch training loss: -0.908068  [1280000/2213439]
# Current batch training loss: -0.929206  [1305600/2213439]
# Current batch training loss: -0.927842  [1331200/2213439]
# Current batch training loss: -0.925450  [1356800/2213439]
# Current batch training loss: -0.915494  [1382400/2213439]
# Current batch training loss: -0.933121  [1408000/2213439]
# Current batch training loss: -0.924749  [1433600/2213439]
# Current batch training loss: -0.915255  [1459200/2213439]
# Current batch training loss: -0.929493  [1484800/2213439]
# Current batch training loss: -0.909306  [1510400/2213439]
# Current batch training loss: -0.910840  [1536000/2213439]
# Current batch training loss: -0.926326  [1561600/2213439]
# Current batch training loss: -0.930307  [1587200/2213439]
# Current batch training loss: -0.890751  [1612800/2213439]
# Current batch training loss: -0.934141  [1638400/2213439]
# Current batch training loss: -0.919600  [1664000/2213439]
# Current batch training loss: -0.917840  [1689600/2213439]
# Current batch training loss: -0.917686  [1715200/2213439]
# Current batch training loss: -0.922402  [1740800/2213439]
# Current batch training loss: -0.940579  [1766400/2213439]
# Current batch training loss: -0.936471  [1792000/2213439]
# Current batch training loss: -0.931361  [1817600/2213439]
# Current batch training loss: -0.930242  [1843200/2213439]
# Current batch training loss: -0.901625  [1868800/2213439]
# Current batch training loss: -0.937315  [1894400/2213439]
# Current batch training loss: -0.929462  [1920000/2213439]
# Current batch training loss: -0.938454  [1945600/2213439]
# Current batch training loss: -0.921533  [1971200/2213439]
# Current batch training loss: -0.923916  [1996800/2213439]
# Current batch training loss: -0.939923  [2022400/2213439]
# Current batch training loss: -0.934570  [2048000/2213439]
# Current batch training loss: -0.935063  [2073600/2213439]
# Current batch training loss: -0.937995  [2099200/2213439]
# Current batch training loss: -0.930905  [2124800/2213439]
# Current batch training loss: -0.914469  [2150400/2213439]
# Current batch training loss: -0.937194  [2176000/2213439]
# Current batch training loss: -0.929336  [2201600/2213439]
# Training loss: -0.929282
# Validation loss: -0.920967
#
# Stopping early!
# Done!

# %% [markdown]
# # Visualize Training

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('Cosine Similarity Loss')
plt.legend()

# %% [markdown]
# # Save the Model

# %%
torch.save(final_model, "../3D_Heteroscedastic_Convnet_models/3D_CNN_subM-256.pt")
print("Saved PyTorch Model State to ../3D_Heteroscedastic_Convnet_models/3D_CNN_subM-256.pt")
# Out:
# Saved PyTorch Model State to ../3D_Heteroscedastic_Convnet_models/3D_CNN_subM-256.pt
